# %% [markdown]
# # Intro to the Web of Science Starter API
#
# This notebook demonstrates some standard means for accessing and retrieving data from the Web of Science (WoS) database using the WoS Starter API.
#
# The Starter API allows users to automate searches of the WoS database, retrieving the following data:
# + author(s), editor(s), etc.
# + document title
# + source / publication title
# + document type
# + author keywords <!--[?]-->
# + document identifiers (ISSN, eISSN, ISBN, DOI, PubMed Id, Web of Science identifier [UT])
# + author /researcher identifiers
# + publication year
# + volume and issue
# + pages
# + times cited??
#
# *Note: The Starter API also retrieves records using the following fields (but which are not included in the results):*
# + keywords:
#     <!--+ author keywords-->
#     + Keywords Plus
# + Abstract
#
# *Thus, you may search for all documents that use "nuclear disarmament" in their keywords or abstract, but the returned results will not include the keywords or abstract themselves. If you want to examine how a particular text uses this term you will have to visit the WoS record to review its abstract or use one of the other methods available tot the Dartmouth community for accessing WoS [detailed here](https://researchguides.dartmouth.edu/c.php?g=59725&p=9910244).*
#
# ### Limits on Starter API use
#
# Institutional subscriptions to the Starter API (which Dartmouth Library has) allow researchers to:
# + place up to 5,000 requests per day
# + up to 5 requests per second
# + retrieve up to 50 records per request
#
# meaning a researcher can retrieve a maximum of 50,000 records in a given day.
#
# For a more information on the WoS Starter and Lite APIs and different ways to access WoS data - particularly relevant for Dartmouth community members, please see the [Dartmouth Library *Accessing Web of Science Data* Guide](https://researchguides.dartmouth.edu/c.php?g=1324739&p=11200897&preview=f2c39380122f0fc7a1ebb71e8a4b55ea). For more on the database fields that may be searched and those that will be returned by the Starter API, see the [README available with the Starter API Client Github page](https://github.com/clarivate/wosstarter_python_client/blob/master/README.md).

# %% [markdown]
# ## I. Getting Started
#
# 1. **Import all necessary packages.** To first install these packages to a local environment, you can use the requirements.txt file. Open a terminal / command prompt within this project's folder and type:
#
# ```
# pip install -r requirements.txt
# ```
#
# Then you can import these packages.

# %%
import requests
import time
import os
from pathlib import Path
import urllib.parse
import pandas as pd
import random
from bs4 import BeautifulSoup   #for parsing xml and html
from random import randint  
from dotenv import load_dotenv 
load_dotenv()
# Out:
# True

# %% [markdown]
# 2. Store the API link to memory and retrieve your API key. See this repository's [ReadME.md](../../README.md) for more acquiring, saving, and retrieving your API Key from an .env file.

# %%
BASEURL_ST = 'https://api.clarivate.com/apis/wos-starter/v1/'
HEADERS_ST = {'X-APIKey': os.getenv("APIKEY")}

# %% [markdown]
# ## II. Search Queries
#
# ### IIa. Retrieve documents by author
#
# 1. We can begin with a simple search query for one author. For example, we can search amongst the [suspiciously prolific publications by the Spanish scholar Rafael Luque](https://english.elpais.com/science-tech/2023-04-02/one-of-the-worlds-most-cited-scientists-rafael-luque-suspended-without-pay-for-13-years.html).

# %%
#SEARCH_QUERY = 'AU=Lepore, Jill' 
SEARCH_QUERY = "AU=Luque, Rafael" # Enter your search query here, in this case we are looking for an author named Rafael Luque
#SEARCH_QUERY = 'AU=Schnell, JD'  

#SEARCH_QUERY = "AI=IMS-5344-2023"
#SEARCH_QUERY = "AI=EFQ-9500-2022"
#SEARCH_QUERY = "UT=WOS:000188058500010"

# %% [markdown]
# 2. **RETRIEVE DATA**: We can then insert the API url (BASEURL_ST), the search query, and the API Key (HEADERS_ST) into a requests command.

# %%
initial_request = requests.get(f'{BASEURL_ST}documents?db=WOS&q={urllib.parse.quote(SEARCH_QUERY)}', headers=HEADERS_ST)
data = initial_request.json()
data
# Out:
# {'metadata': {'total': 1066, 'page': 1, 'limit': 10},
#  'hits': [{'uid': 'WOS:001591054100001',
#    'title': 'Supported metal nanoparticles on porous materials. Methods and applications (Vol 38, pg 481, 2009)',
#    'types': ['Correction', 'Early Access'],
#    'sourceTypes': ['Correction', 'Early Access'],
#    'source': {'sourceTitle': 'CHEMICAL SOCIETY REVIEWS',
#     'publishYear': 2025,
#     'pages': {'count': 2}},
#    'names': {'authors': [{'displayName': 'White, Robin J.',
#       'wosStandard': 'White, RJ',
#       'researcherId': 'CFN-0008-2022'},
#      {'displayName': 'Luque, Rafael',
#       'wosStandard': 'Luque, R',
#       'researcherId': 'F-9853-2010'},
#      {'displayName': 'Budarin, Vitaliy L.',
#       'wosStandard': 'Budarin, VL',
#       'researcherId': 'LMY-8679-2024'},
#      {'displayName': 'Clark, James H.',
#       'wosStandard': 'Clark, JH',
#       'researcherId': 'LRH-3540-2024'},
#      {'displayName': 'Macquarrie, Duncan J.',
#       'wosStandard': 'Macquarrie, DJ',
#       'researcherId': 'DXM-7702-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:001591054100001&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:001591054100001&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:001591054100001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 0}],
#    'identifiers': {'doi': '10.1039/d5cs90086g',
#     'issn': '0306-0012',
#     'eissn': '1460-4744',
#     'pmid': '41063699'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:000453472500003',
#    'title': 'Development of Educative Software: A Methodological Proposal',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'TELOS-REVISTA DE ESTUDIOS INTERDISCIPLINARIOS EN CIENCIAS SOCIALES',
#     'publishYear': 2005,
#     'volume': '7',
#     'issue': '3',
#     'pages': {'range': '383-396', 'begin': '383', 'end': '396', 'count': 14}},
#    'names': {'authors': [{'displayName': 'Quintero, Hugo',
#       'wosStandard': 'Quintero, H'},
#      {'displayName': 'Portillo, Lisbeth',
#       'wosStandard': 'Portillo, L',
#       'researcherId': 'FRT-3411-2022'},
#      {'displayName': 'Luque, Rafael',
#       'wosStandard': 'Luque, R',
#       'researcherId': 'IGB-3297-2023'},
#      {'displayName': 'Gonzalez, Marisela',
#       'wosStandard': 'González, M',
#       'researcherId': 'CTD-2653-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000453472500003&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000453472500003&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000453472500003&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000453472500003&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 1}],
#    'identifiers': {'issn': '2343-5763', 'eissn': '1317-0570'},
#    'keywords': {'authorKeywords': ['Educational software',
#      'methodology',
#      'software development']}},
#   {'uid': 'WOS:000420415500010',
#    'title': 'INFECTIOUS BACTEREMIC ECTHYMA IN A PATIENT WITH HIV INFECTION',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'ACTAS DERMO-SIFILIOGRAFICAS',
#     'publishYear': 2005,
#     'publishMonth': 'FEB',
#     'volume': '96',
#     'issue': '1',
#     'pages': {'range': '54-55', 'begin': '54', 'end': '55', 'count': 2}},
#    'names': {'authors': [{'displayName': 'Bernabeu, Jose',
#       'wosStandard': 'Bernabeu, J',
#       'researcherId': 'OOE-9941-2025'},
#      {'displayName': 'Aparicio, Reyes',
#       'wosStandard': 'Aparicio, R',
#       'researcherId': 'EMT-5884-2022'},
#      {'displayName': 'Luque, Rafael',
#       'wosStandard': 'Luque, R',
#       'researcherId': 'HVB-2615-2023'},
#      {'displayName': 'Nieto, Maria D.',
#       'wosStandard': 'Nieto, MD',
#       'researcherId': 'GBN-0050-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000420415500010&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000420415500010&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000420415500010&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000420415500010&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 5}],
#    'identifiers': {'doi': '10.1016/S0001-7310(05)73036-2',
#     'issn': '0001-7310',
#     'eissn': '1578-2190',
#     'pmid': '16476336'},
#    'keywords': {'authorKeywords': ['ecthyma',
#      'HIV',
#      'bacteremia',
#      'Streptococcus pyogenes',
#      'Escherichia coli']}},
#   {'uid': 'WOS:000248430903088',
#    'title': 'Object recognition and inspection in difficult industrial environments',
#    'types': ['Meeting'],
#    'sourceTypes': ['Proceedings Paper'],
#    'source': {'sourceTitle': '2006 IEEE INTERNATIONAL CONFERENCE ON INDUSTRIAL TECHNOLOGY, VOLS 1-6',
#     'publishYear': 2006,
#     'pages': {'range': '2035-+', 'begin': '2035', 'end': '+', 'count': 2}},
#    'names': {'authors': [{'displayName': 'Dominguez, Enrique',
#       'wosStandard': 'Domínguez, E',
#       'researcherId': 'K-8465-2012'},
#      {'displayName': 'Spinola, Carlos',
#       'wosStandard': 'Spinola, C',
#       'researcherId': 'GAF-9034-2022'},
#      {'displayName': 'Luque, Rafael M.',
#       'wosStandard': 'Luque, RM',
#       'researcherId': 'Q-8132-2018'},
#      {'displayName': 'Palomo, Esteban J.',
#       'wosStandard': 'Palomo, EJ',
#       'researcherId': 'DXT-3316-2022'},
#      {'displayName': 'Munoz, Jose',
#       'wosStandard': 'Muñoz, J',
#       'researcherId': 'JJS-3866-2023'}],
#     'bookCorp': [{'displayName': 'IEEE'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000248430903088&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000248430903088&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000248430903088&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000248430903088&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 1}],
#    'identifiers': {'isbn': '978-1-4244-0725-5'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:000241036200006',
#    'title': 'Green chemistry and the biorefinery: A partnership for a sustainable future',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'GREEN CHEMISTRY',
#     'publishYear': 2006,
#     'volume': '8',
#     'issue': '10',
#     'pages': {'range': '853-860', 'begin': '853', 'end': '860', 'count': 8}},
#    'names': {'authors': [{'displayName': 'Clark, James H.',
#       'wosStandard': 'Clark, JH',
#       'researcherId': 'C-2064-2012'},
#      {'displayName': 'Budarin, Vitaly',
#       'wosStandard': 'Budarin, V',
#       'researcherId': 'J-9212-2019'},
#      {'displayName': 'Deswarte, Fabien E. I.',
#       'wosStandard': 'Deswarte, FEI',
#       'researcherId': 'ETF-7953-2022'},
#      {'displayName': 'Hardy, Jeffrey J. E.',
#       'wosStandard': 'Hardy, JJE',
#       'researcherId': 'P-2029-2017'},
#      {'displayName': 'Kerton, Fran M.',
#       'wosStandard': 'Kerton, FM',
#       'researcherId': 'B-1444-2012'},
#      {'displayName': 'Hunt, Andrew J.',
#       'wosStandard': 'Hunt, AJ',
#       'researcherId': 'FAA-2942-2022'},
#      {'displayName': 'Luque, Rafael',
#       'wosStandard': 'Luque, R',
#       'researcherId': 'F-9853-2010'},
#      {'displayName': 'Macquarrie, Duncan J.',
#       'wosStandard': 'Macquarrie, DJ',
#       'researcherId': 'DXM-7702-2022'},
#      {'displayName': 'Milkowski, Krzysztof',
#       'wosStandard': 'Milkowski, K',
#       'researcherId': 'FPK-4456-2022'},
#      {'displayName': 'Rodriguez, Aitana',
#       'wosStandard': 'Rodriguez, A',
#       'researcherId': 'DPC-9993-2022'},
#      {'displayName': 'Samuel, Owain',
#       'wosStandard': 'Samuel, O',
#       'researcherId': 'DQY-4668-2022'},
#      {'displayName': 'Tavener, Stewart J.',
#       'wosStandard': 'Tavener, SJ',
#       'researcherId': 'EBX-3007-2022'},
#      {'displayName': 'White, Robin J.',
#       'wosStandard': 'White, RJ',
#       'researcherId': 'P-3490-2015'},
#      {'displayName': 'Wilson, Ashley J.',
#       'wosStandard': 'Wilson, AJ',
#       'researcherId': 'GKJ-5744-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000241036200006&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000241036200006&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000241036200006&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000241036200006&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 256}],
#    'identifiers': {'doi': '10.1039/b604483m',
#     'issn': '1463-9262',
#     'eissn': '1463-9270'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:000238335100009',
#    'title': 'Starbons: New starch-derived mesoporous carbonaceous materials with tunable properties',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'ANGEWANDTE CHEMIE-INTERNATIONAL EDITION',
#     'publishYear': 2006,
#     'volume': '45',
#     'issue': '23',
#     'pages': {'range': '3782-3786',
#      'begin': '3782',
#      'end': '3786',
#      'count': 5}},
#    'names': {'authors': [{'displayName': 'Budarin, Vitaly',
#       'wosStandard': 'Budarin, V',
#       'researcherId': 'J-9212-2019'},
#      {'displayName': 'Clark, James H.',
#       'wosStandard': 'Clark, JH',
#       'researcherId': 'C-2064-2012'},
#      {'displayName': 'Hardy, Jeffrey J. E.',
#       'wosStandard': 'Hardy, JJE',
#       'researcherId': 'P-2029-2017'},
#      {'displayName': 'Luque, Rafael',
#       'wosStandard': 'Luque, R',
#       'researcherId': 'F-9853-2010'},
#      {'displayName': 'Milkowski, Krzysztof',
#       'wosStandard': 'Milkowski, K',
#       'researcherId': 'FPK-4456-2022'},
#      {'displayName': 'Tavener, Stewart J.',
#       'wosStandard': 'Tavener, SJ',
#       'researcherId': 'EBX-3007-2022'},
#      {'displayName': 'Wilson, Ashley J.',
#       'wosStandard': 'Wilson, AJ',
#       'researcherId': 'GKJ-5744-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000238335100009&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000238335100009&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000238335100009&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000238335100009&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 255}],
#    'identifiers': {'doi': '10.1002/anie.200600460',
#     'issn': '1433-7851',
#     'eissn': '1521-3773',
#     'pmid': '16671136'},
#    'keywords': {'authorKeywords': ['carbohydrates',
#      'carbon',
#      'mesoporous materials',
#      'surface chemistry',
#      'thermochemistry']}},
#   {'uid': 'WOS:000283580900040',
#    'title': 'Structural and Catalytic Properties of Amorphous Mesoporous AlPO<sub>4</sub> Materials Prepared in the Presence of 2,4-Pentanedione and 2,5-Hexanedione as Aluminium Chelating Agents',
#    'types': ['Meeting'],
#    'sourceTypes': ['Proceedings Paper'],
#    'source': {'sourceTitle': 'SCIENTIFIC BASES FOR THE PREPARATION OF HETEROGENEOUS CATALYSTS, PROCEEDINGS OF THE 9TH INTERNATIONAL SYMPOSIUM',
#     'publishYear': 2006,
#     'volume': '162',
#     'pages': {'range': '315-322', 'begin': '315', 'end': '322', 'count': 8}},
#    'names': {'authors': [{'displayName': 'Campelo, Juan M.',
#       'wosStandard': 'Campelo, JM',
#       'researcherId': 'EMZ-4390-2022'},
#      {'displayName': 'Jaraba, Margarita',
#       'wosStandard': 'Jaraba, M',
#       'researcherId': 'FBO-0046-2022'},
#      {'displayName': 'Luna, Diego',
#       'wosStandard': 'Luna, D',
#       'researcherId': 'HRI-9560-2023'},
#      {'displayName': 'Luque, Rafael',
#       'wosStandard': 'Luque, R',
#       'researcherId': 'F-9853-2010'},
#      {'displayName': 'Marinas, Jose M.',
#       'wosStandard': 'Marinas, JM',
#       'researcherId': 'FLG-5664-2022'},
#      {'displayName': 'Romero, Antonio A.',
#       'wosStandard': 'Romero, AA',
#       'researcherId': 'IPL-3566-2023'}],
#     'bookEditors': [{'displayName': 'Gaigneaux, EM'},
#      {'displayName': 'Devillers, M'},
#      {'displayName': 'De Vos, DE'},
#      {'displayName': 'Hermans, S'},
#      {'displayName': 'Jacobs, PA'},
#      {'displayName': 'Martens, JA'},
#      {'displayName': 'Ruiz, P'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000283580900040&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000283580900040&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000283580900040&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 0}],
#    'identifiers': {'doi': '10.1016/S0167-2991(06)80922-5',
#     'issn': '0167-2991',
#     'eisbn': '978-0-444-52827-8'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:000239926900029',
#    'title': 'Catechol <i>O</i>-methylation with dimethyl carbonate over different acid-base catalysts',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'NEW JOURNAL OF CHEMISTRY',
#     'publishYear': 2006,
#     'publishMonth': 'AUG',
#     'volume': '30',
#     'issue': '8',
#     'pages': {'range': '1228-1234',
#      'begin': '1228',
#      'end': '1234',
#      'count': 7}},
#    'names': {'authors': [{'displayName': 'Luque, Rafael',
#       'wosStandard': 'Luque, R',
#       'researcherId': 'F-9853-2010'},
#      {'displayName': 'Campelo, Juan Manuel',
#       'wosStandard': 'Campelo, JM',
#       'researcherId': 'EMZ-4390-2022'},
#      {'displayName': 'Conesa, Tomas David',
#       'wosStandard': 'Conesa, TD',
#       'researcherId': 'CKF-8490-2022'},
#      {'displayName': 'Luna, Diego',
#       'wosStandard': 'Luna, D',
#       'researcherId': 'HRI-9560-2023'},
#      {'displayName': 'Marinas, Jose Maria',
#       'wosStandard': 'Marinas, JM',
#       'researcherId': 'FOQ-9906-2022'},
#      {'displayName': 'Romero, Antonio Angel',
#       'wosStandard': 'Romero, AA',
#       'researcherId': 'K-6205-2014'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000239926900029&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000239926900029&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000239926900029&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000239926900029&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 31}],
#    'identifiers': {'doi': '10.1039/b605053k',
#     'issn': '1144-0546',
#     'eissn': '1369-9261'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:000241973400014',
#    'title': 'Apoptotic and proliferation indexes in primary superficial bladder tumors',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'CANCER LETTERS',
#     'publishYear': 2006,
#     'publishMonth': 'OCT 28',
#     'volume': '242',
#     'issue': '2',
#     'pages': {'range': '266-272', 'begin': '266', 'end': '272', 'count': 7}},
#    'names': {'authors': [{'displayName': 'Gonzalez-Campora, Ricardo',
#       'wosStandard': 'Gonzalez-Campora, R',
#       'researcherId': 'CRR-8259-2022'},
#      {'displayName': 'Davalos-Casanova, Guillermo',
#       'wosStandard': 'Davalos-Casanova, G',
#       'researcherId': 'CNK-3051-2022'},
#      {'displayName': 'Beato-Moreno, Antonio',
#       'wosStandard': 'Beato-Moreno, A',
#       'researcherId': 'AAG-7533-2020'},
#      {'displayName': 'Luque, Rafael J.',
#       'wosStandard': 'Luque, RJ',
#       'researcherId': 'DWC-6013-2022'},
#      {'displayName': 'Alvarez-Kindelan, Jose',
#       'wosStandard': 'Alvarez-Kindelan, J',
#       'researcherId': 'ELO-4958-2022'},
#      {'displayName': 'Requena, Maria J.',
#       'wosStandard': 'Requena, MJ',
#       'researcherId': 'FTY-8368-2022'},
#      {'displayName': 'Montironi, Rodolfo',
#       'wosStandard': 'Montironi, R',
#       'researcherId': 'DWH-6887-2022'},
#      {'displayName': 'Lopez-Beltran, Antonio',
#       'wosStandard': 'Lopez-Beltrán, A',
#       'researcherId': 'AAK-7326-2020'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000241973400014&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000241973400014&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000241973400014&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000241973400014&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 17}],
#    'identifiers': {'doi': '10.1016/j.canlet.2005.11.006',
#     'issn': '0304-3835',
#     'eissn': '1872-7980',
#     'pmid': '16426743'},
#    'keywords': {'authorKeywords': ['bladder cancer', 'apoptosis', 'Ki-67']}},
#   {'uid': 'WOS:000249848200022',
#    'title': 'A microwave approach to the selective synthesis of ω-laurolactam',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'GREEN CHEMISTRY',
#     'publishYear': 2007,
#     'volume': '9',
#     'issue': '10',
#     'pages': {'range': '1109-1113',
#      'begin': '1109',
#      'end': '1113',
#      'count': 5}},
#    'names': {'authors': [{'displayName': 'Conesa, Tomas D.',
#       'wosStandard': 'Conesa, TD',
#       'researcherId': 'CKF-8490-2022'},
#      {'displayName': 'Campelo, Juan M.',
#       'wosStandard': 'Campelo, JM',
#       'researcherId': 'EMZ-4390-2022'},
#      {'displayName': 'Clark, James H.',
#       'wosStandard': 'Clark, JH',
#       'researcherId': 'C-2064-2012'},
#      {'displayName': 'Luque, Rafael',
#       'wosStandard': 'Luque, R',
#       'researcherId': 'F-9853-2010'},
#      {'displayName': 'Macquarrie, Duncan J.',
#       'wosStandard': 'Macquarrie, DJ',
#       'researcherId': 'DXM-7702-2022'},
#      {'displayName': 'Romero, Antonio A.',
#       'wosStandard': 'Romero, AA',
#       'researcherId': 'K-6205-2014'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000249848200022&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000249848200022&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000249848200022&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000249848200022&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 18}],
#    'identifiers': {'doi': '10.1039/b705881k',
#     'issn': '1463-9262',
#     'eissn': '1463-9270'},
#    'keywords': {'authorKeywords': []}}]}

# %% [markdown]
# 3. **RECORD LIMITS**: Although this query finds 1066 records, only 10 are returned due to the default limit of records. We can increase that to 50 using the `limit` parameter:

# %%
initial_request = requests.get(f'{BASEURL_ST}documents?db=WOS&q={urllib.parse.quote(SEARCH_QUERY)}&limit=50', headers=HEADERS_ST)
data = initial_request.json()

# %% [markdown]
# 4. **VIEW SUMMARY INFORMATION FROM WOS REQUEST**: As you can see, this returns a json document as a Python dictionary. We can retrieve specific information from this record the same way we would a dictionary. To retrieve only a summary of the record, we can run the following:

# %%
data['metadata']  #returns total number of records
# Out:
# {'total': 1066, 'page': 1, 'limit': 50}

# %% [markdown]
# 5. **CONVERT TO DATAFRAME TO DISAMBIGUATE AUTHORS**:
#
# The results above return the work of multiple scholars with the name Rafael Luque or R. Luque. Instead we need to search for this particular scholar by using his ResearcherID.
#
# We can filter the data already retrieved to disambiguate the different Rafael Luques.
#
# Let's first examine the data returned (under the name `data`).

# %%
def author_summary(jsondict):
    """
    This function reads in the json returned with a WoS search query
    and then converts that response into a dataframe of authors
    """
    auth_rows = []
    hits = [hit for hit in jsondict['hits']]
    print(f"Titles (and their authors) included in response to the query: '{SEARCH_QUERY}' - first {len(hits)} hits")
    for hit in hits:
        title = hit.get('title')
        year = hit.get('source', {}).get('publishYear')
        authors = hit.get('names', {}).get('authors')
        au_keywords = hit.get('keywords', {}).get('authorKeywords')
        #print(authors)
        for author in authors:
            # print("\nauthor = ", author)
            au_std_name = author.get('wosStandard')
            au_res_id = author.get('researcherId')
            auth_rows.append([title, year, au_keywords, au_std_name, au_res_id])
    return(auth_rows)    

rows = author_summary(data)

author_df = pd.DataFrame(rows, columns = ["title", "year", "author_keywords", "authorname_wos_std", "researcherid"])
print(author_df.shape)
author_df.head()
# Out:
# Titles (and their authors) included in response to the query: 'AU=Luque, Rafael' - first 50 hits
# (284, 5)
#                                                title  year author_keywords  \
# 0  Supported metal nanoparticles on porous materi...  2025              []
# 1  Supported metal nanoparticles on porous materi...  2025              []
# 2  Supported metal nanoparticles on porous materi...  2025              []
# 3  Supported metal nanoparticles on porous materi...  2025              []
# 4  Supported metal nanoparticles on porous materi...  2025              []
#
#   authorname_wos_std   researcherid
# 0          White, RJ  CFN-0008-2022
# 1           Luque, R    F-9853-2010
# 2        Budarin, VL  LMY-8679-2024
# 3          Clark, JH  LRH-3540-2024
# 4     Macquarrie, DJ  DXM-7702-2022

# %% [markdown]
# 6. **GROUP BY AUTHOR ID TO CREATE A SUMMARY TABLE OF AUTHORS**:

# %%
# groupby researcherid
from collections import Counter
#author_df.groupby(by = "researcherid")["author_keywords"].apply(list)

def flatten_extend(matrix: list):
    flat_list = []
    for row in matrix:
        if type(row) is list:
            flat_list.extend(row)
        else:
            flat_list.append(row)
    return flat_list

def most_common_keywords(kwlist: list):
    #print(kwlist)
    flat_kwlist = flatten_extend(kwlist)
    #print("FLATTENED:", flat_kwlist)
    kw_ctr = Counter(flat_kwlist)
    #print("***counter:", kw_ctr)
    kw_most_common = kw_ctr.most_common(5)
    #print("$$Top 3 most common:", kw_most_common)
    return kw_most_common

author_summary = author_df.groupby(by = "researcherid")\
    .agg({"authorname_wos_std": "first", "title": "count", "author_keywords": lambda x: most_common_keywords(x)})

author_summary = author_summary.rename(columns = {"title": "au_count"})

author_summary = author_summary.sort_values(by = "au_count", ascending=False)
author_summary_sub = author_summary[author_summary['authorname_wos_std'].str.startswith("Luque")]
author_summary_sub
# Out:
#               authorname_wos_std  au_count  \
# researcherid
# F-9853-2010             Luque, R        40
# Q-8132-2018            Luque, RM         4
# HVB-2615-2023           Luque, R         2
# IGB-3297-2023           Luque, R         2
# DWC-6013-2022          Luque, RJ         2
#
#                                                  author_keywords
# researcherid
# F-9853-2010    [(heterogeneous catalysis, 8), (mesoporous mat...
# Q-8132-2018    [(network security, 2), (data mining, 2), (Com...
# HVB-2615-2023  [(ecthyma, 1), (HIV, 1), (bacteremia, 1), (Str...
# IGB-3297-2023  [(Educational software, 1), (methodology, 1), ...
# DWC-6013-2022  [(bladder cancer, 1), (apoptosis, 1), (Ki-67, 1)]

# %%
list(author_summary_sub.loc[ :, "author_keywords"])
# Out:
# [[('heterogeneous catalysis', 8),
#   ('mesoporous materials', 4),
#   ('Ti-MCM-41', 2),
#   ('Organic functionalisation', 2),
#   ('Microwaves', 2)],
#  [('network security', 2),
#   ('data mining', 2),
#   ('Competitive learning', 1),
#   ('intrusion detection system', 1),
#   ('Multiagent system', 1)],
#  [('ecthyma', 1),
#   ('HIV', 1),
#   ('bacteremia', 1),
#   ('Streptococcus pyogenes', 1),
#   ('Escherichia coli', 1)],
#  [('Educational software', 1),
#   ('methodology', 1),
#   ('software development', 1)],
#  [('bladder cancer', 1), ('apoptosis', 1), ('Ki-67', 1)]]

# %% [markdown]
# 7. **SEARCH BY AUTHOR ID**: We can now refine our search using a **WoS Research Id** to focus our search on "R Luque" the chemist:

# %%
SEARCH_QUERY2 = 'AI=F-9853-2010'

initial_request = requests.get(f'{BASEURL_ST}documents?db=WOS&q={urllib.parse.quote(SEARCH_QUERY2)}&limit=50', headers=HEADERS_ST)
data2 = initial_request.json()

# %%
data2['metadata']  #returns total number of records
# Out:
# {'total': 984, 'page': 1, 'limit': 50}

# %%
len(data2['hits'])
# Out:
# 50

# %% [markdown]
# 8. **RETRIEVE A LIST OF TITLES BY ONE AUTHOR**: To retrieve only summary information for each publication (title, source, year, and page range) we can run the following function:

# %%
def title_summary(jsondict):
    hits = [hit for hit in jsondict['hits']]
    print(f"Titles included in response to the query: '{SEARCH_QUERY2}'")
    for hit in hits:
        title = hit.get('title')
        so_title = hit.get('source', {}).get('sourceTitle')
        year = hit.get('source', {}).get('publishYear')
        pages = hit.get('source', {}).get('pages', {}).get('range', {})
        if isinstance(pages, str):
            pages = pages.split("-")
        print(f"{year}. '{title}', {so_title}: {pages}")

# %%
title_summary(data2)
# Out:
# Titles included in response to the query: 'AI=F-9853-2010'
# 2025. 'Supported metal nanoparticles on porous materials. Methods and applications (Vol 38, pg 481, 2009)', CHEMICAL SOCIETY REVIEWS: {}
# 1994. 'COTTARDS-SYMDROME - HISTORICAL AND CONCEPTUAL ASPECTS', ACTAS LUSO-ESPANOLAS DE NEUROLOGIA PSIQUIATRIA Y CIENCIAS AFINES: ['178', '188']
# 1995. 'THE CAMBRIDGE NEUROLOGICAL INVENTORY - A CLINICAL INSTRUMENT FOR ASSESSMENT OF SOFT NEUROLOGICAL SIGNS IN PSYCHIATRIC-PATIENTS', PSYCHIATRY RESEARCH: ['183', '204']
# 1996. 'Demographic and phenomenological features of a Spanish population of patients with late paraphrenia', INTERNATIONAL JOURNAL OF GERIATRIC PSYCHIATRY: ['745', '747']
# 2003. 'Effect of phosphate precursor and organic additives on the structural and catalytic properties of amorphous mesoporous AlPO<sub>4</sub> materials', CHEMISTRY OF MATERIALS: ['3352', '3364']
# 2005. 'Cyclohexene conversion and toluene methylation with dimethyl carbonate over Al-MCM-41 catalysts', MOLECULAR SIEVES: FROM BASIC RESEARCH TO INDUSTRIAL APPLICATIONS, PTS A AND B: ['1383', '1390']
# 2005. 'Structured mesoporous organosilicas from an acetonitrile-water template system', JOURNAL OF MATERIALS CHEMISTRY: ['3946', '3951']
# 2005. 'A novel highly active biomaterial supported palladium catalyst', GREEN CHEMISTRY: ['552', '557']
# 2005. 'MANAGEMENT INDICATORS AND BENCHMARKING TECHNIQUES APPLIED TO THE IMPROVEMENT OF REGENT COMMUNITIES', INGENIERIA DEL AGUA: ['63', '76']
# 2005. 'Synthesis of acidic Al-MCM-48: Influence of the Si/Al ratio, degree of the surfactant hydroxyl exchange, and post-treatment in NH<sub>4</sub>F solution', JOURNAL OF CATALYSIS: ['327', '338']
# 2005. 'Cotard's syndrome in adolescents and young adults: A possible onset of bipolar disorder requiring a mood stabilizer?', JOURNAL OF CHILD AND ADOLESCENT PSYCHOPHARMACOLOGY: ['706', '711']
# 2005. 'NH<sub>4</sub>F effect in post-synthesis Al-MCM-41 mesoporous treatment of materials', MICROPOROUS AND MESOPOROUS MATERIALS: ['11', '20']
# 2005. 'Aryl alkynylation versus alkyne homocoupling: Unprecedented selectivity switch in Cu, phosphine and solvent-free heterogeneous Pd-catalysed couplings', TETRAHEDRON: ['9860', '9868']
# 2006. 'Green chemistry and the biorefinery: A partnership for a sustainable future', GREEN CHEMISTRY: ['853', '860']
# 2006. 'Starbons: New starch-derived mesoporous carbonaceous materials with tunable properties', ANGEWANDTE CHEMIE-INTERNATIONAL EDITION: ['3782', '3786']
# 2006. 'Structural and Catalytic Properties of Amorphous Mesoporous AlPO<sub>4</sub> Materials Prepared in the Presence of 2,4-Pentanedione and 2,5-Hexanedione as Aluminium Chelating Agents', SCIENTIFIC BASES FOR THE PREPARATION OF HETEROGENEOUS CATALYSTS, PROCEEDINGS OF THE 9TH INTERNATIONAL SYMPOSIUM: ['315', '322']
# 2006. 'Influence of the acid-base properties in Si-MCM-41 and B-MCM-41 mesoporous materials on the activity and selectivity of ε-caprolactam synthesis', APPLIED CATALYSIS A-GENERAL: ['224', '234']
# 2006. 'Catechol <i>O</i>-methylation with dimethyl carbonate over different acid-base catalysts', NEW JOURNAL OF CHEMISTRY: ['1228', '1234']
# 2007. 'A microwave approach to the selective synthesis of ω-laurolactam', GREEN CHEMISTRY: ['1109', '1113']
# 2007. 'Tunable mesoporous materials optimised for aqueous phase esterifications', GREEN CHEMISTRY: ['992', '995']
# 2007. 'Towards a bio-based industry: Benign catalytic esterifications of succinic acid in the presence of water', CHEMISTRY-A EUROPEAN JOURNAL: ['6914', '6919']
# 2007. 'Versatile mesoporous carbonaceous materials for acid catalysis', CHEMICAL COMMUNICATIONS: ['634', '636']
# 2007. 'Catalytic performance of Al-MCM-41 materials in the <i>N</i>-alkylation of aniline', JOURNAL OF MOLECULAR CATALYSIS A-CHEMICAL: ['190', '196']
# 2007. 'Ga-MCM-41 synthesis and catalytic activity in the liquid-phase isomerisation of α-pinene', MICROPOROUS AND MESOPOROUS MATERIALS: ['333', '340']
# 2007. 'Cotard's syndrome in adolescents and young adults is associated with an increased risk of bipolar disorder', BIPOLAR DISORDERS: ['665', '668']
# 2007. 'EPR spin probe investigation into the synthesis of mesoporous silica from the water/acetonitrile/<i>n</i>-dodecylamine system', JOURNAL OF PHYSICAL CHEMISTRY C: ['14500', '14507']
# 2007. 'Novel mesoporous silicoaluminophosphates as highly active and selective materials in the Beckmann rearrangement of cyclohexanone and cyclododecanone oximes', JOURNAL OF CATALYSIS: ['1', '10']
# 2008. 'Biofuels: a technological perspective', ENERGY & ENVIRONMENTAL SCIENCE: ['542', '564']
# 2008. 'Preparation of highly active and dispersed platinum nanoparticles on mesoporous Al-MCM-48 and their activity in the hydroisomerisation of <i>n</i>-octane', CHEMISTRY-A EUROPEAN JOURNAL: ['5988', '5995']
# 2008. 'Microwave facile preparation of highly active and dispersed SBA-12 supported metal nanoparticles', GREEN CHEMISTRY: ['853', '858']
# 2008. 'Microwave-assisted synthesis of oligothiophene semiconductors in aqueous media using silica and chitosan supported Pd catalysts', GREEN CHEMISTRY: ['517', '523']
# 2008. 'Palladium nanoparticles on polysaccharide-derived mesoporous materials and their catalytic performance in C-C coupling reactions', GREEN CHEMISTRY: ['382', '387']
# 2008. 'Efficient Microwave Oxidation of Alcohols Using Low-Loaded Supported Metallic Iron Nanoparticles', CHEMSUSCHEM: ['746', '750']
# 2008. 'Catalytic performance of carbonaceous materials in the esterification of succinic acid', CATALYSIS COMMUNICATIONS: ['1709', '1714']
# 2008. 'Controlling selectivity in catalysis: Selective greener oxidation of cyclohexene under microwave conditions', APPLIED CATALYSIS A-GENERAL: ['154', '159']
# 2008. 'A simple and efficient route to active and dispersed silica supported palladium nanoparticles', CATALYSIS LETTERS: ['204', '214']
# 2008. 'Glycerol transformations on polysaccharide derived mesoporous materials', APPLIED CATALYSIS B-ENVIRONMENTAL: ['157', '162']
# 2008. 'Physico-chemical characterisation of lipids from <i>Mytilus galloprovincialis</i> (L.) and <i>Rapana venosa</i> and their healing properties on skin burns', LIPIDS: ['829', '841']
# 2008. 'ARISTOTLE RULES, OK?', PHILOSOPHY PSYCHIATRY & PSYCHOLOGY: ['265', '268']
# 2008. 'TERESIAN VISIONS', PHILOSOPHY PSYCHIATRY & PSYCHOLOGY: ['273', '276']
# 2008. 'Microwave oxidation of alkenes and alcohols using highly active and stable mesoporous organotitanium silicates', JOURNAL OF MOLECULAR CATALYSIS A-CHEMICAL: ['17', '24']
# 2008. 'Activity of Gallium and Aluminum SBA-15 materials in the Friedel-Crafts alkylation of toluene with benzyl chloride and benzyl alcohol', APPLIED CATALYSIS A-GENERAL: ['148', '155']
# 2008. 'Preparation of Mesoporous Organically Modified Titanium Materials and their Activity in the Oxidation of Cyclohexene', CATALYSIS LETTERS: ['179', '187']
# 2009. 'A COMPREHENSIVE STUDY OF THE AL-MCM-48 SYNTHESIS PARAMETERS AND THEIR EFFECTS OVER THE MESOPOROUS MATERIALS FRAMEWORK', MESOPOROUS MATERIALS: PROPERTIES, PREPARATION AND APPLICATIONS: ['57', '73']
# 2009. 'Microwave-assisted versatile hydrogenation of carbonyl compounds using supported metal nanoparticles', ORGANIC & BIOMOLECULAR CHEMISTRY: ['4821', '4824']
# 2009. 'Selective epoxidation of alkenes using highly active V-SBA-15 materials: microwave <i>vs</i>. conventional heating', JOURNAL OF MATERIALS CHEMISTRY: ['8603', '8609']
# 2009. 'Tuneable porous carbonaceous materials from renewable resources', CHEMICAL SOCIETY REVIEWS: ['3401', '3418']
# 2009. '<i>Para</i>-hydrogen induced polarisation effects in liquid phase hydrogenations catalysed by supported metal nanoparticles', DALTON TRANSACTIONS: ['5074', '5076']
# 2009. 'Efficient aqueous hydrogenation of biomass platform molecules using supported metal nanoparticles on Starbons®', CHEMICAL COMMUNICATIONS: ['5305', '5307']
# 2009. 'Nanotubular self-assembly of <i>n</i>-dodecylamine-TEOS-water-acetonitrile mixtures', CHEMICAL COMMUNICATIONS: ['4581', '4583']

# %% [markdown]
# ### IIb. Other Search Fields

# %% [markdown]
# 1. **SEARCHING THE WOS DATASET USING OTHER FIELDS**: We can search by a variety of fields besides author ("AU") and even combine searches by multiple fields.

# %% [markdown]
# Search fields for the Web of Science Starter API are listed in the [project's README page](https://github.com/clarivate/wosstarter_python_client) but are also copied here:
#
# | Field Tag | Description                                                                                                                                                 |
# |-----------|-------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | TI        | Title of document                                                                                                                                           |
# | IS        | ISSN or ISBN                                                                                                                                                |
# | SO        | Source title - The result contains all source titles within product database (for example, journal titles and/or book titles if the product includes books) |
# | VL        | Volume                                                                                                                                                      |
# | PG        | Page                                                                                                                                                        |
# | CS        | Issue                                                                                                                                                       |
# | PY        | Year Published                                                                                                                                              |
# | AU        | Author                                                                                                                                                      |
# | AI        | Author Identifier                                                                                                                                                      |
# | UT        | Accession Number                                                                                                                                            |
# | DO        | DOI                                                                                                                                                         |
# | DT        | [Document Type](https://webofscience.help.clarivate.com/en-us/Content/document-types.html)                                                                                                                                                         |
# | PMID      | PubMed ID                                                                                                                                                   |
# | OG        | Search for preferred organization names and/or their name variants from the Preferred Organization Index. <p> A search on a preferred organization name returns all records that contain the preferred name and all records that contain its name variants. A search on a name variant returns all records that contain the variant. For example, Cornell Law Sch returns all records that contain Cornell Law Sch in the Addresses field. <p> When searching for organization names that contain a Boolean (AND, NOT, NEAR, and SAME), always enclose the word in quotation marks ( \" \" ). For example: <p>   - OG=(Japan Science \"and\" Technology Agency (JST))      <br>   - OG=(\"Near\" East Univ)         <br> - OG=(\"OR\" Hlth Sci Univ)                           |
# | TS        | Searches for topic terms in the following fields within a document: <p> - Title <br> - Abstract <br> - Author keywords <br> - Keywords Plus
#
#
# Allowed tags are AI, AU, CS, DO, DT, IS, OG, PG, PMID, PY, SO, SUR, TI, TS, UT, VL

# %% [markdown]
# ### IIc. Search by Publication
#
# 1. **SEARCH FOR A SPECIFIC JOURNAL**: You may also, for example, search by journal. We recommend looking up the journal's ISSN number rather than searching by journal title. You can look up a journal's ISSN using the [ISSN Portal](https://portal.issn.org/).
#
# For example, we can search in ***The William and Mary Quarterly*** using its ISSN ("0043-5597"). This query identifies 6,082 results (although it only returns 10\*).
#
# *\*Note: we are keeping the 'limit' at 10 for this experimentation. But, if you want the API to retrieve the maximum allowed number of sources (50), add in "&limit=50" as we did in Step #6 above. If we wanted to retrieve all 6,082 results, for example, we could do so using a loop that first retrieves records 1-50, then 51-100, and so on for 122 times until it finishes. Part III shows how to do so below.*

# %%
SEARCH_QUERY = "IS=0043-5597"
initial_request = requests.get(f'{BASEURL_ST}documents?db=WOS&q={urllib.parse.quote(SEARCH_QUERY)}', headers=HEADERS_ST)
initial_request.json()
# Out:
# {'metadata': {'total': 6218, 'page': 1, 'limit': 10},
#  'hits': [{'uid': 'WOS:A1956CCF2500007',
#    'title': 'ASTROLOGY IN COLONIAL AMERICA - AN EXTENDED QUERY',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'WILLIAM AND MARY QUARTERLY',
#     'publishYear': 1956,
#     'volume': '13',
#     'issue': '4',
#     'pages': {'range': '551-563', 'begin': '551', 'end': '563', 'count': 13}},
#    'names': {'authors': [{'displayName': 'STAHLMAN, WD',
#       'wosStandard': 'STAHLMAN, WD',
#       'researcherId': 'DYG-3714-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CCF2500007&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CCF2500007&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CCF2500007&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CCF2500007&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 6}],
#    'identifiers': {'doi': '10.2307/1917023',
#     'issn': '0043-5597',
#     'pmid': '19943368'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:A1956CCF2400003',
#    'title': 'SCOTT,WILLIAM AND THE ESSEX',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'WILLIAM AND MARY QUARTERLY',
#     'publishYear': 1956,
#     'volume': '13',
#     'issue': '2',
#     'pages': {'range': '169-183', 'begin': '169', 'end': '183', 'count': 15}},
#    'names': {'authors': [{'displayName': 'PERKINS, B',
#       'wosStandard': 'PERKINS, B',
#       'researcherId': 'DMX-5417-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CCF2400003&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CCF2400003&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CCF2400003&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CCF2400003&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 6}],
#    'identifiers': {'doi': '10.2307/1920531', 'issn': '0043-5597'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:A1956CKE5900020',
#    'title': 'BURKE,EDMUND, NEW-YORK AGENT, WITH HIS LETTERS TO THE NEW-YORK ASSEMBLY AND INTIMATE CORRESPONDENCE WITH OHARA,CHARLES, 1761-1776 - HOFFMAN,RJS',
#    'types': ['Review'],
#    'sourceTypes': ['Book Review'],
#    'source': {'sourceTitle': 'WILLIAM AND MARY QUARTERLY',
#     'publishYear': 1956,
#     'volume': '13',
#     'issue': '3',
#     'pages': {'range': '430-432', 'begin': '430', 'end': '432', 'count': 3}},
#    'names': {'authors': [{'displayName': 'ROLLAND, SB',
#       'wosStandard': 'ROLLAND, SB',
#       'researcherId': 'FTM-7234-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CKE5900020&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CKE5900020&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CKE5900020&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 0}],
#    'identifiers': {'issn': '0043-5597', 'eissn': '1933-7698'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:A1956CKE5900021',
#    'title': 'HISTORICAL MEMOIRS FROM 16 MARCH 1763 TO 9 JULY 1776 OF SMITH,WILLIAM, HISTORIAN OF THE PROVINCE OF NEW-YORK, MEMBER OF THE GOVERNORS COUNCIL, AND LAST CHIEF JUSTICE OF THAT PROVINCE UNDER THE CROWN, CHIEF JUSTICE OF QUEBEC - SABINE,WHW',
#    'types': ['Review'],
#    'sourceTypes': ['Book Review'],
#    'source': {'sourceTitle': 'WILLIAM AND MARY QUARTERLY',
#     'publishYear': 1956,
#     'volume': '13',
#     'issue': '3',
#     'pages': {'range': '430-432', 'begin': '430', 'end': '432', 'count': 3}},
#    'names': {'authors': [{'displayName': 'ROLLAND, SB',
#       'wosStandard': 'ROLLAND, SB',
#       'researcherId': 'FTM-7234-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CKE5900021&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CKE5900021&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CKE5900021&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 0}],
#    'identifiers': {'issn': '0043-5597', 'eissn': '1933-7698'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:A1956CCF2500023',
#    'title': 'AUTOBIOGRAPHY OF CARTWRIGHT,PETER - WALLIS,CL',
#    'types': ['Review'],
#    'sourceTypes': ['Book Review'],
#    'source': {'sourceTitle': 'WILLIAM AND MARY QUARTERLY',
#     'publishYear': 1956,
#     'volume': '13',
#     'issue': '4',
#     'pages': {'range': '595-596', 'begin': '595', 'end': '596', 'count': 2}},
#    'names': {'authors': [{'displayName': 'JOHNSON, CA',
#       'wosStandard': 'JOHNSON, CA',
#       'researcherId': 'CYO-7788-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CCF2500023&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CCF2500023&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CCF2500023&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 0}],
#    'identifiers': {'issn': '0043-5597', 'eissn': '1933-7698'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:A1956CCF2500024',
#    'title': 'HOOF BEATS TO HEAVEN - A TRUE CHRONICLE OF THE LIFE AND WILD TIMES OF CARTWRIGHT,PETER, CIRCUIT RIDER - GREENBIE,S, GREENBIE,MB',
#    'types': ['Review'],
#    'sourceTypes': ['Book Review'],
#    'source': {'sourceTitle': 'WILLIAM AND MARY QUARTERLY',
#     'publishYear': 1956,
#     'volume': '13',
#     'issue': '4',
#     'pages': {'range': '595-596', 'begin': '595', 'end': '596', 'count': 2}},
#    'names': {'authors': [{'displayName': 'JOHNSON, CA',
#       'wosStandard': 'JOHNSON, CA',
#       'researcherId': 'CYO-7788-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CCF2500024&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CCF2500024&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CCF2500024&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 0}],
#    'identifiers': {'issn': '0043-5597', 'eissn': '1933-7698'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:A1956CCF2300017',
#    'title': '3 PRESIDENTS AND THEIR BOOKS - THE READING OF JEFFERSON, LINCOLN, ROOSEVELT,FRANKLIN,D. - BESTOR,AE, MEARNS,DC, DANIELS,J',
#    'types': ['Review'],
#    'sourceTypes': ['Book Review'],
#    'source': {'sourceTitle': 'WILLIAM AND MARY QUARTERLY',
#     'publishYear': 1956,
#     'volume': '13',
#     'issue': '1',
#     'pages': {'range': '118-122', 'begin': '118', 'end': '122', 'count': 5}},
#    'names': {'authors': [{'displayName': 'COLBOURN, HT',
#       'wosStandard': 'COLBOURN, HT',
#       'researcherId': 'EQX-9871-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CCF2300017&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CCF2300017&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CCF2300017&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 0}],
#    'identifiers': {'issn': '0043-5597', 'eissn': '1933-7698'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:A1956CCF2500016',
#    'title': 'THE UNIVERSITY IN THE KINGDOM-OF-GUATEMALA - LANNING,JT',
#    'types': ['Review'],
#    'sourceTypes': ['Book Review'],
#    'source': {'sourceTitle': 'WILLIAM AND MARY QUARTERLY',
#     'publishYear': 1956,
#     'volume': '13',
#     'issue': '4',
#     'pages': {'range': '583-584', 'begin': '583', 'end': '584', 'count': 2}},
#    'names': {'authors': [{'displayName': 'BUTTERFIELD, ME',
#       'wosStandard': 'BUTTERFIELD, ME',
#       'researcherId': 'GAC-8036-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CCF2500016&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CCF2500016&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CCF2500016&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 0}],
#    'identifiers': {'issn': '0043-5597', 'eissn': '1933-7698'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:A1956CCF2500015',
#    'title': 'THE FORMATIVE YEARS OF THE MISSIONARY COLLEGE OF SANTA-CRUZ OF QUERETARO, 1683-1733 - MCCLOSKEY,MB',
#    'types': ['Review'],
#    'sourceTypes': ['Book Review'],
#    'source': {'sourceTitle': 'WILLIAM AND MARY QUARTERLY',
#     'publishYear': 1956,
#     'volume': '13',
#     'issue': '4',
#     'pages': {'range': '583-584', 'begin': '583', 'end': '584', 'count': 2}},
#    'names': {'authors': [{'displayName': 'BUTTERFIELD, ME',
#       'wosStandard': 'BUTTERFIELD, ME',
#       'researcherId': 'GAC-8036-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CCF2500015&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CCF2500015&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CCF2500015&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 0}],
#    'identifiers': {'issn': '0043-5597', 'eissn': '1933-7698'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:A1956CCF2300020',
#    'title': 'STUART,GILBERT - FLEXNER,JT',
#    'types': ['Review'],
#    'sourceTypes': ['Book Review'],
#    'source': {'sourceTitle': 'WILLIAM AND MARY QUARTERLY',
#     'publishYear': 1956,
#     'volume': '13',
#     'issue': '1',
#     'pages': {'range': '126-128', 'begin': '126', 'end': '128', 'count': 3}},
#    'names': {'authors': [{'displayName': 'SELLERS, CC',
#       'wosStandard': 'SELLERS, CC',
#       'researcherId': 'DRD-5654-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CCF2300020&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CCF2300020&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1956CCF2300020&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 0}],
#    'identifiers': {'issn': '0043-5597', 'eissn': '1933-7698'},
#    'keywords': {'authorKeywords': []}}]}

# %% [markdown]
# 2. **FILTER BY YEAR(S)**: We may then narrow our search of this one journal by limiting it to a series of years

# %%
SEARCH_QUERY = "IS=0043-5597 AND PY=(2000-2010)"
initial_request = requests.get(f'{BASEURL_ST}documents?db=WOS&q={urllib.parse.quote(SEARCH_QUERY)}', headers=HEADERS_ST)
initial_request.json()
# Out:
# {'metadata': {'total': 1054, 'page': 1, 'limit': 10},
#  'hits': [{'uid': 'WOS:000084741500025',
#    'title': 'The crisis of the standing order: Clerical intellectuals and cultural authority in Massachusetts, 1780-1833',
#    'types': ['Review'],
#    'sourceTypes': ['Book Review'],
#    'source': {'sourceTitle': 'WILLIAM AND MARY QUARTERLY',
#     'publishYear': 2000,
#     'publishMonth': 'JAN',
#     'volume': '57',
#     'issue': '1',
#     'pages': {'range': '244-247', 'begin': '244', 'end': '247', 'count': 4}},
#    'names': {'authors': [{'displayName': 'Andrew, J',
#       'wosStandard': 'Andrew, J',
#       'researcherId': 'EKB-2906-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500025&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500025&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500025&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 0}],
#    'identifiers': {'issn': '0043-5597', 'eissn': '1933-7698'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:000084741500026',
#    'title': 'Sectional nationalism: Massachusetts conservative leaders and the transformation of America, 1815-1836',
#    'types': ['Review'],
#    'sourceTypes': ['Book Review'],
#    'source': {'sourceTitle': 'WILLIAM AND MARY QUARTERLY',
#     'publishYear': 2000,
#     'publishMonth': 'JAN',
#     'volume': '57',
#     'issue': '1',
#     'pages': {'range': '244-247', 'begin': '244', 'end': '247', 'count': 4}},
#    'names': {'authors': [{'displayName': 'Andrew, J',
#       'wosStandard': 'Andrew, J',
#       'researcherId': 'EKB-2906-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500026&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500026&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500026&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 0}],
#    'identifiers': {'issn': '0043-5597', 'eissn': '1933-7698'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:000084741500024',
#    'title': 'The Iroquois in the War of 1812',
#    'types': ['Review'],
#    'sourceTypes': ['Book Review'],
#    'source': {'sourceTitle': 'WILLIAM AND MARY QUARTERLY',
#     'publishYear': 2000,
#     'publishMonth': 'JAN',
#     'volume': '57',
#     'issue': '1',
#     'pages': {'range': '239-243', 'begin': '239', 'end': '243', 'count': 5}},
#    'names': {'authors': [{'displayName': 'Altoff, GT',
#       'wosStandard': 'Altoff, GT',
#       'researcherId': 'CBA-2427-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500024&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500024&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500024&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 0}],
#    'identifiers': {'issn': '0043-5597', 'eissn': '1933-7698'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:000084741500017',
#    'title': 'Benjamin!Franklin and his gods',
#    'types': ['Review'],
#    'sourceTypes': ['Book Review'],
#    'source': {'sourceTitle': 'WILLIAM AND MARY QUARTERLY',
#     'publishYear': 2000,
#     'publishMonth': 'JAN',
#     'volume': '57',
#     'issue': '1',
#     'pages': {'range': '226-228', 'begin': '226', 'end': '228', 'count': 3}},
#    'names': {'authors': [{'displayName': 'Anderson, D',
#       'wosStandard': 'Anderson, D',
#       'researcherId': 'EJR-2050-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500017&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500017&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500017&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 0}],
#    'identifiers': {'issn': '0043-5597', 'eissn': '1933-7698'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:000084741500023',
#    'title': 'Citizen soldiers in the War of 1812',
#    'types': ['Review'],
#    'sourceTypes': ['Book Review'],
#    'source': {'sourceTitle': 'WILLIAM AND MARY QUARTERLY',
#     'publishYear': 2000,
#     'publishMonth': 'JAN',
#     'volume': '57',
#     'issue': '1',
#     'pages': {'range': '239-243', 'begin': '239', 'end': '243', 'count': 5}},
#    'names': {'authors': [{'displayName': 'Altoff, GT',
#       'wosStandard': 'Altoff, GT',
#       'researcherId': 'CBA-2427-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500023&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500023&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500023&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 0}],
#    'identifiers': {'issn': '0043-5597', 'eissn': '1933-7698'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:000084741500018',
#    'title': 'Recovering Benjamin!Franklin: An exploration of a life of science and service',
#    'types': ['Review'],
#    'sourceTypes': ['Book Review'],
#    'source': {'sourceTitle': 'WILLIAM AND MARY QUARTERLY',
#     'publishYear': 2000,
#     'publishMonth': 'JAN',
#     'volume': '57',
#     'issue': '1',
#     'pages': {'range': '226-228', 'begin': '226', 'end': '228', 'count': 3}},
#    'names': {'authors': [{'displayName': 'Anderson, D',
#       'wosStandard': 'Anderson, D',
#       'researcherId': 'CCI-5182-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500018&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500018&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500018&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 0}],
#    'identifiers': {'issn': '0043-5597', 'eissn': '1933-7698'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:000084741500003',
#    'title': 'Soldiers in peace and war: Comparative perspectives on the recruitment of the United States Army, 1802-1815',
#    'types': ['Review'],
#    'sourceTypes': ['Review'],
#    'source': {'sourceTitle': 'WILLIAM AND MARY QUARTERLY',
#     'publishYear': 2000,
#     'publishMonth': 'JAN',
#     'volume': '57',
#     'issue': '1',
#     'pages': {'range': '79-120', 'begin': '79', 'end': '120', 'count': 42}},
#    'names': {'authors': [{'displayName': 'Stagg, JCA',
#       'wosStandard': 'Stagg, JCA',
#       'researcherId': 'GEJ-7539-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500003&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500003&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500003&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500003&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 8}],
#    'identifiers': {'doi': '10.2307/2674359',
#     'issn': '0043-5597',
#     'eissn': '1933-7698'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:000084741500009',
#    'title': "Jefferson's rationalizations",
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'WILLIAM AND MARY QUARTERLY',
#     'publishYear': 2000,
#     'publishMonth': 'JAN',
#     'volume': '57',
#     'issue': '1',
#     'pages': {'range': '183-197', 'begin': '183', 'end': '197', 'count': 15}},
#    'names': {'authors': [{'displayName': 'Burstein, A',
#       'wosStandard': 'Burstein, A',
#       'researcherId': 'ERQ-1357-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500009&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500009&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500009&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500009&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 4}],
#    'identifiers': {'doi': '10.2307/2674365', 'issn': '0043-5597'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:000084741500022',
#    'title': 'A devil of a whipping: The Battle of Cowpens',
#    'types': ['Review'],
#    'sourceTypes': ['Book Review'],
#    'source': {'sourceTitle': 'WILLIAM AND MARY QUARTERLY',
#     'publishYear': 2000,
#     'publishMonth': 'JAN',
#     'volume': '57',
#     'issue': '1',
#     'pages': {'range': '238-239', 'begin': '238', 'end': '239', 'count': 2}},
#    'names': {'authors': [{'displayName': 'Johnson, JM',
#       'wosStandard': 'Johnson, JM',
#       'researcherId': 'FBL-8825-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500022&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500022&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500022&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 0}],
#    'identifiers': {'doi': '10.2307/2674377', 'issn': '0043-5597'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:000084741500021',
#    'title': 'Seriatim: The Supreme Court before John Marshall',
#    'types': ['Review'],
#    'sourceTypes': ['Book Review'],
#    'source': {'sourceTitle': 'WILLIAM AND MARY QUARTERLY',
#     'publishYear': 2000,
#     'publishMonth': 'JAN',
#     'volume': '57',
#     'issue': '1',
#     'pages': {'range': '235-237', 'begin': '235', 'end': '237', 'count': 3}},
#    'names': {'authors': [{'displayName': 'Jay, S',
#       'wosStandard': 'Jay, S',
#       'researcherId': 'CVW-6415-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500021&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500021&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500021&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 0}],
#    'identifiers': {'doi': '10.2307/2674376', 'issn': '0043-5597'},
#    'keywords': {'authorKeywords': []}}]}

# %% [markdown]
# 3. **FILTER BY DOCUMENT TYPE**: We can filter by Document Type (DT) to retrieve only articles (rather than book reviews and other types) from this journal. As you can see, we have reduced the number of results to 222.

# %%
SEARCH_QUERY = "IS=0043-5597 AND PY=(2000-2010) AND DT=Article"
initial_request = requests.get(f'{BASEURL_ST}documents?db=WOS&q={urllib.parse.quote(SEARCH_QUERY)}', headers=HEADERS_ST)

initial_request.json()
# Out:
# {'metadata': {'total': 222, 'page': 1, 'limit': 10},
#  'hits': [{'uid': 'WOS:000084741500009',
#    'title': "Jefferson's rationalizations",
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'WILLIAM AND MARY QUARTERLY',
#     'publishYear': 2000,
#     'publishMonth': 'JAN',
#     'volume': '57',
#     'issue': '1',
#     'pages': {'range': '183-197', 'begin': '183', 'end': '197', 'count': 15}},
#    'names': {'authors': [{'displayName': 'Burstein, A',
#       'wosStandard': 'Burstein, A',
#       'researcherId': 'ERQ-1357-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500009&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500009&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500009&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500009&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 4}],
#    'identifiers': {'doi': '10.2307/2674365', 'issn': '0043-5597'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:000084741500010',
#    'title': "Coincidence or causal connection? The relationship between Thomas Jefferson's visits to Monticello and Sally Hemings's conceptions",
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'WILLIAM AND MARY QUARTERLY',
#     'publishYear': 2000,
#     'publishMonth': 'JAN',
#     'volume': '57',
#     'issue': '1',
#     'pages': {'range': '198-210', 'begin': '198', 'end': '210', 'count': 13}},
#    'names': {'authors': [{'displayName': 'Neiman, FD',
#       'wosStandard': 'Neiman, FD',
#       'researcherId': 'FRK-5128-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500010&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500010&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500010&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500010&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 14}],
#    'identifiers': {'doi': '10.2307/2674366',
#     'issn': '0043-5597',
#     'pmid': '18273997'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:000084741500002',
#    'title': 'Curiosities, commodities, and transplanted bodies in Hans Sloane\'s "Natural History of Jamaica"',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'WILLIAM AND MARY QUARTERLY',
#     'publishYear': 2000,
#     'publishMonth': 'JAN',
#     'volume': '57',
#     'issue': '1',
#     'pages': {'range': '35-78', 'begin': '35', 'end': '78', 'count': 44}},
#    'names': {'authors': [{'displayName': 'Kriz, KD',
#       'wosStandard': 'Kriz, KD',
#       'researcherId': 'DBO-7274-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500002&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500002&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500002&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500002&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 44}],
#    'identifiers': {'doi': '10.2307/2674358', 'issn': '0043-5597'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:000084741500001',
#    'title': '"A world of business to do": William Freeman and the foundations of England\'s commercial empire, 1645-1707',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'WILLIAM AND MARY QUARTERLY',
#     'publishYear': 2000,
#     'publishMonth': 'JAN',
#     'volume': '57',
#     'issue': '1',
#     'pages': {'range': '3-34', 'begin': '3', 'end': '34', 'count': 32}},
#    'names': {'authors': [{'displayName': 'Hancock, D',
#       'wosStandard': 'Hancock, D',
#       'researcherId': 'HYH-6865-2023'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500001&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500001&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500001&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 25}],
#    'identifiers': {'doi': '10.2307/2674357', 'issn': '0043-5597'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:000084741500008',
#    'title': 'Engaging Jefferson: Blacks and the founding father',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'WILLIAM AND MARY QUARTERLY',
#     'publishYear': 2000,
#     'publishMonth': 'JAN',
#     'volume': '57',
#     'issue': '1',
#     'pages': {'range': '171-182', 'begin': '171', 'end': '182', 'count': 12}},
#    'names': {'authors': [{'displayName': 'Gordon-Reed, A',
#       'wosStandard': 'Gordon-Reed, A',
#       'researcherId': 'CTA-2244-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500008&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500008&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500008&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500008&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 16}],
#    'identifiers': {'doi': '10.2307/2674364',
#     'issn': '0043-5597',
#     'pmid': '18273995'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:000084741500006',
#    'title': 'The other end of the telescope: Jefferson through the eyes of his slaves',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'WILLIAM AND MARY QUARTERLY',
#     'publishYear': 2000,
#     'publishMonth': 'JAN',
#     'volume': '57',
#     'issue': '1',
#     'pages': {'range': '139-152', 'begin': '139', 'end': '152', 'count': 14}},
#    'names': {'authors': [{'displayName': 'Stanton, L',
#       'wosStandard': 'Stanton, L',
#       'researcherId': 'DYG-6819-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500006&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500006&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500006&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500006&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 5}],
#    'identifiers': {'doi': '10.2307/2674362', 'issn': '0043-5597'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:000084741500004',
#    'title': 'Thomas Jefferson and Sally Hemings redux - Introduction',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'WILLIAM AND MARY QUARTERLY',
#     'publishYear': 2000,
#     'publishMonth': 'JAN',
#     'volume': '57',
#     'issue': '1',
#     'pages': {'range': '121-124', 'begin': '121', 'end': '124', 'count': 4}},
#    'names': {'authors': [{'displayName': 'Lewis, J',
#       'wosStandard': 'Lewis, J',
#       'researcherId': 'DCS-5242-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500004&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500004&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500004&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500004&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 3}],
#    'identifiers': {'issn': '0043-5597', 'pmid': '18273996'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:000084741500007',
#    'title': 'Every generation is an "independent nation": Colonization, miscegenation, and the fate of Jefferson\'s children',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'WILLIAM AND MARY QUARTERLY',
#     'publishYear': 2000,
#     'publishMonth': 'JAN',
#     'volume': '57',
#     'issue': '1',
#     'pages': {'range': '153-170', 'begin': '153', 'end': '170', 'count': 18}},
#    'names': {'authors': [{'displayName': 'Onuf, PS',
#       'wosStandard': 'Onuf, PS',
#       'researcherId': 'DKR-4010-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500007&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500007&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500007&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500007&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 15}],
#    'identifiers': {'doi': '10.2307/2674363', 'issn': '0043-5597'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:000084741500005',
#    'title': 'Jefferson: Post-DNA',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'WILLIAM AND MARY QUARTERLY',
#     'publishYear': 2000,
#     'publishMonth': 'JAN',
#     'volume': '57',
#     'issue': '1',
#     'pages': {'range': '125-138', 'begin': '125', 'end': '138', 'count': 14}},
#    'names': {'authors': [{'displayName': 'Ellis, JJ',
#       'wosStandard': 'Ellis, JJ',
#       'researcherId': 'CNL-7755-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500005&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500005&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500005&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000084741500005&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 19}],
#    'identifiers': {'doi': '10.2307/2674361',
#     'issn': '0043-5597',
#     'eissn': '1933-7698',
#     'pmid': '18271151'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:000086423100005',
#    'title': 'Acting the manly Christian: White evangelical masculinity in revolutionary Virginia',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'WILLIAM AND MARY QUARTERLY',
#     'publishYear': 2000,
#     'publishMonth': 'APR',
#     'volume': '57',
#     'issue': '2',
#     'pages': {'range': '393-416', 'begin': '393', 'end': '416', 'count': 24}},
#    'names': {'authors': [{'displayName': 'Lindman, JM',
#       'wosStandard': 'Lindman, JM',
#       'researcherId': 'FHK-7496-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000086423100005&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000086423100005&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000086423100005&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000086423100005&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 26}],
#    'identifiers': {'doi': '10.2307/2674480',
#     'issn': '0043-5597',
#     'eissn': '1933-7698'},
#    'keywords': {'authorKeywords': []}}]}

# %% [markdown]
# ### IId. Search by keyword
#
# 1. **TOPIC TERMS SEARCH**: We can also use the Starter API's Topic Terms (TS) field to search for keywords and terms found in a text's Title, Author Keywords, Keywords Plus, and Abstract fields. As noted in the introduction to this notebook, while you can search through these fields, only the Title field is actually returned.
#
# In the example below, we retrieve all works that have the term "humanized landscape" stored in these fields.

# %%
#SEARCH_QUERY = "TS=(ecology AND humanized landscape)"
SEARCH_QUERY = "TS=humanized landscape"
initial_request = requests.get(f'{BASEURL_ST}documents?db=WOS&q={urllib.parse.quote(SEARCH_QUERY)}', headers=HEADERS_ST)
data = initial_request.json()
data['metadata']
# Out:
# {'total': 421, 'page': 1, 'limit': 10}

# %%
data
# Out:
# {'metadata': {'total': 421, 'page': 1, 'limit': 10},
#  'hits': [{'uid': 'WOS:A1978FT34300005',
#    'title': 'LANDSCAPED CAMPUS SITE HUMANIZES LIFE FOR ELDERLY',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'HOSPITALS',
#     'publishYear': 1978,
#     'volume': '52',
#     'issue': '20',
#     'pages': {'range': '75-&', 'begin': '75', 'end': '&', 'count': 0}},
#    'names': {'authors': [{'displayName': 'SMART, JD',
#       'wosStandard': 'SMART, JD',
#       'researcherId': 'FYX-7131-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1978FT34300005&DestLinkType=FullRecord&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 0}],
#    'identifiers': {'issn': '0018-5973', 'pmid': '689636'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:A1992JH71700003',
#    'title': 'THE PRISTINE MYTH - THE LANDSCAPE OF THE AMERICA IN 1492',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'ANNALS OF THE ASSOCIATION OF AMERICAN GEOGRAPHERS',
#     'publishYear': 1992,
#     'publishMonth': 'SEP',
#     'volume': '82',
#     'issue': '3',
#     'pages': {'range': '369-385', 'begin': '369', 'end': '385', 'count': 17}},
#    'names': {'authors': [{'displayName': 'DENEVAN, WM',
#       'wosStandard': 'DENEVAN, WM',
#       'researcherId': 'ESD-1505-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1992JH71700003&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1992JH71700003&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1992JH71700003&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1992JH71700003&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 931}],
#    'identifiers': {'doi': '10.1111/j.1467-8306.1992.tb01965.x',
#     'issn': '0004-5608',
#     'eissn': '1467-8306'},
#    'keywords': {'authorKeywords': ['PRISTINE MYTH',
#      '1492',
#      'COLUMBUS, NATIVE AMERICAN SETTLEMENT AND DEMOGRAPHY',
#      'PREHISTORIC NEW WORLD',
#      'VEGETATION CHANGE',
#      'EARTHWORKS']}},
#   {'uid': 'WOS:A1996UK81200005',
#    'title': 'Landscapes without peasants',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'HOMME',
#     'publishYear': 1996,
#     'publishMonth': 'APR-JUN',
#     'volume': '36',
#     'issue': '138',
#     'pages': {'range': '111-120', 'begin': '111', 'end': '120', 'count': 18}},
#    'names': {'authors': [{'displayName': 'Prado, P',
#       'wosStandard': 'Prado, P',
#       'researcherId': 'IHD-6041-2023'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1996UK81200005&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1996UK81200005&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1996UK81200005&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 0}],
#    'identifiers': {'issn': '0439-4216'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:A1997WD25200006',
#    'title': 'Incremental agroforestry: Enriching Pacific landscapes',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'CONTEMPORARY PACIFIC',
#     'publishYear': 1997,
#     'publishMonth': 'SPR',
#     'volume': '9',
#     'issue': '1',
#     'pages': {'range': '121-148', 'begin': '121', 'end': '148', 'count': 28}},
#    'names': {'authors': [{'displayName': 'Clarke, WC',
#       'wosStandard': 'Clarke, WC',
#       'researcherId': 'HWS-5742-2023'},
#      {'displayName': 'Thaman, RR',
#       'wosStandard': 'Thaman, RR',
#       'researcherId': 'EAS-9162-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1997WD25200006&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1997WD25200006&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1997WD25200006&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:A1997WD25200006&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 12}],
#    'identifiers': {'issn': '1043-898X', 'eissn': '1527-9464'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:000075020300018',
#    'title': 'Autonomous development. Humanizing the landscape: An excursion into radical thinking and practice.',
#    'types': ['Review'],
#    'sourceTypes': ['Book Review'],
#    'source': {'sourceTitle': 'CONTRIBUTIONS TO INDIAN SOCIOLOGY',
#     'publishYear': 1998,
#     'publishMonth': 'JAN-JUN',
#     'volume': '32',
#     'issue': '1',
#     'pages': {'range': '140-140', 'begin': '140', 'end': '140', 'count': 1}},
#    'names': {'authors': [{'displayName': 'Savyasachi',
#       'wosStandard': 'Savyasachi',
#       'researcherId': 'HWM-7416-2023'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000075020300018&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000075020300018&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000075020300018&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 0}],
#    'identifiers': {'doi': '10.1177/006996679803200117',
#     'issn': '0069-9659',
#     'eissn': '0973-0648'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:000075608300011',
#    'title': 'Humanized nature. The meaning of landscape and weather in the English novel from Ann Radcliffe to Thomas Hardy',
#    'types': ['Review'],
#    'sourceTypes': ['Book Review'],
#    'source': {'sourceTitle': 'GERMANISCH-ROMANISCHE MONATSSCHRIFT',
#     'publishYear': 1998,
#     'volume': '48',
#     'issue': '1',
#     'pages': {'range': '120-127', 'begin': '120', 'end': '127', 'count': 8}},
#    'names': {'authors': [{'displayName': 'Wolf, W',
#       'wosStandard': 'Wolf, W',
#       'researcherId': 'EGL-8121-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000075608300011&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000075608300011&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000075608300011&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 0}],
#    'identifiers': {'issn': '0016-8904'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:000075183900005',
#    'title': 'The myth of the humanized landscape: An example from Yosemite National Park',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'NATURAL AREAS JOURNAL',
#     'publishYear': 1998,
#     'publishMonth': 'JUL',
#     'volume': '18',
#     'issue': '3',
#     'pages': {'range': '231-236', 'begin': '231', 'end': '236', 'count': 6}},
#    'names': {'authors': [{'displayName': 'Vale, TR',
#       'wosStandard': 'Vale, TR',
#       'researcherId': 'DZZ-7688-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000075183900005&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000075183900005&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000075183900005&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000075183900005&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 65}],
#    'identifiers': {'issn': '0885-8608'},
#    'keywords': {'authorKeywords': ['natural landscape',
#      'humanized landscape',
#      'Yosemite National Park',
#      'social ideology']}},
#   {'uid': 'WOS:000081973600046',
#    'title': 'Humanized nature. On the significance of landscape and weather in the English novel from Ann Radcliffe to Thomas Hardy',
#    'types': ['Review'],
#    'sourceTypes': ['Book Review'],
#    'source': {'sourceTitle': 'ARCHIV FUR DAS STUDIUM DER NEUEREN SPRACHEN UND LITERATUREN',
#     'publishYear': 1999,
#     'volume': '236',
#     'issue': '1',
#     'pages': {'range': '196-199', 'begin': '196', 'end': '199', 'count': 4}},
#    'names': {'authors': [{'displayName': 'Horatschek, A',
#       'wosStandard': 'Horatschek, A',
#       'researcherId': 'CVL-1550-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000081973600046&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000081973600046&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000081973600046&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 0}],
#    'identifiers': {'issn': '0003-8970'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:000086292600015',
#    'title': 'Nature and culture in environmental ethics',
#    'types': ['Meeting'],
#    'sourceTypes': ['Proceedings Paper'],
#    'source': {'sourceTitle': 'PROCEEDINGS OF THE TWENTIETH WORLD CONGRESS OF PHILOSOPHY, VOL 1',
#     'publishYear': 1999,
#     'pages': {'range': '151-158', 'begin': '151', 'end': '158', 'count': 4}},
#    'names': {'authors': [{'displayName': 'Rolston, H',
#       'wosStandard': 'Rolston, H',
#       'researcherId': 'FWL-6426-2022'}],
#     'bookEditors': [{'displayName': 'Brinkmann, K'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000086292600015&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000086292600015&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000086292600015&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000086292600015&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 6}],
#    'identifiers': {'isbn': '1-889680-05-2'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:000081123600003',
#    'title': 'Henry Ward Ranger and the humanized landscape',
#    'types': ['Review'],
#    'sourceTypes': ['Art Exhibit Review'],
#    'source': {'sourceTitle': 'MAGAZINE ANTIQUES',
#     'publishYear': 1999,
#     'publishMonth': 'JUL',
#     'volume': '156',
#     'issue': '1',
#     'pages': {'range': '24-+', 'begin': '24', 'end': '+', 'count': 0}},
#    'names': {'authors': [{'displayName': 'Ledes, AE',
#       'wosStandard': 'Ledes, AE',
#       'researcherId': 'DCM-8747-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000081123600003&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000081123600003&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=dartrds_jeremy_01&SrcAuth=WosAPI&KeyUT=WOS:000081123600003&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 0}],
#    'identifiers': {'issn': '0161-9284'},
#    'keywords': {'authorKeywords': []}}]}

# %% [markdown]
# ## III. Placing Retrieved Data in a Dataframe and saving to a csv
#
# The Starter API returns query results in the format of [JSON data](https://www.w3schools.com/js/js_json_intro.asp), which is hierarchical in format.
#
# Often, however, researchers will want to place this data in a two-dimensional data table (in Python - these data tables are known as dataframes). This part shows how to transform this returned JSON data into a dataframe.

# %% [markdown]
# ### IIIa. Retrieve 50 or fewer records and place in a dataframe
#
# 1. We will continue with our most recent SEARCH_QUERY. First, let's retrieve the number of records this query found:

# %%
print(f"Our current search query: {SEARCH_QUERY}")
total_records = data.get('metadata', {}).get('total')
print(total_records)
# Out:
# Our current search query: TS=humanized landscape
# 421

# %% [markdown]
# 1b. In a later step, we will work on retrieving all of these records. For the moment, however, let's just request the first 50.

# %%
#50 or less results
datadict = {}
initial_request = requests.get(
        f'{BASEURL_ST}documents?db=WOS&q={SEARCH_QUERY}&limit=50', headers=HEADERS_ST)
data = initial_request.json()
datadict = data
print(f"Total number of records pulled: {len(datadict['hits'])}")
print(f"for the search query: {SEARCH_QUERY}")
uids = set([hit['uid'] for hit in datadict['hits']])
print(f"Total number of unique ids: {len(uids)}")
print(f"Number of requests remaining today: {initial_request.headers['X-RateLimit-Remaining-Day']}.")
# Out:
# Total number of records pulled: 50
# for the search query: TS=humanized landscape
# Total number of unique ids: 50
# Number of requests remaining today: 4947.

# %% [markdown]
# 1c. The code above retrieved the data ("initial_request"), saved it as a json file ("data"), created an empty dictionary ("datadict"), placed the JSON data in this dictionary, and then created a list of unique IDs found in the dictionary ("uids").
#
# Let's examine the results:

# %%
list(uids)
# Out:
# ['WOS:A1997WD25200006',
#  'WOS:000297917200005',
#  'WOS:000239166900006',
#  'WOS:000169881400010',
#  'WOS:000081973600046',
#  'WOS:000280915400009',
#  'WOS:000274206500014',
#  'WOS:000231043700001',
#  'WOS:000275947300124',
#  'WOS:000086006700005',
#  'WOS:000075020300018',
#  'WOS:000270600800009',
#  'WOS:000291370500030',
#  'WOS:000280784600010',
#  'WOS:000436985900009',
#  'WOS:000231927600005',
#  'WOS:000260575400005',
#  'WOS:000280633800009',
#  'WOS:000165903400002',
#  'WOS:000075608300011',
#  'WOS:000243899200008',
#  'WOS:A1978FT34300005',
#  'WOS:000256236000011',
#  'WOS:A1996UK81200005',
#  'WOS:000286419400006',
#  'WOS:000287956600016',
#  'WOS:000300167300002',
#  'WOS:000090103900001',
#  'WOS:000075183900005',
#  'WOS:000296955600003',
#  'WOS:000232979900001',
#  'WOS:000286541400011',
#  'WOS:000186870800010',
#  'WOS:000260514400014',
#  'WOS:000086292600015',
#  'WOS:000257297800007',
#  'WOS:000394684200028',
#  'WOS:A1992JH71700003',
#  'WOS:000245219600015',
#  'WOS:000242239000002',
#  'WOS:000081123600003',
#  'WOS:000264261100006',
#  'WOS:000225009100008',
#  'WOS:000256228200003',
#  'WOS:000210717900003',
#  'WOS:000259447900007',
#  'WOS:000165460300002',
#  'WOS:000180642000010',
#  'WOS:000086068400012',
#  'WOS:000169377400004']

# %% [markdown]
# 1d. Now we can create a function that converts the JSON results (which we have stored in a Python dictionary) into a dataframe.

# %%
def retrieve_all_data(datahits):
    #hits = [hit for hit in data['hits']]
    datalist = []
    for hit in datahits:
        datadict = {}
        datadict['uid'] = hit.get("uid", "")
        datadict['title'] = hit.get("title", "")
        datadict['authors'] = "; ".join([name.get('wosStandard') for name in hit.get("names").get("authors")])
        datadict['researcherIds'] = "; ".join([str(name.get('researcherId')) for name in hit.get("names").get("authors")])
        datadict['pubyear'] = hit.get("source", {}).get("publishYear")
        datadict['source_title'] = hit.get("source", {}).get("sourceTitle")
        datadict['volume'] = hit.get("source", {}).get("volume")
        datadict['page_start'] = hit.get("source", {}).get("pages", {}).get("begin")
        datadict['page_end'] = hit.get("source", {}).get("pages", {}).get("end")
        datadict['page_count'] = hit.get("source", {}).get("pages", {}).get("count")
        identifiers = hit.get("identifiers")
        datadict['doi'] = identifiers.get("doi")
        datadict['issn'] = identifiers.get("issn")
        datadict['eissn'] = identifiers.get("eissn")
        datadict['isbn'] = identifiers.get("isbn")
        citations = hit.get("citations")
        if len(citations) > 0:   #for some reason the citations key stores a dict inside a list
            datadict["citation_counts"] = citations[0].get("count")
         
        datadict['author_keywords'] = "; ".join([kw.lower() for kw in hit.get("keywords").get("authorKeywords")])
        #datadict['keywords_plus'] = hit.get("keywords").get("keywordsPlus")
        links = hit.get("links")
        datadict['record_links'] = links.get("record")
        datadict['citing_links'] = links.get("citingArticles")
        datadict['reference_links'] = links.get("references")
        datadict['related_links'] = links.get("related")
        datalist.append(datadict)
    #print(datalist)
    return(pd.DataFrame(datalist))

# %% [markdown]
# 1e. With this function we can now convert our dictionary ("datadict") into a dataframe.

# %%
df1 = retrieve_all_data(datadict['hits'])
df1.head()
# Out:
#                    uid                                              title  \
# 0  WOS:A1978FT34300005  LANDSCAPED CAMPUS SITE HUMANIZES LIFE FOR ELDERLY
# 1  WOS:A1992JH71700003  THE PRISTINE MYTH - THE LANDSCAPE OF THE AMERI...
# 2  WOS:A1996UK81200005                        Landscapes without peasants
# 3  WOS:A1997WD25200006  Incremental agroforestry: Enriching Pacific la...
# 4  WOS:000075020300018  Autonomous development. Humanizing the landsca...
#
#                   authors                 researcherIds  pubyear  \
# 0               SMART, JD                 FYX-7131-2022     1978
# 1             DENEVAN, WM                 ESD-1505-2022     1992
# 2                Prado, P                 IHD-6041-2023     1996
# 3  Clarke, WC; Thaman, RR  HWS-5742-2023; EAS-9162-2022     1997
# 4              Savyasachi                 HWM-7416-2023     1998
#
#                                         source_title volume page_start  \
# 0                                          HOSPITALS     52         75
# 1  ANNALS OF THE ASSOCIATION OF AMERICAN GEOGRAPHERS     82        369
# 2                                              HOMME     36        111
# 3                               CONTEMPORARY PACIFIC      9        121
# 4                  CONTRIBUTIONS TO INDIAN SOCIOLOGY     32        140
#
#   page_end  page_count                                 doi       issn  \
# 0        &           0                                None  0018-5973
# 1      385          17  10.1111/j.1467-8306.1992.tb01965.x  0004-5608
# 2      120          18                                None  0439-4216
# 3      148          28                                None  1043-898X
# 4      140           1          10.1177/006996679803200117  0069-9659
#
#        eissn  isbn  citation_counts  \
# 0       None  None                0
# 1  1467-8306  None              931
# 2       None  None                0
# 3  1527-9464  None               12
# 4  0973-0648  None                0
#
#                                      author_keywords  \
# 0
# 1  pristine myth; 1492; columbus, native american...
# 2
# 3
# 4
#
#                                         record_links  \
# 0  https://www.webofscience.com/api/gateway?GWVer...
# 1  https://www.webofscience.com/api/gateway?GWVer...
# 2  https://www.webofscience.com/api/gateway?GWVer...
# 3  https://www.webofscience.com/api/gateway?GWVer...
# 4  https://www.webofscience.com/api/gateway?GWVer...
#
#                                         citing_links  \
# 0                                               None
# 1  https://www.webofscience.com/api/gateway?GWVer...
# 2                                               None
# 3  https://www.webofscience.com/api/gateway?GWVer...
# 4                                               None
#
#                                      reference_links  \
# 0                                               None
# 1  https://www.webofscience.com/api/gateway?GWVer...
# 2  https://www.webofscience.com/api/gateway?GWVer...
# 3  https://www.webofscience.com/api/gateway?GWVer...
# 4  https://www.webofscience.com/api/gateway?GWVer...
#
#                                        related_links
# 0                                               None
# 1  https://www.webofscience.com/api/gateway?GWVer...
# 2  https://www.webofscience.com/api/gateway?GWVer...
# 3  https://www.webofscience.com/api/gateway?GWVer...
# 4  https://www.webofscience.com/api/gateway?GWVer...

# %% [markdown]
# 1f. ...and export this dataframe into a csv.

# %%
# write results to csv
df1.to_csv(f"wos_results_{SEARCH_QUERY}_page1only.csv", encoding = 'utf=8')

# %% [markdown]
# ### IIIb. SEND MULTIPLE REQUESTS TO RETRIEVE 50+ RECORDS FROM A QUERY
#
# However, our search query ("TS=humanized landscapes") returned more than 50 results (306 in total).
#
# When a query returns more than 50 records, we need to write a iterative loop that retrieves 50 records at a time.

# %% [markdown]
# 1a. **RETRIEVE RESULTS AND PLACE IN A DICTIONARY**: Create a for loop to retrieve 50 records at a time and assemble the result into one Python dictionary:

# %%
total_records = data['metadata']['total']
print(f"Our current search query: {SEARCH_QUERY} returned {total_records} records.")

requests_required = ((total_records - 1) // 50) + 1  #306 records - 1 = 305 // 50 = 6 + 1 = 7
print(requests_required)
datadict = {}
if requests_required > 1:
    print(f"API requests required to get all data from the query - '{SEARCH_QUERY}': {requests_required}")
for i in range(requests_required):
    subsequent_response = requests.get(
        f'{BASEURL_ST}documents?db=WOS&q={SEARCH_QUERY}&limit=50&page={i+1}', headers=HEADERS_ST)
    data = subsequent_response.json()
    if i == 0:
        print(data['metadata'])
        datadict = data
    else:
        datadict['hits'].extend(data['hits'])
    print(f"**Pulling from Page {i+1} of {requests_required}**")
print(f"Total number of records pulled: {len(datadict['hits'])}")
uids = set([hit['uid'] for hit in datadict['hits']])
print(f"Total number of unique ids: {len(uids)}")
print(f"Number of requests remaining today: {subsequent_response.headers['X-RateLimit-Remaining-Day']}.")
# Out:
# Our current search query: TS=humanized landscape returned 421 records.
# 9
# API requests required to get all data from the query - 'TS=humanized landscape': 9
# {'total': 421, 'page': 1, 'limit': 50}
# **Pulling from Page 1 of 9**
# **Pulling from Page 2 of 9**
# **Pulling from Page 3 of 9**
# **Pulling from Page 4 of 9**
# **Pulling from Page 5 of 9**
# **Pulling from Page 6 of 9**
# **Pulling from Page 7 of 9**
# **Pulling from Page 8 of 9**
# **Pulling from Page 9 of 9**
# Total number of records pulled: 421
# Total number of unique ids: 421
# Number of requests remaining today: 4938.

# %% [markdown]
# 1b. **TRANSFORM DICTIONARY INTO A DATAFRAME**: Next, we can transform the dictionary into a dataframe:

# %%
df_all = retrieve_all_data(datadict['hits'])
df_all.head()
# Out:
#                    uid                                              title  \
# 0  WOS:A1978FT34300005  LANDSCAPED CAMPUS SITE HUMANIZES LIFE FOR ELDERLY
# 1  WOS:A1992JH71700003  THE PRISTINE MYTH - THE LANDSCAPE OF THE AMERI...
# 2  WOS:A1996UK81200005                        Landscapes without peasants
# 3  WOS:A1997WD25200006  Incremental agroforestry: Enriching Pacific la...
# 4  WOS:000075020300018  Autonomous development. Humanizing the landsca...
#
#                   authors                 researcherIds  pubyear  \
# 0               SMART, JD                 FYX-7131-2022     1978
# 1             DENEVAN, WM                 ESD-1505-2022     1992
# 2                Prado, P                 IHD-6041-2023     1996
# 3  Clarke, WC; Thaman, RR  HWS-5742-2023; EAS-9162-2022     1997
# 4              Savyasachi                 HWM-7416-2023     1998
#
#                                         source_title volume page_start  \
# 0                                          HOSPITALS     52         75
# 1  ANNALS OF THE ASSOCIATION OF AMERICAN GEOGRAPHERS     82        369
# 2                                              HOMME     36        111
# 3                               CONTEMPORARY PACIFIC      9        121
# 4                  CONTRIBUTIONS TO INDIAN SOCIOLOGY     32        140
#
#   page_end  page_count                                 doi       issn  \
# 0        &           0                                None  0018-5973
# 1      385          17  10.1111/j.1467-8306.1992.tb01965.x  0004-5608
# 2      120          18                                None  0439-4216
# 3      148          28                                None  1043-898X
# 4      140           1          10.1177/006996679803200117  0069-9659
#
#        eissn  isbn  citation_counts  \
# 0       None  None                0
# 1  1467-8306  None              931
# 2       None  None                0
# 3  1527-9464  None               12
# 4  0973-0648  None                0
#
#                                      author_keywords  \
# 0
# 1  pristine myth; 1492; columbus, native american...
# 2
# 3
# 4
#
#                                         record_links  \
# 0  https://www.webofscience.com/api/gateway?GWVer...
# 1  https://www.webofscience.com/api/gateway?GWVer...
# 2  https://www.webofscience.com/api/gateway?GWVer...
# 3  https://www.webofscience.com/api/gateway?GWVer...
# 4  https://www.webofscience.com/api/gateway?GWVer...
#
#                                         citing_links  \
# 0                                               None
# 1  https://www.webofscience.com/api/gateway?GWVer...
# 2                                               None
# 3  https://www.webofscience.com/api/gateway?GWVer...
# 4                                               None
#
#                                      reference_links  \
# 0                                               None
# 1  https://www.webofscience.com/api/gateway?GWVer...
# 2  https://www.webofscience.com/api/gateway?GWVer...
# 3  https://www.webofscience.com/api/gateway?GWVer...
# 4  https://www.webofscience.com/api/gateway?GWVer...
#
#                                        related_links
# 0                                               None
# 1  https://www.webofscience.com/api/gateway?GWVer...
# 2  https://www.webofscience.com/api/gateway?GWVer...
# 3  https://www.webofscience.com/api/gateway?GWVer...
# 4  https://www.webofscience.com/api/gateway?GWVer...

# %% [markdown]
# 1c. **EXPORT THE RESULTS DATAFRAME INTO A CSV**:

# %%
df_all.to_csv(f"wos_results_{SEARCH_QUERY}_all.csv", encoding = 'utf=8')

# %% [markdown]
# That's it. We can review the number of requests we have remaining for today:

# %%
subsequent_response.headers['X-RateLimit-Remaining-Day']
# Out:
# '4938'
