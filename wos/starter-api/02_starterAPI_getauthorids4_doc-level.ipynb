# %% [markdown]
# # Using WoS Starter API to retrieve author information
#
# In order to run the code below you will need to request and acquire an API key for the Web of Science Starter API.
#
# See this repository's [ReadME.md](../../README.md) for more information on saving and retrieving your API Key from an .env file.

# %% [markdown]
# This notebook will demonstrate how to take a list of authors and retrieve information about their publication record using the Starter API.

# %% [markdown]
# ### I. Getting Started
#
# 1. **Import all necessary packages.** To first install these packages to a local environment, you can use the requirements.txt file. Open a terminal / command prompt within this project's folder and type:
#
# ```
# pip install -r requirements.txt
# ```
#
# Then you can import these packages.

# %%
import requests
import time
import os
import urllib.parse
import pandas as pd
import random
from bs4 import BeautifulSoup   #for parsing xml and html
from random import randint  
from dotenv import load_dotenv 
load_dotenv()
# Out:
# True

# %% [markdown]
# 2. Store the API link to memory and retrieve your API key.

# %%
BASEURL_ST = 'https://api.clarivate.com/apis/wos-starter/v1/'
HEADERS_ST = {'X-APIKey': os.getenv("APIKEY")}

# %%
import Levenshtein as lev
# lev_wts = (1, 0, 1)

# %%
#authordf = pd.read_csv("../data/chor_davin_authors.csv", encoding = 'utf-8', usecols=[0,1,2,3,4,5], nrows=10000)
authordf = pd.read_csv("../data/sample_author-names-and-insts.csv", encoding = 'utf-8')
authordf.head()
# Out:
#    University Name             Name             Position
# 0  Harvard College  Alberto Alesina            Professor
# 1  Harvard College   Isaiah Andrews            Professor
# 2  Harvard College       Pol Antràs            Professor
# 3  Harvard College  Robert J. Barro            Professor
# 4  Harvard College      Emily Breza  Assistant Professor

# %%
#authordf = authordf.iloc[:, 0:6]
print(authordf.shape)
authordf = authordf.dropna(how="all")
# authordf["Ranking"] = authordf["Ranking"].ffill()
# authordf['Ranking'] = authordf['Ranking'].astype(int)
#authordf["University Name"] = authordf["University Name"].ffill()
#authordf = authordf.astype({"Ranking": str, "University Name": str})

print(authordf.shape)
authordf = authordf.fillna("")
authordf.head()
# Out:
# (107, 3)
# (107, 3)
#    University Name             Name             Position
# 0  Harvard College  Alberto Alesina            Professor
# 1  Harvard College   Isaiah Andrews            Professor
# 2  Harvard College       Pol Antràs            Professor
# 3  Harvard College  Robert J. Barro            Professor
# 4  Harvard College      Emily Breza  Assistant Professor

# %% [markdown]
# ### Convert First M. Last Suffix to Last FM
#
# The Starter API searches by authors in the format "LASTNAME, FIRST_INIT."
#
# So, for the table above, we need to convert an auther named "Alex Brown" into "Brown, A." The following cells defines a function that does just that, and the cell after that applies the results to four new columns for our data frame, lastname (i.e. "Brown"), firstname ("Alex"), first initial ("A.), and finally the reordered_name ("Brown, A.").

# %%
def convert_name_first2last_to_last_fminits(orig_name: str):
    if orig_name == "":
        return "", "", "", "", ""
    comma_split = orig_name.split(", ")
    if len(comma_split) > 1:
        suffix = comma_split[-1]
    else:
        suffix = ""
    name = comma_split[0]
    name_parts = name.split()
    last_name = name_parts.pop(-1)
    first_names = ' '.join(name_parts)
    first_inits = ''.join([part[0] for part in name_parts])
    #reordered_name = last_name + " " + first_names + " " + suffix
    #reordered_shortname = last_name + " " + first_inits
    reordered_shortname2 = last_name + ", " + first_inits
    return last_name, first_names, first_inits, suffix, reordered_shortname2

# %%
authordf["lastname"], authordf["firstnames"], authordf["firstinits"], authordf["suffix"], authordf["reordered_name"] = \
    zip(*authordf["Name"].apply(convert_name_first2last_to_last_fminits))
authordf.head()
# Out:
#    University Name             Name             Position lastname firstnames  \
# 0  Harvard College  Alberto Alesina            Professor  Alesina    Alberto
# 1  Harvard College   Isaiah Andrews            Professor  Andrews     Isaiah
# 2  Harvard College       Pol Antràs            Professor   Antràs        Pol
# 3  Harvard College  Robert J. Barro            Professor    Barro  Robert J.
# 4  Harvard College      Emily Breza  Assistant Professor    Breza      Emily
#
#   firstinits suffix reordered_name
# 0          A            Alesina, A
# 1          I            Andrews, I
# 2          P             Antràs, P
# 3         RJ             Barro, RJ
# 4          E              Breza, E

# %% [markdown]
# ## Apply to dataframe of multiple authors
#
# The following functions - **get_author_metadata()** and **get_author_info()** - reads in a column of author names from a dataframe,
# then searches the WoS database one author at a time returning author and document
# information for all documents written by authors that match the search name.
#
# Note, since authors are searched by last name and first initial (I.e. "Brown, A."),
# many author searches will return multiple matches. Parsing author searches that retrieve many
# author match candidates may take more time than doing a manual search for the author on the WoS
# online database. For this reason, the **get_author_metadata** does not retrieve results for
# any author that returns more than 10 pages of results (or 500 total documents).

# %%
#def get_author_info(row: pd.Series, authorname: str, page: int):
def get_author_info(authorname: str, page: int):
    """
    This functions reads in a string with an author's name and an integer representing the
    page number we want the Starter API to call (limit: 50 records at a time, so item number 51 will be on page 2)

    It then places the author's name into a search query and retrieves the *n* page of the document results
    returned for this search query.
    
    """
    
    print("\n***Searching for:", authorname)
    SEARCH_QUERY = f"AU={authorname}"
    request = requests.get(f'{BASEURL_ST}documents?db=WOS&q={urllib.parse.quote(SEARCH_QUERY)}&limit=50&page={page}', headers=HEADERS_ST)
    data = request.json()
    #id_dict = {}
    doclist = []
    hits = [hit for hit in data['hits']]
    for hit in hits:
        try:
            authors = hit['names']['authors']
            short_names = [au['wosStandard'] for au in authors]
            short_names_lower = [name.lower() for name in short_names]
            ids = [au['researcherId'] if 'researcherId' in au.keys() else '' for au in authors]
            lev_scores = [lev.distance(authorname.lower(), name, weights = lev_wts) for name in short_names_lower]
            min_idx = lev_scores.index(min(lev_scores))
            if lev_scores[min_idx] > 2:
                print("no close match:", short_names[min_idx])
                # return something or set some value??
                continue
            #use min idx to get name and id
            tgt_shortname = short_names[min_idx]
            tgt_id = ids[min_idx]
        except KeyError:
            print("missing authors:", authorname, hit['uid'])
            continue
        keywords = hit['keywords']['authorKeywords']
        if "sourceTitle" in hit['source'].keys():
            so_title = hit['source']['sourceTitle']
        else:
            so_title = []
        if "publishYear" in hit['source'].keys():
            pubyear = [hit['source']['publishYear']]
        else:
            pubyear = []
        doc_uid = hit['uid']
        if 'doi' in hit['identifiers'].keys():
            doi = hit['identifiers']['doi']
        else:
            doi = ""
        if 'issn' in hit['identifiers'].keys():
            issn = hit['identifiers']['issn']
        else:
            issn = ""
        if 'eissn' in hit['identifiers'].keys():
            eissn = hit['identifiers']['eissn']
        else:
            eissn = ""
        citedby_count = hit['citations'][0]['count']
        doclist.append([tgt_shortname, tgt_id, 
                        doc_uid, doi, issn, eissn,
                        so_title, keywords, pubyear, 
                        citedby_count])
    
    return(doclist)

# %%
#get_author_info(authorname="Fryer, RG", page=1)

# %%
def get_author_metadata(row:pd.Series, colname:str):
    """
    Reads in dataframe with one column with author names written in the form of "LastName, FirstInits"
    Uses Starter API to search for authors with this name
    Retrieve author info for potential matching authors
    Also retrieves document ids for documents written by these authors
    """
    print(row)
    print(row[colname])
    authorname = row[colname]
    SEARCH_QUERY = f"AU={authorname}"
    initial_request = requests.get(f'{BASEURL_ST}documents?db=WOS&q={urllib.parse.quote(SEARCH_QUERY)}&limit=10', headers=HEADERS_ST)
    data = initial_request.json()
    try:
        num_results = int(data['metadata']['total'])
        num_pages = 1 + (num_results -1)// 50
    except KeyError:
        print("no metadata for match! - ", authorname, "\n")
        return [], True
    try:
        hits = [hit for hit in data['hits']]
    except KeyError:
        print("##no metadata for match2! - ", num_results, ":",    authorname, "\n")
        return [], True
    doclist = []
    if num_pages <= 1:
        doclist = get_author_info(authorname, page=1)
    elif num_pages > 10:
        #row['too_many_matches'] = "yes"
        print("TOO MANY MATCHES:", authorname, "\n")
        #return(row)
        return [], True
    else:
        print("multiple pages for: ", authorname, "pages = ", num_pages)
        for i in range(1, num_pages + 1):
            doclist.extend(get_author_info(authorname, i))
    print("***doclist***:", doclist)
    #newdoclist = []
    #for doc in doclist:
    #    newdoclist.append(row + doc)
    #return newdoclist
    return doclist, False

# %% [markdown]
# Divide dataframe with author names into lists of length *n*

# %%
numauthors = len(authordf)
print(numauthors)
n = 50
num_iterations = numauthors // n
print(num_iterations)
# Out:
# 107
# 2

# %%
for i in range(0, num_iterations + 1):
    startidx = i * 50
    endidx = startidx + 50
    #startidx = 0
    #endidx = 3
    subdf = authordf.iloc[startidx:endidx].copy()
    subdf["doclists"], subdf['toomany_orno_matches'] = \
       zip(*subdf.apply(lambda x: get_author_metadata(x, "reordered_name"), axis=1))
    #authordf.loc[startidx: endidx, "doclists"] = authordf.iloc[startidx:endidx].apply(lambda x: get_author_metadata(x, "reordered_name"), axis=1)
    docdf = subdf.explode("doclists")
    docdf['doclists'] = docdf['doclists'].apply(lambda d: d if isinstance(d, list) else [])
    #docdf['doclists'] = docdf['doclists'].fillna("").apply(list)
    docdf[["match_name", "resID", "doc_uid", "doc_doi", "doc_issn",
           "doc_eissn", "so_title", "au_keywords", "pubyear", "citedby_count"]] =\
           pd.DataFrame(docdf.doclists.tolist(), index=docdf.index)
    docdf.loc[: , "pubyear"] = docdf.loc[: , "pubyear"].str[0]
    docdf.to_csv(f"../data/docdata_{startidx}-{endidx}.csv", encoding='utf-8')   
    #df = authordf.iloc[startidx: endidx].apply(lambda x: get_author_metadata(x, "reordered_name"), axis=1)
    #authordf.to_csv(f"data/authordata_{startidx}-{endidx}.csv", encoding='utf-8')
# Out:
# University Name    Harvard College
# Name               Alberto Alesina
# Position                 Professor
# lastname                   Alesina
# firstnames                 Alberto
# firstinits                       A
# suffix
# reordered_name          Alesina, A
# Name: 0, dtype: object
# Alesina, A
# multiple pages for:  Alesina, A pages =  3
#
# ***Searching for: Alesina, A
#
# ***Searching for: Alesina, A
#
# ***Searching for: Alesina, A
# ***doclist***: [['ALESINA, A', 'CBE-0396-2022', 'WOS:A1979GV96200029', '', '0002-9939', '', 'PROCEEDINGS OF THE AMERICAN MATHEMATICAL SOCIETY', [], [1979], 0], ['ALESINA, A', 'CBE-0396-2022', 'WOS:A
['ALESINA, A', 'EMJ-5429-2022', 'WOS:A1993LB05700001', '10.2307/2077833', '0022-2879', '', 'JOURNAL OF MONEY CREDIT AND BANKING', [], [1993], 678], ['ALESINA, A', 'EMJ-5429-2022', 'WOS:A1994NQ07100006', '10.2307/2118470', '0033-5533' ...
# University Name    Harvard College
# Name                Isaiah Andrews
# Position                 Professor
# lastname                   Andrews
# firstnames                  Isaiah
# firstinits                       I
# suffix
# reordered_name          Andrews, I
# Name: 1, dtype: object
# Andrews, I
# multiple pages for:  Andrews, I pages =  5
#
# ***Searching for: Andrews, I
#
# ***Searching for: Andrews, I
#
# ***Searching for: Andrews, I
#
# ***Searching for: Andrews, I
#
# ***Searching for: Andrews, I
# no close match: Spear, A
# no close match: Haws, JK
# no close match: Price, M
# no close match: Large, SI
# no close match: Palma, MAM
# no close match: Thakur, H
# no close match: Dosta, P
# no close match: Ngan, P
# no close match: Dove, CJ
# no close match: Bond, N
# no close match: Lee, JY
# ***doclist***: [['ANDREWS, IR', 'CDG-3825-2022', 'WOS:A1963CLF5400004', '10.1111/j.1468-232X.1963.tb00807.x', '0019-8676', '', 'INDUSTRIAL RELATIONS', [], [1963], 57], ['ANDREWS, IC', 'CDK-8782-2022', 'WOS:A19644215A00005', '10.1097/00000542-196407000-00016', '0003-3022', '1528-1175', 'ANESTHESIOLOGY', [], [1964], 5], ['ANDREWS, I', 'ELB-5934-2022', 'WOS:A19656592400019', '10.1002/pssb.19650100120', '0031-8957', '', 'PHYSICA STATUS SOLIDI', [], [1965], 32], ['ANDREWS, I', 'ELB-5934-2022', 'WOS:A19667800600045', '10.1002/pssb.19660150246', '0031-8957', '', 'PHYSICA STATUS SOLIDI', [], [1966], 3], ['ANDREWS, IC', 'CDK-8782-2022', 'WOS:A19667360200024', '10.1097/00000542-196603000-00026', '0003-3022', '', 'ANESTHESIOLOGY', [], [1966], 0], ['ANDREWS, IR', 'CDG-3825-2022', 'WOS:A19679024400007', '10.1037/h0024242', '0021-9010', '', 'JOURNAL OF APPLIED PSYCHOLOGY', [], [1967], 68], ['ANDREWS, IM', 'ELB-5934-2022', 'WOS:A19679207900010', '', '0031-4005', '1098-4275', 'PEDIATRICS', [], [1967], 54], ['ANDREWS, IR', 'CDG-3825-2022', 'WOS:A1970G159100004', '10.1016/0030-5073(70)90020-6', '0030-5073', '', 'ORGANIZATIONAL BEHAVIOR AND HUMAN PERFORMANCE', [], [1970], 15], ['ANDREWS, IR', 'CDG-3825-2022', 'WOS:A1970Y295700019', '10.2307/3150302', '0022-2437', '', 'JOURNAL OF MARKETING RESEARCH', [], [1970], 4], ['ANDREWS, IR', 'CDG-3825-2022', 'WOS:A1971L103200013', '10.1037/h0031917', '0022-3514', '', 'JOURNAL OF PERSONALITY AND SOCIAL PSYCHOLOGY', [], [1971], 15], ['ANDREWS, IR', 'CDG-3825-2022', 'WOS:A1971Y239300017', '10.3758/BF03335563', '', '', 'PSYCHONOMIC SCIENCE', [], [1971], 7], ['ANDREWS, IR', 'CDG-3825-2022', 'WOS:A1971I546700014', '10.1037/h0030636', '0021-9010', '', 'JOURNAL OF APPLIED PSYCHOLOGY', [], [1971], 37], ['ANDREWS, IR', 'CDG-3825-2022', 'WOS:A1971I546700003', '10.1037/h0030634', '0021-9010', '1939-1854', 'JOURNAL OF APPLIED PSYCHOLOGY', [], [1971], 34], ['ANDREWS, IC', 'CDK-8782-2022', 'WOS:A1972N806900007', '', '0028-7628', '', 'NEW YORK STATE JOURNAL OF MEDICINE', [], [1972], 0], ['ANDREWS, IC', 'CDK-8782-2022', 'WOS:A1972M648600010', '', '0028-7628', '', 'NEW YORK STATE JOURNAL OF MEDICINE', [], [1972], 0], ['ANDREWS, IR', 'CDG-3825-2022', 'WOS:A1973Q528800008', '10.1037/h0035409', '0021-9010', '', 'JOURNAL OF APPLIED PSYCHOLOGY', [], [1973], 38], ['ANDREWS, IR', 'CDG-3825-2022', 'WOS:A1973R894600003', '10.1177/002188637300900606', '0021-8863', '', 'JOURNAL OF APPLIED BEHAVIORAL SCIENCE', [], [1973], 40], ['ANDREWS, I', 'ELB-5934-2022', 'WOS:A1974T757100003', '10.1049/ep.1974.0424', '0013-5127', '', 'ELECTRONICS AND POWER', [], [1974], 0], ['ANDREWS, IR', 'CDG-3825-2022', 'WOS:A1974S101100027', '10.1037/h0035818', '0021-9010', '', 'JOURNAL OF APPLIED PSYCHOLOGY', [], [1974], 6], ['ANDREWS, IM', 'ELB-5934-2022', 'WOS:A1975AJ93200073', '10.7567/JJAPS.14S1.373', '0021-4922', '', 'JAPANESE JOURNAL OF APPLIED PHYSICS', [], [1975], 0], ['ANDREWS, IR', 'CDG-3825-2022', 'WOS:A1975AB78400010', '10.1037/0013335', '0010-7549', '', 'CONTEMPORARY PSYCHOLOGY', [], [1975], 0], ['ANDREWS, IM', 'ELB-5934-2022', 'WOS:A1976BS27400011', '10.1147/rd.203.0285', '0018-8646', '', 'IBM JOURNAL OF RESEARCH AND DEVELOPMENT', [], [1976], 0], ['ANDREWS, IC', 'CDK-8782-2022', 'WOS:A1977EF11000007', '', '0011-393X', '', 'CURRENT THERAPEUTIC RESEARCH-CLINICAL AND EXPERIMENTAL', [], [1977], 7], ['ANDREWS, I', 'CBS-6678-2022', 'WOS:A1980LA17700001', '10.1515/iral.1980.18.1-4.273', '0019-042X', '', 'IRAL-INTERNATIONAL REVIEW OF APPLIED LINGUISTICS IN LANGUAGE TEACHING', [], [1980], 3], ['ANDREWS, I', 'CBS-6678-2022', 'WOS:A1980KP64400015', '', '0019-042X', '', 'IRAL-INTERNATIONAL REVIEW OF APPLIED LINGUISTICS IN LANGUAGE TEACHING', [], [1980], 1], ['ANDREWS, I', 'EKF-6106-2022', 'WOS:A1981MT07500061', '10.1086/352900', '0021-1753', '', 'ISIS', [], [1981], 0], ['ANDREWS, I', 'CBS-6678-2022', 'WOS:A1981MN93500009', '', '0019-042X', '', 'IRAL-INTERNATIONAL REVIEW OF APPLIED LINGUISTICS IN LANGUAGE TEACHING', [], [1981], 0], ['ANDREWS, I', 'CBS-6678-20 ...
# University Name    Harvard College
# Name                    Pol Antràs
# Position                 Professor
# lastname                    Antràs
# firstnames                     Pol
# firstinits                       P
# suffix
# reordered_name           Antràs, P
# Name: 2, dtype: object
# Antràs, P
#
# ***Searching for: Antràs, P
# ***doclist***: [['Antràs, P', 'CDH-5210-2022', 'WOS:000181481300003', '10.1016/S0014-4983(02)00024-4', '0014-4983', '1090-2457', 'EXPLORATIONS IN ECONOMIC HISTORY', ['British industrial revolution', 'productivity growth', 'dual measurement of productivity'], [2003], 48], ['Antràs, P', 'ELB-5271-2022', 'WOS:000186624900006', '10.1162/003355303322552829', '0033-5533', '1531-4650', 'QUARTERLY JOURNAL OF ECONOMICS', [], [2003], 488], ['Antràs, P', 'ELB-5271-2022', 'WOS:000221807200002', '10.1086/383099', '0022-3808', '', 'JOURNAL OF POLITICAL ECONOMY', [], [2004], 771], ['Antràs, P', 'ELB-5271-2022', 'WOS:000233172500005', '10.1257/000282805774669871', '0002-8282', '', 'AMERICAN ECONOMIC REVIEW', [], [2005], 31], ['Antràs, P', 'ELB-5271-2022', 'WOS:000233213000008', '10.1257/0002828054825600', '0002-8282', '', 'AMERICAN ECONOMIC REVIEW', [], [2005], 169], ['Antràs, P', 'ELB-5271-2022', 'WOS:000236766000002', '', '0033-5533', '1531-4650', 'QUARTERLY JOURNAL OF ECONOMICS', [], [2006], 192], ['Antràs, P', 'ELB-5271-2022', 'WOS:000248070600017', '10.1257/aer.97.3.916', '0002-8282', '1944-7981', 'AMERICAN ECONOMIC REVIEW', [], [2007], 207], ['Antras, P', 'ELB-5271-2022', 'WOS:000248987000001', '10.1016/j.jinteco.2006.12.003', '0022-1996', '', 'JOURNAL OF INTERNATIONAL ECONOMICS', ['bargaining', 'trade agreements', 'regionalism', 'multilateralism', 'coalition externalities'], [2007], 89], ['Antràs, P', 'ELB-5271-2022', 'WOS:000273630000004', '10.1146/annurev.economics.050708.143257', '1941-1383', '', 'ANNUAL REVIEW OF ECONOMICS', ['technology', 'fragmentation', 'wage inequality matching', 'internalization', 'contractual frictions', 'comparative advantage', 'outsourcing', 'offshoring'], [2009], 92], ['Antràs, P', 'ELB-5271-2022', 'WOS:000269692900007', '10.1162/qjec.2009.124.3.1171', '0033-5533', '1531-4650', 'QUARTERLY JOURNAL OF ECONOMICS', [], [2009], 130], ['Antràs, P', 'ELB-5271-2022', 'WOS:000268904400004', '10.1086/605583', '0022-3808', '1537-534X', 'JOURNAL OF POLITICAL ECONOMY', [], [2009], 120], ['Antràs, P', 'ELB-5271-2022', 'WOS:000276460500012', '10.1111/j.1542-4774.2010.tb00515.x', '1542-4766', '', 'JOURNAL OF THE EUROPEAN ECONOMIC ASSOCIATION', [], [2010], 12], ['Antràs, P', 'ELB-5271-2022', 'WOS:000278389300082', '10.1257/aer.100.2.424', '0002-8282', '', 'AMERICAN ECONOMIC REVIEW', [], [2010], 20], ['Antrás, P', 'ELB-5271-2022', 'WOS:000282144600005', '', '0022-0515', '', 'JOURNAL OF ECONOMIC LITERATURE', [], [2010], 0], ['Antràs, P', 'CDH-5210-2022', 'WOS:000292667800001', '10.1016/j.jinteco.2011.03.011', '0022-1996', '1873-0353', 'JOURNAL OF INTERNATIONAL ECONOMICS', ['Foreign influence', 'Externalities', 'Welfare', 'Electoral competition', 'Balance of power', 'Import tariffs'], [2011], 26], ['Antràs, P', 'ELB-5271-2022', 'WOS:000294556700006', '10.1093/qje/qjr019', '0033-5533', '1531-4650', 'QUARTERLY JOURNAL OF ECONOMICS', ['F10', 'F15', 'D20', 'D30', 'O10'], [2011], 91], ['Antràs, P', 'ELB-5271-2022', 'WOS:000304262000072', '10.1257/aer.102.3.412', '0002-8282', '', 'AMERICAN ECONOMIC REVIEW', [], [2012], 507], ['Antràs, P', 'ELB-5271-2022', 'WOS:000304262000082', '10.1257/aer.102.3.470', '0002-8282', '', 'AMERICAN ECONOMIC REVIEW', [], [2012], 32], ['Antràs, P', 'ELB-5271-2022', 'WOS:000312093000002', '10.1257/aer.102.7.3140', '0002-8282', '', 'AMERICAN ECONOMIC REVIEW', [], [2012], 168], ['Antràs, P', 'ELB-5271-2022', 'WOS:000326878900001', '10.3982/ECTA10813', '0012-9682', '1468-0262', 'ECONOMETRICA', ['Property-rights theory', 'contractual frictions', 'sequential production', 'downstreamness', 'intrafirm trade'], [2013], 392], ['Antràs, P', 'ELB-5271-2022', 'WOS:000342836400004', '10.1016/B978-0-444-54314-1.00002-1', '0169-7218', '', 'HANDBOOK OF INTERNATIONAL ECONOMICS, VOL 4', ['Multinationals', 'Foreign direct investment', 'Vertical FDI', 'Horizontal FDI', 'Complex FDI', 'Internalization', 'Offshoring', 'Outsourcing', 'Related party trade', 'Cross-border acquisitions', 'Greenfield FDI'], [2014], 190], ['Antràs, ...
'0022-3808', '', 'JOURNAL OF POLITICAL ECONOMY', [], [1979], 1262], ['BARRO, RJ' ...
# University Name        Harvard College
# Name                       Emily Breza
# Position           Assistant Professor
# lastname                         Breza
# firstnames                       Emily
# firstinits                           E
# suffix
# reordered_name                Breza, E
# Name: 4, dtype: object
# Breza, E
#
# ***Searching for: Breza, E
# ***doclist***: [['Breza, E', 'FZR-2442-2022', 'WOS:000392309300008', '10.1111/jofi.12439', '0022-1082', '1540-6261', 'JOURNAL OF FINANCE', [], [2017], 58], ['Breza, E', 'FZR-2442-2022', 'WOS:000434468600084', '10.1257/pandp.20181011', '2574-0768', '2574-0776', 'AEA PAPERS AND PROCEEDINGS', [], [2018], 2], ['Breza, E', 'FZR-2442-2022', 'WOS:000435871300002', '10.1093/qje/qjx041', '0033-5533', '1531-4650', 'QUARTERLY JOURNAL OF ECONOMICS', [], [2018], 182], ['Breza, E', 'FZR-2442-2022', 'WOS:000451282800001', '10.1093/rfs/hhy006', '0893-9454', '1465-7368', 'REVIEW OF FINANCIAL STUDIES', [], [2018], 44], ['Breza, E', 'FZR-2442-2022', 'WOS:000457653200006', '10.3982/ECTA13683', '0012-9682', '1468-0262', 'ECONOMETRICA', ['Commitment', 'reputation', 'savings', 'social networks'], [2019], 61], ['Breza, E', 'FZR-2442-2022', 'WOS:000506809500005', '10.1093/oxrep/grz025', '0266-903X', '1460-2121', 'OXFORD REVIEW OF ECONOMIC POLICY', ['social networks', 'learning', 'information diffusion', 'risk sharing', 'econometrics of networks'], [2019], 16], ['Breza, E', 'FZR-2442-2022', 'WOS:000555699000005', '10.1257/aer.20170861', '0002-8282', '1944-7981', 'AMERICAN ECONOMIC REVIEW', [], [2020], 46], ['Breza, E', 'FZR-2442-2022', 'WOS:000644942400035', '10.7326/M20-6141', '0003-4819', '1539-3704', 'ANNALS OF INTERNAL MEDICINE', [], [2021], 87], ['Breza, E', 'FZR-2442-2022', 'WOS:000672777600003', '10.1093/qje/qjab016', '0033-5533', '1531-4650', 'QUARTERLY JOURNAL OF ECONOMICS', [], [2021], 45], ['Breza, E', 'FZR-2442-2022', 'WOS:000672973700008', '10.1001/jamanetworkopen.2021.17115', '2574-3805', '', 'JAMA NETWORK OPEN', [], [2021], 37], ['Breza, E', 'FZR-2442-2022', 'WOS:000686447900002', '10.1038/s41591-021-01487-3', '1078-8956', '1546-170X', 'NATURE MEDICINE', [], [2021], 48], ['Breza, E', 'FZR-2442-2022', 'WOS:000703454600004', '10.1257/aer.20201385', '0002-8282', '1944-7981', 'AMERICAN ECONOMIC REVIEW', [], [2021], 20], ['Breza, E', 'FZR-2442-2022', 'WOS:000712407400003', '10.1257/aer.20181151', '0002-8282', '1944-7981', 'AMERICAN ECONOMIC REVIEW', [], [2021], 13], ['Breza, E', 'GLO-0293-2022', 'WOS:000719465200122', '', '0041-1337', '1534-6080', 'TRANSPLANTATION', [], [2021], 4], ['Breza, E', 'FZR-2442-2022', 'WOS:000770385500047', '', '0036-8075', '1095-9203', 'SCIENCE', [], [2022], 0], ['Breza, E', 'GLO-0293-2022', 'WOS:001023645700100', '10.1097/01.tp.0000945876.38793.fe', '0041-1337', '1534-6080', 'TRANSPLANTATION', [], [2023], 0], ['Breza, E', 'FZR-2442-2022', 'WOS:001033436300001', '10.1073/pnas.2207185120', '0027-8424', '1091-6490', 'PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES OF THE UNITED STATES OF AMERICA', ['social networks', 'aggregated relational data', 'consistency', 'survey methods'], [2023], 3], ['Breza, E', 'FZR-2442-2022', 'WOS:001156641400001', '10.1093/restud/rdad068', '0034-6527', '1467-937X', 'REVIEW OF ECONOMIC STUDIES', ['Information diffusion', 'Social learning', 'Common knowledge', 'Demonetisation'], [2024], 3], ['Breza, E', 'FZR-2442-2022', 'WOS:001186724000001', '10.1093/restud/rdad065', '0034-6527', '1467-937X', 'REVIEW OF ECONOMIC STUDIES', ['Social networks', 'Network change', 'Network formation', 'Network evolution', 'Microfinance', 'Market exposure', 'Favor exchange', 'Social capital'], [2023], 16]]
'0013-4694', '', 'ELECTROENCEPHALOGRAPHY AND CLINICAL NEUROPHYSIOLOGY', [], [1953], 9], ['CHAMBERLAIN, GHN', 'CIP-5954-2022', 'WOS:A1953UL22000013', '', '', '', 'DISCUSSIONS OF THE FARADAY SOCIETY', [], [1953], 8], ['CHAMBERLAIN, GHA', 'CIP-5954-2022', 'WOS:A1954UN55300012', '', '0035-9157', '', 'PROCEEDINGS OF THE ROYAL SOCIETY OF MEDICINE-LONDON', [], [1954], 0], ['CHAMBERLAIN, G', 'CKF-7091-2022', 'WOS:A1958WC26800021', '10.1136/bmj.1.5070.577-b', '1756-1833', '', 'BMJ-BRITISH MEDICAL JOURNAL', [], [1958], 0], ['CHAMBERLAIN, GT', 'CJR-4001-2022', 'WOS:A1958ZQ51200036', '10.1038/1821607a0', '0028-0836', '', 'NATURE', [], [1958], 4], ['CHAMBERLAIN, G', 'CHU-4310-2022', 'WOS:A1960WM51500002', '10.1136/gut.1.2.106', '0017-5749', '', 'GUT', [], [1960], 3], ['CHAMBERLAIN, G', 'CKF-7091-2022', 'WOS:A1960WC67600037', '10.1136/bmj.2.5204.1020-a', '0959-8138', '', 'BRITISH MEDICAL JOURNAL', [], [1960], 0], ['CHAMBERLAIN, GT', 'CJR-4001-2022', 'WOS:A1961WL26200011', '10.1016/0371-1951(61)80112-4', '', '', 'SPECTROCHIMICA ACTA', [], [1961], 2], ['CHAMBERLAIN, G', 'CKF-7091-2022', 'WOS:A19633179A00005', '', '0002-9378', '', 'AMERICAN JOURNAL OF OBSTETRICS AND GYNECOLOGY', [], [1963], 3], ['CHAMBERLAIN, GE', 'CJU-6872-2022', 'WOS:A19631487C00011', '10.1103/PhysRev.129.677', '0031-899X', '', 'PHYSICAL REVIEW', [], [1963], 114], ['CHAMBERLAIN, G', 'CKF-7091-2022', 'WOS:A19637785A00316', '', '1756-1833', '', 'BMJ-BRITISH MEDICAL JOURNAL', [], [1963], 1], ['CHAMBERLAIN, G', 'CKF-7091-2022', 'WOS:A19637786A00308', '10.1136/bmj.1.5344.1524', '0959-8138', '', 'BRITISH MEDICAL JOURNAL', [], [1963], 29], ['CHAMBERLAIN, G', 'CKF-7091-2022', 'WOS:A19637786A00307', '', '1756-1833', '', 'BMJ-BRITISH MEDICAL JOURNAL', [], [1963], 0], ['CHAMBERLAIN, G', 'CKF-7091-2022', 'WOS:A19637786A00306', '10.1136/bmj.2.5348.36', '0959-8138', '', 'BRITISH MEDICAL JOURNAL', [], [1963], 1], ['CHAMBERLAIN, GE', 'CJU-6872-2022', 'WOS:A19631491C00073', '10.1103/PhysRev.129.2566', '0031-899X', '', 'PHYSICAL REVIEW', [], [1963], 45], ['CHAMBERLAIN, G', 'CKF-7091-2022', 'WOS:A19647790A00212', '10.1136/bmj.1.5375.96', '0959-535X', '', 'BRITISH MEDICAL JOURNAL', [], [1964], 5], ['CHAMBERLA', 'HVJ-4762-2023', 'WOS:A19641627B00144', '', '0014-9446', '', 'FEDERATION PROCEEDINGS', [], [1964], 2], ['CHAMBERLAIN, GE', 'CJU-6872-2022', 'WOS:A19641647C00004', '10.1103/PhysRevLett.12.647', '0031-9007', '', 'PHYSICAL REVIEW LETTERS', [], [1964] ...
# University Name    Harvard College
# Name                    Raj Chetty
# Position                 Professor
# lastname                    Chetty
# firstnames                     Raj
# firstinits                       R
# suffix
# reordered_name           Chetty, R
# Name: 7, dtype: object
# Chetty, R
# TOO MANY MATCHES: Chetty, R
#
# University Name           Harvard College
# Name               Gabriel Chodorow-Reich
# Position              Assistant Professor
# lastname                   Chodorow-Reich
# firstnames                        Gabriel
# firstinits                              G
# suffix
# reordered_name          Chodorow-Reich, G
# Name: 8, dtype: object
# Chodorow-Reich, G
#
# ***Searching for: Chodorow-Reich, G
# ***doclist***: [['Chodorow-Reich, G', 'EPG-2139-2022', 'WOS:
['Chodorow-Reich, G', 'EPG-2139-2022', 'WOS:001284586800003', '10.1257/jep.38.3.61', '0895-3309', '1944-7965', 'JOURNAL OF ECONOMIC PERSPECTIVES', [], [2024], 4], ['Chodorow-Reich, G', 'EPG-2139-2022', 'WOS:001543408400002', '10.1086/735270', '0889-3365', '1537-2642', 'NBER MACROECONOMICS ANNUAL', [], [2025], 0]]
# University Name    Harvard College
# Name                Richard Cooper
# Position                 Professor
# lastname                    Cooper
# firstnames                 Richard
# firstinits                       R
# suffix
# reordered_name           Cooper, R
# Name: 9, dtype: object
# Cooper, R
# TOO MANY MATCHES: Cooper, R
#
# University Name    Harvard College
# Name               David M. Cutler
# Position                 Professor
# lastname                    Cutler
# firstnames                David M.
# firstinits                      DM
# suffix
# reordered_name          Cutler, DM
# Name: 10, dtype: object
# Cutler, DM
# multiple pages for:  Cutler, DM pages =  6
#
# ***Searching for: Cutler, DM
#
# ***Searching for: Cutler, DM
#
# ***Searching for: Cutler, DM
#
# ***Searching for: Cutler, DM
#
# ***Searching for: Cutler, DM
#
# ***Searching for: Cutler, DM
# ***doclist***: [['CUTLER, DM', 'HXG-9448-2023', 'WOS:A1988AC16700001', '10.2307/2555697', '0741-6261', '', 'RAND JOURNAL OF ECONOMICS', [], [1988], 92], ['CUTLER, DM', 'HXG-9448-2023', 'WOS:A1988R349500017', '', '0002-8282', '', 'AMERICAN ECONOMIC REVIEW', [], [1988], 51], ['CUTLER, DM', 'HXG-9448-2023', 'WOS:A1989U958000002', '10.3905/jpm.1989.409212', '0095-4918', '2168-8656', 'JOURNAL OF PORTFOLIO MANAGEMENT', [], [1989], 443], ['CUTLER, DM', 'HXG-9448-2023', 'WOS:A1990DT53200001', '', '0007-2303', '', 'BROOKINGS PAPERS ON ECONOMIC ACTIVITY', [], [1990], 108], ['CUTLER, DM', 'HXG-9448-2023', 'WOS:A1990DA38900013', '', '0002-8282', '', 'AMERICAN ECONOMIC REVIEW', [], [1990], 178], ['CUTLER, DM', 'HXG-9448-2023', 'WOS:A1991HD33300001', '', '0007-2303', '', 'BROOKINGS PAPERS ON ECONOMIC ACTIVITY', [], [1991], 133], ['CUTLER, DM', 'HXG-9448-2023', 'WOS:A1991FQ95800008', '10.2307/2298010', '0034-6527', '', 'REVIEW OF ECONOMIC STUDIES', [], [1991], 265], ['CUTLER, DM', 'HXG-9448-2023', 'WOS:A1992HW14900094', '', '0002-8282', '', 'AMERICAN ECONOMIC REVIEW', [], [1992], 188], ['CUTLER, DM', 'HXG-9448-2023', 'WOS:A1993NF37500013', '', '0033-3476', '', 'PUBLIC FINANCE-FINANCES PUBLIQUES', [], [1993], 50], ['CUTLER, DM', 'HXG-9448-2023', 'WOS:A1993KM78700009', '10.2307/2118501', '0033-5533', '', 'QUARTERLY JOURNAL OF ECONOMICS', [], [1993], 47], ['CUTLER, DM', 'HXG-9448-2023', 'WOS:A1993KW13600007', '', '0028-0283', '', 'NATIONAL TAX JOURNAL', [], [1993], 9], ['CUTLER, DM', 'HXG-9448-2023', 'WOS:A1994BC62M00007', '10.1017/CBO9780511571824.008', '', '', 'TAX PROGRESSIVITY AND INCOME INEQUALITY', [], [1994], 0], ['CUTLER, DM', 'HXG-9448-2023', 'WOS:A1994MX78800005', '10.1377/hlthaff.13.1.30', '0278-2715', '', 'HEALTH AFFAIRS', [], [1994], 5], ['CUTLER, DM', 'HXG-9448-2023', 'WOS:A1994MX78800007', '10.1377/hlthaff.13.1.55', '0278-2715', '', 'HEALTH AFFAIRS', [], [1994], 0], ['CUTLER, DM', 'HXG-9448-2023', 'WOS:A1994PE24300002', '10.1257/jep.8.3.13', '0895-3309', '1944-7965', 'JOURNAL OF ECONOMIC PERSPECTIVES', [], [1994], 36], ['CUTLER, DM', 'HXG-9448-2023', 'WOS:A1995QC86900002', '10.2307/2951696', '0012-9682', '', 'ECONOMETRICA', ['PROSPECTIVE PAYMENT', 'MORTALITY', 'HOSPITAL READMISSION', 'COMPETING HAZARDS'], [1995], 155], ['Cutler, DM', 'HXG-9448-2023', 'WOS:A1995BG50J00001', '', '', '', '1994 PROCEEDINGS OF THE EIGHTY-SEVENTH ANNUAL CONFERENCE ON TAXATION', [], [1995], 1], ['CUTLER, DM', 'HXG-9448-2023', 'WOS:A1995QW29800020', '10.1377/hlthaff.14.1.161', '0278-2715', '', 'HEALTH AFFAIRS', [], [1995], 13], ['CUTLER, DM', 'HXG-9448-2023', 'WOS:A1995QW29800017', '10.1377/hlthaff.14.1.125', '0278-2715', '', 'HEALTH AFFAIRS', [], [1995], 40], ['CUTLER, DM', 'HXG-9448-2023', 'WOS:A1995RB65100009', '', '0002-8282', '', 'AMERICAN ECONOMIC REVIEW', [], [1995], 18], ['CUTLER, DM', 'HXG-9448-2023', 'WOS:A1995RY24600031', '', '0022-0515', '', 'JOURNAL OF ECONOMIC LITERATURE', [], [1995], 0], ['Cutler, DM', 'HXG-9448-2023', 'WOS:A1996BG28V00011', '', '', '', "PROBLEM THAT WON'T GO AWAY", [], [1996], 1], ['Cutler, DM', 'HXG-9448-2023', 'WOS:A1996UL37300072', '', '0002-8282', '', 'AMERICAN ECONOMIC REVIEW', [], [1996], 49], ['Cutler, DM', 'HXG-9448-2023', 'WOS:A1996UL13200004', '10.2307/2946683', '0033-5533', '', 'QUARTERLY JOURNAL OF ECONOMICS', [], [1996], 430], ['Cutler, DM', 'HXG-9448-2023', 'WOS:A1996UW91900021', '', '0022-0515', '', 'JOURNAL OF ECONOMIC LITERATURE', [], [1996], 0], ['Cutler, DM', 'HXG-9448-2023', 'WOS:000072342900005', '', '0007-2303', '1533-4465', 'BROOKINGS PAPERS ON ECONOMIC ACTIVITY', [], [1997], 128], ['Cutler, DM', 'HXG-9448-2023', 'WOS:A1997WD59400020', '10.1377/hlthaff.16.1.194', '0278-2715', '', 'HEALTH AFFAIRS', [], [1997], 33], ['Cutler, DM', 'HXG-9448-2023', 'WOS:000072192400015', '', '', '', 'TAX REFORM', [], [1997], 0], ['Cutler, DM', 'HXG-9448-2023', 'WOS:000071309300020', '', '', '', '1996 PROCEEDINGS OF THE EIGHTY-NINTH ANNUAL CONFERENCE ON TAXATION', [], [1997], 0], ['Cutler, DM', 'HXG-9448-2023', 'WOS:A19 ...
# University Name    Harvard College
# Name                  Melissa Dell
# Position                 Professor
# lastname                      Dell
# firstnames                 Melissa
# firstinits                       M
# suffix
# reordered_name             Dell, M
# Name: 11, dtype: object
# Dell, M
# multiple pages for:  Dell, M pages =  7
#
# ***Searching for: Dell, M
#
# ***Searching for: Dell, M
# no close match: Volpe, M
# no close match: Decker, K
#
# ***Searching for: Dell, M
# no close match: Dell'mour, R
# no close match: Unger, A
# no close match: Range, F
# no close match: Dell'mour, M
# no close match: Dell'mour, M
#
# ***Searching for: Dell, M
# no close match: Dell'mour, M
# no close match: Dell'mour, M
# no close match: Dell'mour, M
#
# ***Searching for: Dell, M
# no close match: Pallio, S
# no close match: Mawla, M
# no close match: Miley, JT
# no close match: Miller, S
#
# ***Searching for: Dell, M
# no close match: Ho, P
# no close match: Andrews, S
# no close match: Ho, P
# no close match: Ellis, A
# no close match: Kent, A
# no close match: Berg, M
#
# ***Searching for: Dell, M
# no close match: Ellis, A
# ***doclist***: [['Dell, MB', 'ESK-4456-2022', 'WOS:000207000700001', '', '0013-7006', '', 'ENCEPHALE-REVUE DE PSYCHIATRIE CLINIQUE BIOLOGIQUE ET THERAPEUTIQUE', [], [1949], 2], ['DELL, MB', 'ESK-4456-2022', 'WOS:A1949UX35200022', '', '0035-3787', '', 'REVUE NEUROLOGIQUE', [], [1949], 97], ['DELL, MB', 'ESK-4456-2022', 'WOS:A1950UX39700001', '', '0035-3787', '', 'REVUE NEUROLOGIQUE', [], [1950], 35], ['DELL, MB', 'ESK-4456-2022', 'WOS:A1951UX40700005', '', '0035-3787', '', 'REVUE NEUROLOGIQUE', [], [1951], 2], ['DELL, MB', 'ESK-4456-2022', 'WOS:A1951UX40700007', '', '0035-3787', '2213-0004', 'REVUE NEUROLOGIQUE', [], [1951], 6], ['DELL, MB', 'ESK-4456-2022', 'WOS:A1951UX40700024', '', '0035-3787', '', 'REVUE NEUROLOGIQUE', [], [1951], 11], ['DELL, MB', 'ESK-4456-2022', 'WOS:A1952UX42400041', '', '0035-3787', '', 'REVUE NEUROLOGIQUE', [], [1952], 0], ['DELL, MB', 'ESK-4456-2022', 'WOS:A1952UX42400037', '', '0035-3787', '', 'REVUE NEUROLOGIQUE', [], [1952], 0], ['DELL, MB', 'ESK-4456-2022', 'WOS:A1952UX42400031', '', '0035-3787', '', 'REVUE NEUROLOGIQUE', [], [1952], 4], ['DELL, MB', 'ESK-4456-2022', 'WOS:A1952UQ84700017', '', '0755-4982', '', 'PRESSE MEDICALE', [], [1952], 0], ['DELL, M', '', 'WOS:A1952UQ84700015', '', '0755-4982', '', 'PRESSE MEDICALE', [], [1952], 0], ['DELL, MB', 'ESK-4456-2022', 'WOS:A1952UG21700069', '', '0013-4694', '', 'ELECTROENCEPHALOGRAPHY AND CLINICAL NEUROPHYSIOLOGY', [], [1952], 0], ['DELL, MB', 'ESK-4456-2022', 'WOS:A1952UG21700054', '', '0013-4694', '', 'ELECTROENCEPHALOGRAPHY AND CLINICAL NEUROPHYSIOLOGY', [], [1952], 0], ['DELL, MB', 'ESK-4456-2022', 'WOS:A1952UG21700052', '', '0013-4694', '', 'ELECTROENCEPHALOGRAPHY AND CLINICAL NEUROPHYSIOLOGY', [], [1952], 0], ['DELL, MB', 'ESK-4456-2022', 'WOS:A1952UX42100002', '', '0035-3787', '2213-0004', 'REVUE NEUROLOGIQUE', [], [1952], 26], ['DELL, M', 'CMS-2539-2022', 'WOS:A1953UZ26100006', '10.1097/00005072-195307000-00006', '0022-3069', '', 'JOURNAL OF NEUROPATHOLOGY AND EXPERIMENTAL NEUROLOGY', [], [1953], 110], ['Dell, MB', 'ESK-4456-2022', 'WOS:000207006500004', '', '0013-7006', '', 'ENCEPHALE-REVUE DE PSYCHIATRIE CLINIQUE BIOLOGIQUE ET THERAPEUTIQUE', [], [1953], 2], ['DELL, MB', 'ESK-4456-2022', 'WOS:A1953UG22000095', '', '0013-4694', '', 'ELECTROENCEPHALOGRAPHY AND CLINICAL NEUROPHYSIOLOGY', [], [1953], 0], ['DELL, MB', 'ESK-4456-2022', 'WOS:A1953UG22000091', '', '0013-4694', '', 'ELECTROENCEPHALOGRAPHY AND CLINICAL NEUROPHYSIOLOGY', [], [1953], 1], ['DELL, MB', 'ESK-4456-2022', 'WOS:A1953UG22000085', '', '0013-4694', '', 'ELECTROENCEPHALOGRAPHY AND CLINICAL NEUROPHYSIOLOGY', [], [1953], 2], ['DELL, MB', 'ESK-4456-2022', 'WOS:A1953UG22200083', '', '0013-4694', '', 'ELECTROENCEPHALOGRAPHY AND CLINICAL NEUROPHYSIOLOGY', [], [1953], 0], ['DELL, MB', 'ESK-4456-2022', 'WOS:A1953UX43000007', '', '0035-3787', '', 'REVUE NEUROLOGIQUE', [], [1953], 1], ['Dell, MB', 'ESK-4456-2022', 'WOS:000207006200006', '', '0013-7006', '', 'ENCEPHALE-REVUE DE PSYCHIATRIE CLINIQUE BIOLOGIQUE ET THERAPEUTIQUE', [], [1953], 3], ['DELL, MB', 'ESK-4456-2022', 'WOS:A1953UQ89600003', '', '0755-4982', '2213-0276', 'PRESSE MEDICALE', [], [1953], 7], ['DELL, MB', 'ESK-4456-2022', 'WOS:A1953UX43100021', '', '0035-3787', '2213-0004', 'REVUE NEUROLOGIQUE', [], [1953], 1], ['DELL, MB', 'ESK-4456-2022', 'WOS:A1953UC52300040', '10.1021/ie50520a045', '0019-7866', '', 'INDUSTRIAL AND ENGINEERING CHEMISTRY', [], [1953], 1], ['DELL, MB', 'ESK-4456-2022', 'WOS:A1954YC59300002', '', '0035-3787', '', 'REVUE NEUROLOGIQUE', [], [1954], 9], ['DELL, MB', 'ESK-4456-2022', 'WOS:A1954UG22600047', '', '0013-4694', '', 'ELECTROENCEPHALOGRAPHY AND CLINICAL NEUROPHYSIOLOGY', [], [1954], 2], ['Dell, MB', 'ESK-4456-2022', 'WOS:000207007900004', '', '0013-7006', '', 'ENCEPHALE-REVUE DE PSYCHIATRIE CLINIQUE BIOLOGIQUE ET THERAPEUTIQUE', [], [1955], 10], ['DELL, MB', 'ESK-4456-2022', 'WOS:A1955WR94300096', '', '0013-4694', '', 'ELECTROENCEPHALOGRAPHY AND CLINICAL NEUROPHYSIOLOGY', [], [1955], 0], ['DELL, M ...
# University Name    Harvard College
# Name                   Karen Dynan
# Position                 Professor
# lastname                     Dynan
# firstnames                   Karen
# firstinits                       K
# suffix
# reordered_name            Dynan, K
# Name: 12, dtype: object
# Dynan, K
#
# ***Searching for: Dynan, K
# ...
# University Name     University of Chicago
# Name                    Lars Peter Hansen
# Position                        Professor
# lastname                           Hansen
# firstnames                     Lars Peter
# firstinits                             LP
# suffix
# reordered_name                 Hansen, LP
# Name: 69, dtype: object
# Hansen, LP
# multiple pages for:  Hansen, LP pages =  7
#
# ***Searching for: Hansen, LP
#
# ***Searching for: Hansen, LP
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File c:\Users\F0040RP\Documents\DartLib_RDS\projects\bibliometrics\bibliometrics-analysis\.venv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File c:\Users\F0040RP\Documents\DartLib_RDS\projects\bibliometrics\bibliometrics-analysis\.venv\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File c:\Users\F0040RP\Documents\DartLib_RDS\projects\bibliometrics\bibliometrics-analysis\.venv\Lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#
# File C:\Python312\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File C:\Python312\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File C:\Python312\Lib\http\client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File c:\Users\F0040RP\Documents\DartLib_RDS\projects\bibliometrics\bibliometrics-analysis\.venv\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File c:\Users\F0040RP\Documents\DartLib_RDS\projects\bibliometrics\bibliometrics-analysis\.venv\Lib\site-packages\urllib3\connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File c:\Users\F0040RP\Documents\DartLib_RDS\projects\bibliometrics\bibliometrics-analysis\.venv\Lib\site-packages\urllib3\util\retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File c:\Users\F0040RP\Documents\DartLib_RDS\projects\bibliometrics\bibliometrics-analysis\.venv\Lib\site-packages\urllib3\util\util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File c:\Users\F0040RP\Documents\DartLib_RDS\projects\bibliometrics\bibliometrics-analysis\.venv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File c:\Users\F0040RP\Documents\DartLib_RDS\projects\bibliometrics\bibliometrics-analysis\.venv\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File c:\Users\F0040RP\Documents\DartLib_RDS\projects\bibliometrics\bibliometrics-analysis\.venv\Lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#
# File C:\Python312\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File C:\Python312\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File C:\Python312\Lib\http\client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[23], line 8
#       4 #startidx = 0
#       5 #endidx = 3
#       6 subdf = authordf.iloc[startidx:endidx].copy()
#       7 subdf["doclists"], subdf['toomany_orno_matches'] = \
# ----> 8    zip(*subdf.apply(lambda x: get_author_metadata(x, "reordered_name"), axis=1))
#       9 #authordf.loc[startidx: endidx, "doclists"] = authordf.iloc[startidx:endidx].apply(lambda x: get_author_metadata(x, "reordered_name"), axis=1)
#      10 docdf = subdf.explode("doclists")
#
# File c:\Users\F0040RP\Documents\DartLib_RDS\projects\bibliometrics\bibliometrics-analysis\.venv\Lib\site-packages\pandas\core\frame.py:10381, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10367 from pandas.core.apply import frame_apply
#   10369 op = frame_apply(
#   10370     self,
#   10371     func=func,
#    (...)  10379     kwargs=kwargs,
#   10380 )
# > 10381 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\F0040RP\Documents\DartLib_RDS\projects\bibliometrics\bibliometrics-analysis\.venv\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File c:\Users\F0040RP\Documents\DartLib_RDS\projects\bibliometrics\bibliometrics-analysis\.venv\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File c:\Users\F0040RP\Documents\DartLib_RDS\projects\bibliometrics\bibliometrics-analysis\.venv\Lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[23], line 8, in <lambda>(x)
#       4 #startidx = 0
#       5 #endidx = 3
#       6 subdf = authordf.iloc[startidx:endidx].copy()
#       7 subdf["doclists"], subdf['toomany_orno_matches'] = \
# ----> 8    zip(*subdf.apply(lambda x: get_author_metadata(x, "reordered_name"), axis=1))
#       9 #authordf.loc[startidx: endidx, "doclists"] = authordf.iloc[startidx:endidx].apply(lambda x: get_author_metadata(x, "reordered_name"), axis=1)
#      10 docdf = subdf.explode("doclists")
#
# Cell In[21], line 36, in get_author_metadata(row, colname)
#      34     print("multiple pages for: ", authorname, "pages = ", num_pages)
#      35     for i in range(1, num_pages + 1):
# ---> 36         doclist.extend(get_author_info(authorname, i))
#      37 print("***doclist***:", doclist)
#      38 #newdoclist = []
#      39 #for doc in doclist:
#      40 #    newdoclist.append(row + doc)
#      41 #return newdoclist
#
# Cell In[19], line 14, in get_author_info(authorname, page)
#      12 print("\n***Searching for:", authorname)
#      13 SEARCH_QUERY = f"AU={authorname}"
# ---> 14 request = requests.get(f'{BASEURL_ST}documents?db=WOS&q={urllib.parse.quote(SEARCH_QUERY)}&limit=50&page={page}', headers=HEADERS_ST)
#      15 data = request.json()
#      16 #id_dict = {}
#
# File c:\Users\F0040RP\Documents\DartLib_RDS\projects\bibliometrics\bibliometrics-analysis\.venv\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\F0040RP\Documents\DartLib_RDS\projects\bibliometrics\bibliometrics-analysis\.venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\F0040RP\Documents\DartLib_RDS\projects\bibliometrics\bibliometrics-analysis\.venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\F0040RP\Documents\DartLib_RDS\projects\bibliometrics\bibliometrics-analysis\.venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\F0040RP\Documents\DartLib_RDS\projects\bibliometrics\bibliometrics-analysis\.venv\Lib\site-packages\requests\adapters.py:682, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#    (...)    678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
# --> 682     raise ConnectionError(err, request=request)
#     684 except MaxRetryError as e:
#     685     if isinstance(e.reason, ConnectTimeoutError):
#     686         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %%
docdf.head(10)
# Out:
#    University Name             Name   Position lastname firstnames firstinits  \
# 0  Harvard College  Alberto Alesina  Professor  Alesina    Alberto          A
# 0  Harvard College  Alberto Alesina  Professor  Alesina    Alberto          A
# 0  Harvard College  Alberto Alesina  Professor  Alesina    Alberto          A
# 0  Harvard College  Alberto Alesina  Professor  Alesina    Alberto          A
# 0  Harvard College  Alberto Alesina  Professor  Alesina    Alberto          A
# 0  Harvard College  Alberto Alesina  Professor  Alesina    Alberto          A
# 0  Harvard College  Alberto Alesina  Professor  Alesina    Alberto          A
# 0  Harvard College  Alberto Alesina  Professor  Alesina    Alberto          A
# 0  Harvard College  Alberto Alesina  Professor  Alesina    Alberto          A
# 0  Harvard College  Alberto Alesina  Professor  Alesina    Alberto          A
#
#   suffix reordered_name                                           doclists  \
# 0            Alesina, A  [ALESINA, A, CBE-0396-2022, WOS:A1979GV9620002...
# 0            Alesina, A  [ALESINA, A, CBE-0396-2022, WOS:A1981LH4860000...
# 0            Alesina, A  [ALESINA, A, CBE-0396-2022, WOS:A1982QW1520000...
# 0            Alesina, A  [ALESINA, A, CBE-0396-2022, WOS:A1983RJ7480000...
# 0            Alesina, A  [ALESINA, A, CBE-0396-2022, WOS:A1985A10860001...
# 0            Alesina, A  [ALESINA, A, EMJ-5429-2022, WOS:A1987J36310001...
# 0            Alesina, A  [ALESINA, A, CBE-0396-2022, WOS:A1987L12860000...
# 0            Alesina, A  [ALESINA, A, EMJ-5429-2022, WOS:A1988M17760001...
# 0            Alesina, A  [ALESINA, A, CBE-0396-2022, WOS:A1988AH4800000...
# 0            Alesina, A  [ALESINA, A, EMJ-5429-2022, WOS:A1988M17930000...
#
#    toomany_orno_matches  match_name          resID              doc_uid  \
# 0                 False  ALESINA, A  CBE-0396-2022  WOS:A1979GV96200029
# 0                 False  ALESINA, A  CBE-0396-2022  WOS:A1981LH48600008
# 0                 False  ALESINA, A  CBE-0396-2022  WOS:A1982QW15200001
# 0                 False  ALESINA, A  CBE-0396-2022  WOS:A1983RJ74800005
# 0                 False  ALESINA, A  CBE-0396-2022  WOS:A1985A108600011
# 0                 False  ALESINA, A  EMJ-5429-2022  WOS:A1987J363100010
# 0                 False  ALESINA, A  CBE-0396-2022  WOS:A1987L128600005
# 0                 False  ALESINA, A  EMJ-5429-2022  WOS:A1988M177600014
# 0                 False  ALESINA, A  CBE-0396-2022  WOS:A1988AH48000001
# 0                 False  ALESINA, A  EMJ-5429-2022  WOS:A1988M179300004
#
#                               doc_doi   doc_issn doc_eissn  \
# 0                                      0002-9939
# 0            10.1109/TCS.1981.1084993  0098-4094
# 0            10.2140/pjm.1982.103.251  0030-8730
# 0                                      0017-0097
# 0                                      0017-0097
# 0                     10.2307/1884222  0033-5533
# 0  10.1111/j.1465-7295.1987.tb00764.x  0095-2583
# 0        10.1016/0304-3932(88)90055-4  0304-3932
# 0                     10.2307/3584936  0889-3365
# 0                                      0022-2879
#
#                                            so_title au_keywords pubyear  \
# 0  PROCEEDINGS OF THE AMERICAN MATHEMATICAL SOCIETY          []  1979.0
# 0         IEEE TRANSACTIONS ON CIRCUITS AND SYSTEMS          []  1981.0
# 0                    PACIFIC JOURNAL OF MATHEMATICS          []  1982.0
# 0    GIORNALE DEGLI ECONOMISTI E ANNALI DI ECONOMIA          []  1983.0
# 0    GIORNALE DEGLI ECONOMISTI E ANNALI DI ECONOMIA          []  1985.0
# 0                    QUARTERLY JOURNAL OF ECONOMICS          []  1987.0
# 0                                  ECONOMIC INQUIRY          []  1987.0
# 0                     JOURNAL OF MONETARY ECONOMICS          []  1988.0
# 0                        NBER MACROECONOMICS ANNUAL          []  1988.0
# 0               JOURNAL OF MONEY CREDIT AND BANKING          []  1988.0
#
#    citedby_count
# 0            0.0
# 0          284.0
# 0            5.0
# 0            0.0
# 0            0.0
# 0          601.0
# 0          143.0
# 0            3.0
# 0          132.0
# 0          129.0
