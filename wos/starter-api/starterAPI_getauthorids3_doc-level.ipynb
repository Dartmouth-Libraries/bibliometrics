# %% [markdown]
# ## Using WoS Starter API to retrieve author information
#
# In order to run the code below you will need to request and acquire an API key for the Web of Science Starter API.
#
# Once you have acquired this key, save it in a document called `.env` within this same folder. Save the key in the following format at the top line of that document:
#
#     STARTERKEY = "XXXXXXXXXXX" #insert the key in place of the Xs
#
# See this repository's ReadME.md [**INSERT LINK**] for more on saving and retrieving your API Key from an .env file.

# %% [markdown]
# ### I. Getting Started
#
# 1. **Import all necessary packages.** To first install these packages to a local environment, you can use the requirements.txt file. Open a terminal / command prompt within this project's folder and type:
#
# ```
# pip install -r requirements.txt
# ```
#
# Then you can import these packages.

# %%
import requests
import time
import os
import urllib.parse
import pandas as pd
import random
from bs4 import BeautifulSoup   #for parsing xml and html
from random import randint  
from dotenv import load_dotenv 
load_dotenv()
# Out:
# C:\Users\F0040RP\AppData\Local\Temp\ipykernel_9660\1841898557.py:5: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# True

# %% [markdown]
# 2. Store the API link to memory and retrieve your API key.

# %%
BASEURL_ST = 'https://api.clarivate.com/apis/wos-starter/v1/'
HEADERS_ST = {'X-APIKey': os.getenv("APIKEY")}

# %%
import Levenshtein as lev
lev_wts = (1, 0, 1)

# %%
authordf = pd.read_csv("data/chor_davin_authors.csv", encoding = 'utf-8', usecols=[0,1,2,3,4,5], nrows=10000)
#authordf = authordf.iloc[:, 0:6]
print(authordf.shape)
authordf = authordf.dropna(how="all")
authordf["Ranking"] = authordf["Ranking"].ffill()
authordf['Ranking'] = authordf['Ranking'].astype(int)
authordf["University Name"] = authordf["University Name"].ffill()
#authordf = authordf.astype({"Ranking": str, "University Name": str})

print(authordf.shape)
authordf = authordf.fillna("")
authordf.head()
# Out:
# (10000, 6)
# (2991, 6)
#    Ranking  University Name             Name             Position  \
# 0        1  Harvard College  Alberto Alesina            Professor
# 1        1  Harvard College   Isaiah Andrews            Professor
# 2        1  Harvard College       Pol Antràs            Professor
# 3        1  Harvard College  Robert J. Barro            Professor
# 4        1  Harvard College      Emily Breza  Assistant Professor
#
#                                                  URL      hosting domain
# 0   https://scholar.harvard.edu/alesina/publications  University webpage
# 1  https://scholar.harvard.edu/iandrews/publications  University webpage
# 2    https://scholar.harvard.edu/antras/publications  University webpage
# 3
# 4  https://sites.Google site.com/view/ebreza/rese...         Google site

# %% [markdown]
# ### Convert First M. Last Suffix to Last FM

# %%
def convert_name_first2last_to_last_fminits(orig_name: str):
    if orig_name == "":
        return "", "", "", "", ""
    comma_split = orig_name.split(", ")
    if len(comma_split) > 1:
        suffix = comma_split[-1]
    else:
        suffix = ""
    name = comma_split[0]
    name_parts = name.split()
    last_name = name_parts.pop(-1)
    first_names = ' '.join(name_parts)
    first_inits = ''.join([part[0] for part in name_parts])
    #reordered_name = last_name + " " + first_names + " " + suffix
    #reordered_shortname = last_name + " " + first_inits
    reordered_shortname2 = last_name + ", " + first_inits
    return last_name, first_names, first_inits, suffix, reordered_shortname2

# %%
authordf["lastname"], authordf["firstnames"], authordf["firstinits"], authordf["suffix"], authordf["reordered_name"] = \
    zip(*authordf["Name"].apply(convert_name_first2last_to_last_fminits))
authordf.head()
# Out:
#    Ranking  University Name             Name             Position  \
# 0        1  Harvard College  Alberto Alesina            Professor
# 1        1  Harvard College   Isaiah Andrews            Professor
# 2        1  Harvard College       Pol Antràs            Professor
# 3        1  Harvard College  Robert J. Barro            Professor
# 4        1  Harvard College      Emily Breza  Assistant Professor
#
#                                                  URL      hosting domain  \
# 0   https://scholar.harvard.edu/alesina/publications  University webpage
# 1  https://scholar.harvard.edu/iandrews/publications  University webpage
# 2    https://scholar.harvard.edu/antras/publications  University webpage
# 3
# 4  https://sites.Google site.com/view/ebreza/rese...         Google site
#
#   lastname firstnames firstinits suffix reordered_name
# 0  Alesina    Alberto          A            Alesina, A
# 1  Andrews     Isaiah          I            Andrews, I
# 2   Antràs        Pol          P             Antràs, P
# 3    Barro  Robert J.         RJ             Barro, RJ
# 4    Breza      Emily          E              Breza, E

# %% [markdown]
# ## Apply to dataframe of multiple authors

# %%
#def get_author_info(row: pd.Series, authorname: str, page: int):
def get_author_info(authorname: str, page: int):
    print("\n***Searching for:", authorname)
    SEARCH_QUERY = f"AU={authorname}"
    request = requests.get(f'{BASEURL_ST}documents?db=WOS&q={urllib.parse.quote(SEARCH_QUERY)}&limit=50&page={page}', headers=HEADERS_ST)
    data = request.json()
    #id_dict = {}
    doclist = []
    hits = [hit for hit in data['hits']]
    for hit in hits:
        try:
            authors = hit['names']['authors']
            short_names = [au['wosStandard'] for au in authors]
            short_names_lower = [name.lower() for name in short_names]
            ids = [au['researcherId'] if 'researcherId' in au.keys() else '' for au in authors]
            lev_scores = [lev.distance(authorname.lower(), name, weights = lev_wts) for name in short_names_lower]
            min_idx = lev_scores.index(min(lev_scores))
            if lev_scores[min_idx] > 2:
                print("no close match:", short_names[min_idx])
                # return something or set some value??
                continue
            #use min idx to get name and id
            tgt_shortname = short_names[min_idx]
            tgt_id = ids[min_idx]
        except KeyError:
            print("missing authors:", authorname, hit['uid'])
            continue
        keywords = hit['keywords']['authorKeywords']
        if "sourceTitle" in hit['source'].keys():
            so_title = hit['source']['sourceTitle']
        else:
            so_title = []
        if "publishYear" in hit['source'].keys():
            pubyear = [hit['source']['publishYear']]
        else:
            pubyear = []
        doc_uid = hit['uid']
        if 'doi' in hit['identifiers'].keys():
            doi = hit['identifiers']['doi']
        else:
            doi = ""
        if 'issn' in hit['identifiers'].keys():
            issn = hit['identifiers']['issn']
        else:
            issn = ""
        if 'eissn' in hit['identifiers'].keys():
            eissn = hit['identifiers']['eissn']
        else:
            eissn = ""
        citedby_count = hit['citations'][0]['count']
        doclist.append([tgt_shortname, tgt_id, 
                        doc_uid, doi, issn, eissn,
                        so_title, keywords, pubyear, 
                        citedby_count])
    
    return(doclist)

# %%
#get_author_info(authorname="Fryer, RG", page=1)

# %%
def get_author_metadata(row:pd.Series, colname:str):
    """
    Reads in an author name written in the form of "LastName, FirstInits"
    Uses Starter API to search for authors with this name
    Retrieve author info for potential matching authors
    Also retrieves document ids for documents written by these authors
    """
    print(row)
    print(row[colname])
    authorname = row[colname]
    SEARCH_QUERY = f"AU={authorname}"
    initial_request = requests.get(f'{BASEURL_ST}documents?db=WOS&q={urllib.parse.quote(SEARCH_QUERY)}&limit=10', headers=HEADERS_ST)
    data = initial_request.json()
    num_results = int(data['metadata']['total'])
    num_pages = 1 + (num_results -1)// 50
    doclist = []
    if num_pages <= 1:
        doclist = get_author_info(authorname, page=1)
    elif num_pages > 10:
        #row['too_many_matches'] = "yes"
        print("TOO MANY MATCHES:", authorname, "\n")
        #return(row)
        return [], True
    else:
        print("multiple pages for: ", authorname, "pages = ", num_pages)
        for i in range(1, num_pages + 1):
            doclist.extend(get_author_info(authorname, i))
    print("***doclist***:", doclist)
    #newdoclist = []
    #for doc in doclist:
    #    newdoclist.append(row + doc)
    #return newdoclist
    return doclist, False

# %%
#doclist = []
#for row in authordf.iloc[:3].iterrows():
#    doclist.extend(get_author_metadata(row, "reordered_name"))
#authordf.loc[:3, doclist] = 
#print(len(doclist))

#authordf.loc[:1, "doclists"] = authordf.iloc[:3].apply(lambda x: get_author_metadata(x, "reordered_name"), axis=1)
#authordf.head()

# %%
numauthors = len(authordf)
print(numauthors)
num_iterations = numauthors // 50
print(num_iterations)
# Out:
# 2991
# 59

# %%
for i in range(5, 8):#num_iterations + 1):
    startidx = i * 50
    endidx = startidx + 50
    #startidx = 0
    #endidx = 3
    subdf = authordf.iloc[startidx:endidx].copy()
    subdf["doclists"], subdf['too_many_matches'] = \
       zip(*subdf.apply(lambda x: get_author_metadata(x, "reordered_name"), axis=1))
    #authordf.loc[startidx: endidx, "doclists"] = authordf.iloc[startidx:endidx].apply(lambda x: get_author_metadata(x, "reordered_name"), axis=1)
    docdf = subdf.explode("doclists")
    docdf['doclists'] = docdf['doclists'].apply(lambda d: d if isinstance(d, list) else [])
    #docdf['doclists'] = docdf['doclists'].fillna("").apply(list)
    docdf[["match_name", "resID", "doc_uid", "doc_doi", "doc_issn",
           "doc_eissn", "so_title", "au_keywords", "pubyear", "citedby_count"]] =\
           pd.DataFrame(docdf.doclists.tolist(), index=docdf.index)
    docdf.to_csv(f"data/docdata_{startidx}-{endidx}.csv", encoding='utf-8')   
    #df = authordf.iloc[startidx: endidx].apply(lambda x: get_author_metadata(x, "reordered_name"), axis=1)
    #authordf.to_csv(f"data/authordata_{startidx}-{endidx}.csv", encoding='utf-8')
# Out:
# Ranking                              3
# University Name    Stanford University
# Name                     Paul A. David
# Position                     Professor
# URL
# hosting domain
# lastname                         David
# firstnames                     Paul A.
# firstinits                          PA
# suffix
# reordered_name               David, PA
# doclists                           NaN
# Name: 150, dtype: object
# David, PA
# multiple pages for:  David, PA pages =  3
#
# ***Searching for: David, PA
#
# ***Searching for: David, PA
#
# ***Searching for: David, PA
# Ranking                                                            3
# University Name                                  Stanford University
# Name                                                   Walter Falcon
# Position                                                   Professor
# URL                https://fse.fsi.stanford.edu/people/walter_p_f...
# hosting domain                                    University webpage
# lastname                                                      Falcon
# firstnames                                                    Walter
# firstinits                                                         W
# suffix
# reordered_name                                             Falcon, W
# doclists                                                         NaN
# Name: 151, dtype: object
# Falcon, W
# multiple pages for:  Falcon, W pages =  2
#
# ***Searching for: Falcon, W
#
# ***Searching for: Falcon, W
# Ranking                              3
# University Name    Stanford University
# Name                   Victor R. Fuchs
# Position                     Professor
# URL
# hosting domain
# lastname                         Fuchs
# firstnames                   Victor R.
# firstinits                          VR
# suffix
# reordered_name               Fuchs, VR
# doclists                           NaN
# Name: 152, dtype: object
# Fuchs, VR
# multiple pages for:  Fuchs, VR pages =  4
#
# ***Searching for: Fuchs, VR
#
# ***Searching for: Fuchs, VR
#
# ***Searching for: Fuchs, VR
#
# ***Searching for: Fuchs, VR
# Ranking                              3
# University Name    Stanford University
# Name                    John G. Gurley
# Position                     Professor
# URL
# hosting domain
# lastname                        Gurley
# firstnames                     John G.
# firstinits                          JG
# suffix
# reordered_name              Gurley, JG
# doclists                           NaN
# Name: 153, dtype: object
# Gurley, JG
# multiple pages for:  Gurley, JG pages =  2
#
# ***Searching for: Gurley, JG
#
# ***Searching for: Gurley, JG
# Ranking                                            3
# University Name                  Stanford University
# Name                                Peter J. Hammond
# Position                                   Professor
# URL                http://web.stanford.edu/~hammond/
# hosting domain                    University webpage
# lastname                                     Hammond
# firstnames                                  Peter J.
# firstinits                                        PJ
# suffix
# reordered_name                           Hammond, PJ
# doclists                                         NaN
# Name: 154, dtype: object
# Hammond, PJ
# multiple pages for:  Hammond, PJ pages =  3
#
# ***Searching for: Hammond, PJ
#
# ***Searching for: Hammond, PJ
#
# ***Searching for: Hammond, PJ
# Ranking                                            3
# University Name                  Stanford University
# Name                                Donald J. Harris
# Position                                   Professor
# URL                http://web.stanford.edu/~dharris/
# hosting domain                    University webpage
# lastname                                      Harris
# firstnames                                 Donald J.
# firstinits                                        DJ
# suffix
# reordered_name                            Harris, DJ
# doclists                                         NaN
# Name: 155, dtype: object
# Harris, DJ
# TOO MANY MATCHES: Harris, DJ
#
# Ranking                              3
# University Name    Stanford University
# Name                      Bert Hickman
# Position                     Professor
# URL
# hosting domain
# lastname                       Hickman
# firstnames                        Bert
# firstinits                           B
# suffix
# reordered_name              Hickman, B
# doclists                           NaN
# Name: 156, dtype: object
# Hickman, B
# multiple pages for:  Hickman, B pages =  4
#
# ***Searching for: Hickman, B
#
# ***Searching for: Hickman, B
# no close match: Bockemühl, J
#
# ***Searching for: Hickman, B
# no close match: Vida, T
# no close match: Farmer, JJ
# no close match: Farmer, JJ
# no close match: Happa, FA
# no close match: Racz, JL
# no close match: Chen, D
# no close match: Qu, C
# no close match: Zeng, R
#
# ***Searching for: Hickman, B
# no close match: Link, DC
# no close match: Soffa, DR
# no close match: Smith, MS
# no close match: Smith, MS
# no close match: Smith, MS
# no close match: McAnally, BE
# no close match: Smith, MS
# no close match: Smith, MS
# no close match: Smith, MS
# no close match: Soffa, DR
# no close match: Wu, GY
# Ranking                              3
# University Name    Stanford University
# Name                   Anne O. Krueger
# Position                     Professor
# URL
# hosting domain
# lastname                       Krueger
# firstnames                     Anne O.
# firstinits                          AO
# suffix
# reordered_name             Krueger, AO
# doclists                           NaN
# Name: 157, dtype: object
# Krueger, AO
# multiple pages for:  Krueger, AO pages =  3
#
# ***Searching for: Krueger, AO
#
# ***Searching for: Krueger, AO
#
# ***Searching for: Krueger, AO
# Ranking                                             3
# University Name                   Stanford University
# Name                                    Mordecai Kurz
# Position                                    Professor
# URL                http://web.stanford.edu/~mordecai/
# hosting domain                     University webpage
# lastname                                         Kurz
# firstnames                                   Mordecai
# firstinits                                          M
# suffix
# reordered_name                                Kurz, M
# doclists                                          NaN
# Name: 158, dtype: object
# Kurz, M
# TOO MANY MATCHES: Kurz, M
#
# Ranking                                          3
# University Name                Stanford University
# Name                               Lawrence J. Lau
# Position                                 Professor
# URL                http://web.stanford.edu/~ljlau/
# hosting domain                  University webpage
# lastname                                       Lau
# firstnames                             Lawrence J.
# firstinits                                      LJ
# suffix
# reordered_name                             Lau, LJ
# doclists                                       NaN
# Name: 159, dtype: object
# Lau, LJ
# multiple pages for:  Lau, LJ pages =  3
#
# ***Searching for: Lau, LJ
#
# ***Searching for: Lau, LJ
# no close match: Tung, CH
#
# ***Searching for: Lau, LJ
# Ranking                                                            3
# University Name                                  Stanford University
# Name                                                      Roger Noll
# Position                                                   Professor
# URL                https://profiles.stanford.edu/roger-noll?tab=p...
# hosting domain                                    University webpage
# lastname                                                        Noll
# firstnames                                                     Roger
# firstinits                                                         R
# suffix
# reordered_name                                               Noll, R
# doclists                                                         NaN
# Name: 160, dtype: object
# Noll, R
# TOO MANY MATCHES: Noll, R
#
# Ranking                                                      3
# University Name                            Stanford University
# Name                                          John H. Pencavel
# Position                                             Professor
# URL                https://profiles.stanford.edu/john-pencavel
# hosting domain                              University webpage
# lastname                                              Pencavel
# firstnames                                             John H.
# firstinits                                                  JH
# suffix
# reordered_name                                    Pencavel, JH
# doclists                                                   NaN
# Name: 161, dtype: object
# Pencavel, JH
#
# ***Searching for: Pencavel, JH
# Ranking                                     3
# University Name           Stanford University
# Name                        Thomas J. Sargent
# Position                            Professor
# URL                http://www.tomsargent.com/
# hosting domain               Amazon Registrar
# lastname                              Sargent
# firstnames                          Thomas J.
# firstinits                                 TJ
# suffix
# reordered_name                    Sargent, TJ
# doclists                                  NaN
# Name: 162, dtype: object
# Sargent, TJ
# multiple pages for:  Sargent, TJ pages =  4
#
# ***Searching for: Sargent, TJ
#
# ***Searching for: Sargent, TJ
#
# ***Searching for: Sargent, TJ
#
# ***Searching for: Sargent, TJ
# Ranking                              3
# University Name    Stanford University
# Name                 David A. Starrett
# Position                     Professor
# URL
# hosting domain
# lastname                      Starrett
# firstnames                    David A.
# firstinits                          DA
# suffix
# reordered_name            Starrett, DA
# doclists                           NaN
# Name: 163, dtype: object
# Starrett, DA
#
# ***Searching for: Starrett, DA
# Ranking                                          3
# University Name                Stanford University
# Name                                  Gavin Wright
# Position                                 Professor
# URL                http://web.stanford.edu/~write/
# hosting domain                  University webpage
# lastname                                    Wright
# firstnames                                   Gavin
# firstinits                                       G
# suffix
# reordered_name                           Wright, G
# doclists                                       NaN
# Name: 164, dtype: object
# Wright, G
# TOO MANY MATCHES: Wright, G
#
# Ranking                                     3
# University Name           Stanford University
# Name                              Ward Hanson
# Position                             Lecturer
# URL                http://www.wardhanson.com/
# hosting domain                          Yahoo
# lastname                               Hanson
# firstnames                               Ward
# firstinits                                  W
# suffix
# reordered_name                      Hanson, W
# doclists                                  NaN
# Name: 165, dtype: object
# Hanson, W
# TOO MANY MATCHES: Hanson, W
#
# Ranking                                          3
# University Name                Stanford University
# Name                                     Gopi Goda
# Position                                  Lecturer
# URL                https://web.stanford.edu/~gopi/
# hosting domain                  University webpage
# lastname                                      Goda
# firstnames                                    Gopi
# firstinits                                       G
# suffix
# reordered_name                             Goda, G
# doclists                                       NaN
# Name: 166, dtype: object
# Goda, G
#
# ***Searching for: Goda, G
# Ranking                                                    3
# University Name                          Stanford University
# Name                                        Martin O'Connell
# Position                                            Lecturer
# URL                https://www.ifs.org.uk/people/profile/415
# hosting domain                          Organization webpage
# lastname                                           O'Connell
# firstnames                                            Martin
# firstinits                                                 M
# suffix
# reordered_name                                  O'Connell, M
# doclists                                                 NaN
# Name: 167, dtype: object
# O'Connell, M
# TOO MANY MATCHES: O'Connell, M
#
# Ranking                                          3
# University Name                Stanford University
# Name                         Marcelo Clerici-Arias
# Position                                  Lecturer
# URL                http://learn-econ.blogspot.com/
# hosting domain                            Blogspot
# lastname                             Clerici-Arias
# firstnames                                 Marcelo
# firstinits                                       M
# suffix
# reordered_name                    Clerici-Arias, M
# doclists                                       NaN
# Name: 168, dtype: object
# Clerici-Arias, M
#
# ***Searching for: Clerici-Arias, M
# Ranking                              3
# University Name    Stanford University
# Name                   Alexander Gould
# Position                      Lecturer
# URL
# hosting domain
# lastname                         Gould
# firstnames                   Alexander
# firstinits                           A
# suffix
# reordered_name                Gould, A
# doclists                           NaN
# Name: 169, dtype: object
# Gould, A
# TOO MANY MATCHES: Gould, A
#
# Ranking                                      3
# University Name            Stanford University
# Name                        Christopher Makler
# Position                              Lecturer
# URL                https://www.econgraphs.org/
# hosting domain
# lastname                                Makler
# firstnames                         Christopher
# firstinits                                   C
# suffix
# reordered_name                       Makler, C
# doclists                                   NaN
# Name: 170, dtype: object
# Makler, C
#
# ***Searching for: Makler, C
# Ranking                              3
# University Name    Stanford University
# Name                      Scott McKeon
# Position                      Lecturer
# URL
# hosting domain
# lastname                        McKeon
# firstnames                       Scott
# firstinits                           S
# suffix
# reordered_name               McKeon, S
# doclists                           NaN
# Name: 171, dtype: object
# McKeon, S
# multiple pages for:  McKeon, S pages =  2
#
# ***Searching for: McKeon, S
# no close match: McKeon-Slattery, M
# no close match: McKeon-Slattery, M
# no close match: McKeon-Slattery, M
# no close match: McKeon-Slattery, M
# no close match: McKeon-Slattery, M
# no close match: McKeon-Slattery, M
# no close match: McKeon-Slattery, M
# no close match: McKeon-Slattery, M
#
# ***Searching for: McKeon, S
# Ranking                                  3
# University Name        Stanford University
# Name                  Cristian Santesteban
# Position                          Lecturer
# URL                http://redpeakecon.com/
# hosting domain
# lastname                       Santesteban
# firstnames                        Cristian
# firstinits                               C
# suffix
# reordered_name              Santesteban, C
# doclists                               NaN
# Name: 172, dtype: object
# Santesteban, C
#
# ***Searching for: Santesteban, C
# Ranking                                                            3
# University Name                                  Stanford University
# Name                                                  Brett Saraniti
# Position                                                    Lecturer
# URL                https://www.kellogg.northwestern.edu/faculty/d...
# hosting domain                                    University webpage
# lastname                                                    Saraniti
# firstnames                                                     Brett
# firstinits                                                         B
# suffix
# reordered_name                                           Saraniti, B
# doclists                                                         NaN
# Name: 173, dtype: object
# Saraniti, B
#
# ***Searching for: Saraniti, B
# Ranking                              3
# University Name    Stanford University
# Name                   Mark L. Tendall
# Position                      Lecturer
# URL
# hosting domain
# lastname                       Tendall
# firstnames                     Mark L.
# firstinits                          ML
# suffix
# reordered_name             Tendall, ML
# doclists                           NaN
# Name: 174, dtype: object
# Tendall, ML
#
# ***Searching for: Tendall, ML
# Ranking                              3
# University Name    Stanford University
# Name                      Ramin Toloui
# Position                      Lecturer
# URL
# hosting domain
# lastname                        Toloui
# firstnames                       Ramin
# firstinits                           R
# suffix
# reordered_name               Toloui, R
# doclists                           NaN
# Name: 175, dtype: object
# Toloui, R
#
# ***Searching for: Toloui, R
# Ranking                                             3
# University Name                   Stanford University
# Name                                      Susan Athey
# Position                        Professor by Courtesy
# URL                https://athey.people.stanford.edu/
# hosting domain                     University webpage
# lastname                                        Athey
# firstnames                                      Susan
# firstinits                                          S
# suffix
# reordered_name                               Athey, S
# doclists                                          NaN
# Name: 176, dtype: object
# Athey, S
# multiple pages for:  Athey, S pages =  3
#
# ***Searching for: Athey, S
#
# ***Searching for: Athey, S
#
# ***Searching for: Athey, S
# Ranking                                         3
# University Name               Stanford University
# Name                         Jayanta Bhattacharya
# Position                    Professor by Courtesy
# URL                https://web.stanford.edu/~jay/
# hosting domain                 University webpage
# lastname                             Bhattacharya
# firstnames                                Jayanta
# firstinits                                      J
# suffix
# reordered_name                    Bhattacharya, J
# doclists                                      NaN
# Name: 177, dtype: object
# Bhattacharya, J
# TOO MANY MATCHES: Bhattacharya, J
#
# Ranking                                              3
# University Name                    Stanford University
# Name                                      Jeremy Bulow
# Position                         Professor by Courtesy
# URL                https://jbulow.people.stanford.edu/
# hosting domain                      University webpage
# lastname                                         Bulow
# firstnames                                      Jeremy
# firstinits                                           J
# suffix
# reordered_name                                Bulow, J
# doclists                                           NaN
# Name: 178, dtype: object
# Bulow, J
# multiple pages for:  Bulow, J pages =  8
#
# ***Searching for: Bulow, J
# no close match: Yde, A
#
# ***Searching for: Bulow, J
#
# ***Searching for: Bulow, J
#
# ***Searching for: Bulow, J
#
# ***Searching for: Bulow, J
#
# ***Searching for: Bulow, J
# no close match: Bülow-Jacobsen, A
#
# ***Searching for: Bulow, J
# no close match: Le Bomin, J
#
# ***Searching for: Bulow, J
# Ranking                                              3
# University Name                    Stanford University
# Name                                   Rebecca Diamond
# Position               Assistant Professor by Courtesy
# URL                https://web.stanford.edu/~diamondr/
# hosting domain                      University webpage
# lastname                                       Diamond
# firstnames                                     Rebecca
# firstinits                                           R
# suffix
# reordered_name                              Diamond, R
# doclists                                           NaN
# Name: 179, dtype: object
# Diamond, R
# TOO MANY MATCHES: Diamond, R
#
# Ranking                                         3
# University Name               Stanford University
# Name                               Darrell Duffie
# Position                    Professor by Courtesy
# URL                https://www.darrellduffie.com/
# hosting domain                     Handy Networks
# lastname                                   Duffie
# firstnames                                Darrell
# firstinits                                      D
# suffix
# reordered_name                          Duffie, D
# doclists                                      NaN
# Name: 180, dtype: object
# Duffie, D
# multiple pages for:  Duffie, D pages =  4
#
# ***Searching for: Duffie, D
#
# ***Searching for: Duffie, D
#
# ***Searching for: Duffie, D
#
# ***Searching for: Duffie, D
# Ranking                                             3
# University Name                   Stanford University
# Name                                 Marcel Fafchamps
# Position                        Professor by Courtesy
# URL                http://web.stanford.edu/~fafchamp/
# hosting domain                     University webpage
# lastname                                    Fafchamps
# firstnames                                     Marcel
# firstinits                                          M
# suffix
# reordered_name                           Fafchamps, M
# doclists                                          NaN
# Name: 181, dtype: object
# Fafchamps, M
# multiple pages for:  Fafchamps, M pages =  3
#
# ***Searching for: Fafchamps, M
#
# ***Searching for: Fafchamps, M
#
# ***Searching for: Fafchamps, M
# Ranking                                                    3
# University Name                          Stanford University
# Name                                         James D. Fearon
# Position                               Professor by Courtesy
# URL                https://fearonresearch.stanford.edu/53-2/
# hosting domain                            University webpage
# lastname                                              Fearon
# firstnames                                          James D.
# firstinits                                                JD
# suffix
# reordered_name                                    Fearon, JD
# doclists                                                 NaN
# Name: 182, dtype: object
# Fearon, JD
#
# ***Searching for: Fearon, JD
# Ranking                                                           3
# University Name                                 Stanford University
# Name                                                   Jacob Goldin
# Position                                      Professor by Courtesy
# URL                https://law.stanford.edu/directory/jacob-goldin/
# hosting domain                                   University webpage
# lastname                                                     Goldin
# firstnames                                                    Jacob
# firstinits                                                        J
# suffix
# reordered_name                                            Goldin, J
# doclists                                                        NaN
# Name: 183, dtype: object
# Goldin, J
# TOO MANY MATCHES: Goldin, J
#
# Ranking                                     3
# University Name           Stanford University
# Name                         Stephen H. Haber
# Position                Professor by Courtesy
# URL                https://stephen-haber.com/
# hosting domain                       BlueHost
# lastname                                Haber
# firstnames                         Stephen H.
# firstinits                                 SH
# suffix
# reordered_name                      Haber, SH
# doclists                                  NaN
# Name: 184, dtype: object
# Haber, SH
#
# ***Searching for: Haber, SH
# Ranking                                                3
# University Name                      Stanford University
# Name                                        Saumitra Jha
# Position                           Professor by Courtesy
# URL                https://saumitra.people.stanford.edu/
# hosting domain                        University webpage
# lastname                                             Jha
# firstnames                                      Saumitra
# firstinits                                             S
# suffix
# reordered_name                                    Jha, S
# doclists                                             NaN
# Name: 185, dtype: object
# Jha, S
# TOO MANY MATCHES: Jha, S
#
# Ranking                                                        3
# University Name                              Stanford University
# Name                                             Charles Kolstad
# Position                                   Professor by Courtesy
# URL                https://profiles.stanford.edu/charles-kolstad
# hosting domain                                University webpage
# lastname                                                 Kolstad
# firstnames                                               Charles
# firstinits                                                     C
# suffix
# reordered_name                                        Kolstad, C
# doclists                                                     NaN
# Name: 186, dtype: object
# Kolstad, C
# multiple pages for:  Kolstad, C pages =  2
#
# ***Searching for: Kolstad, C
#
# ***Searching for: Kolstad, C
# Ranking                                                            3
# University Name                                  Stanford University
# Name                                                  David M. Kreps
# Position                                       Professor by Courtesy
# URL                https://www.gsb.stanford.edu/faculty-research/...
# hosting domain                                    University webpage
# lastname                                                       Kreps
# firstnames                                                  David M.
# firstinits                                                        DM
# suffix
# reordered_name                                             Kreps, DM
# doclists                                                         NaN
# Name: 187, dtype: object
# Kreps, DM
# multiple pages for:  Kreps, DM pages =  2
#
# ***Searching for: Kreps, DM
#
# ***Searching for: Kreps, DM
# Ranking                                                            3
# University Name                                  Stanford University
# Name                                                   Edward Lazear
# Position                                       Professor by Courtesy
# URL                https://www.gsb.stanford.edu/faculty-research/...
# hosting domain                                    University webpage
# lastname                                                      Lazear
# firstnames                                                    Edward
# firstinits                                                         E
# suffix
# reordered_name                                             Lazear, E
# doclists                                                         NaN
# Name: 188, dtype: object
# Lazear, E
# multiple pages for:  Lazear, E pages =  3
#
# ***Searching for: Lazear, E
#
# ***Searching for: Lazear, E
#
# ***Searching for: Lazear, E
# Ranking                                                3
# University Name                      Stanford University
# Name                                        Grant Miller
# Position                 Associate Professor by Courtesy
# URL                https://ngmiller.people.stanford.edu/
# hosting domain                        University webpage
# lastname                                          Miller
# firstnames                                         Grant
# firstinits                                             G
# suffix
# reordered_name                                 Miller, G
# doclists                                             NaN
# Name: 189, dtype: object
# Miller, G
# TOO MANY MATCHES: Miller, G
#
# Ranking                                                        3
# University Name                              Stanford University
# Name                                          Rosamond L. Naylor
# Position                                   Professor by Courtesy
# URL                https://profiles.stanford.edu/rosamond-naylor
# hosting domain                                University webpage
# lastname                                                  Naylor
# firstnames                                           Rosamond L.
# firstinits                                                    RL
# suffix
# reordered_name                                        Naylor, RL
# doclists                                                     NaN
# Name: 190, dtype: object
# Naylor, RL
# multiple pages for:  Naylor, RL pages =  3
#
# ***Searching for: Naylor, RL
#
# ***Searching for: Naylor, RL
#
# ***Searching for: Naylor, RL
# Ranking                                                            3
# University Name                                  Stanford University
# Name                                                  Peter C. Reiss
# Position                                       Professor by Courtesy
# URL                https://www.gsb.stanford.edu/faculty-research/...
# hosting domain                                    University webpage
# lastname                                                       Reiss
# firstnames                                                  Peter C.
# firstinits                                                        PC
# suffix
# reordered_name                                             Reiss, PC
# doclists                                                         NaN
# Name: 191, dtype: object
# Reiss, PC
#
# ***Searching for: Reiss, PC
# Ranking                                              3
# University Name                    Stanford University
# Name                                   Gregory Rosston
# Position                         Professor by Courtesy
# URL                https://web.stanford.edu/~grosston/
# hosting domain                      University webpage
# lastname                                       Rosston
# firstnames                                     Gregory
# firstinits                                           G
# suffix
# reordered_name                              Rosston, G
# doclists                                           NaN
# Name: 192, dtype: object
# Rosston, G
#
# ***Searching for: Rosston, G
# Ranking                                                            3
# University Name                                  Stanford University
# Name                                               Kenneth Singleton
# Position                                       Professor by Courtesy
# URL                https://www.gsb.stanford.edu/faculty-research/...
# hosting domain                                    University webpage
# lastname                                                   Singleton
# firstnames                                                   Kenneth
# firstinits                                                         K
# suffix
# reordered_name                                          Singleton, K
# doclists                                                         NaN
# Name: 193, dtype: object
# Singleton, K
# multiple pages for:  Singleton, K pages =  7
#
# ***Searching for: Singleton, K
#
# ***Searching for: Singleton, K
#
# ***Searching for: Singleton, K
#
# ***Searching for: Singleton, K
#
# ***Searching for: Singleton, K
#
# ***Searching for: Singleton, K
#
# ***Searching for: Singleton, K
# Ranking                                         3
# University Name               Stanford University
# Name                            Andrzej Skrzypacz
# Position                    Professor by Courtesy
# URL                http://web.stanford.edu/~skrz/
# hosting domain                 University webpage
# lastname                                Skrzypacz
# firstnames                                Andrzej
# firstinits                                      A
# suffix
# reordered_name                       Skrzypacz, A
# doclists                                      NaN
# Name: 194, dtype: object
# Skrzypacz, A
#
# ***Searching for: Skrzypacz, A
# Ranking                                                           4
# University Name    London School of Economics and Political Science
# Name                                                Philippe Aghion
# Position                                                  Professor
# URL                              https://scholar.harvard.edu/aghion
# hosting domain                                   University webpage
# lastname                                                     Aghion
# firstnames                                                 Philippe
# firstinits                                                        P
# suffix
# reordered_name                                            Aghion, P
# doclists                                                        NaN
# Name: 195, dtype: object
# Aghion, P
# multiple pages for:  Aghion, P pages =  3
#
# ***Searching for: Aghion, P
#
# ***Searching for: Aghion, P
#
# ***Searching for: Aghion, P
# Ranking                                                           4
# University Name    London School of Economics and Political Science
# Name                                                    Nava Ashraf
# Position                                                  Professor
# URL                               https://ashrafnava.wordpress.com/
# hosting domain                                            Wordpress
# lastname                                                     Ashraf
# firstnames                                                     Nava
# firstinits                                                        N
# suffix
# reordered_name                                            Ashraf, N
# doclists                                                        NaN
# Name: 196, dtype: object
# Ashraf, N
# TOO MANY MATCHES: Ashraf, N
#
# Ranking                                                           4
# University Name    London School of Economics and Political Science
# Name                                                Oriana Bandiera
# Position                                                  Professor
# URL                                 https://www.orianabandiera.net/
# hosting domain                                          Wix Hosting
# lastname                                                   Bandiera
# firstnames                                                   Oriana
# firstinits                                                        O
# suffix
# reordered_name                                          Bandiera, O
# doclists                                                        NaN
# Name: 197, dtype: object
# Bandiera, O
#
# ***Searching for: Bandiera, O
# Ranking                                                           4
# University Name    London School of Economics and Political Science
# Name                                                   David Baqaee
# Position                                        Assistant Professor
# URL                 https://sites.Google site.com/site/davidbaqaee/
# hosting domain                                          Google site
# lastname                                                     Baqaee
# firstnames                                                    David
# firstinits                                                        D
# suffix
# reordered_name                                            Baqaee, D
# doclists                                                        NaN
# Name: 198, dtype: object
# Baqaee, D
#
# ***Searching for: Baqaee, D
# Ranking                                                           4
# University Name    London School of Economics and Political Science
# Name                                               Sir Charles Bean
# Position                                                  Professor
# URL
# hosting domain
# lastname                                                       Bean
# firstnames                                              Sir Charles
# firstinits                                                       SC
# suffix
# reordered_name                                             Bean, SC
# doclists                                                        NaN
# Name: 199, dtype: object
# Bean, SC
#
# ***Searching for: Bean, SC
# Ranking                                                           4
# University Name    London School of Economics and Political Science
# Name                                               Gianluca Benigno
# Position                                        Associate Professor
# URL                              http://personal.lse.ac.uk/BENIGNO/
# hosting domain                                   University webpage
# lastname                                                    Benigno
# firstnames                                                 Gianluca
# firstinits                                                        G
# suffix
# reordered_name                                           Benigno, G
# doclists                                                        NaN
# Name: 200, dtype: object
# Benigno, G
# multiple pages for:  Benigno, G pages =  2
#
# ***Searching for: Benigno, G
# no close match: Rizo-Maestre, C
# no close match: Rivera, MM
# no close match: Lozoya-Peral, A
# no close match: Ibarra-Coves, F
#
# ***Searching for: Benigno, G
# Ranking                                                            4
# University Name     London School of Economics and Political Science
# Name                                                    Erik Berglof
# Position                                                   Professor
# URL                http://www.lse.ac.uk/economics/people/personal...
# hosting domain                                    University webpage
# lastname                                                     Berglof
# firstnames                                                      Erik
# firstinits                                                         E
# suffix
# reordered_name                                            Berglof, E
# doclists                                                         NaN
# Name: 201, dtype: object
# Berglof, E
# multiple pages for:  Berglof, E pages =  2
#
# ***Searching for: Berglof, E
#
# ***Searching for: Berglof, E
# Ranking                                                            4
# University Name     London School of Economics and Political Science
# Name                                                      Tim Besley
# Position                                                   Professor
# URL                http://www.lse.ac.uk/economics/people/personal...
# hosting domain                                    University webpage
# lastname                                                      Besley
# firstnames                                                       Tim
# firstinits                                                         T
# suffix
# reordered_name                                             Besley, T
# doclists                                                         NaN
# Name: 202, dtype: object
# Besley, T
# multiple pages for:  Besley, T pages =  5
#
# ***Searching for: Besley, T
#
# ***Searching for: Besley, T
#
# ***Searching for: Besley, T
#
# ***Searching for: Besley, T
#
# ***Searching for: Besley, T
# Ranking                                                           4
# University Name    London School of Economics and Political Science
# Name                                                   Gharad Bryan
# Position                                                   Lecturer
# URL                 https://sites.Google site.com/site/gharadbryan/
# hosting domain                                          Google site
# lastname                                                      Bryan
# firstnames                                                   Gharad
# firstinits                                                        G
# suffix
# reordered_name                                             Bryan, G
# doclists                                                        NaN
# Name: 203, dtype: object
# Bryan, G
# TOO MANY MATCHES: Bryan, G
#
# Ranking                                                            4
# University Name     London School of Economics and Political Science
# Name                                                   Robin Burgess
# Position                                                   Professor
# URL                http://www.lse.ac.uk/economics/people/personal...
# hosting domain                                    University webpage
# lastname                                                     Burgess
# firstnames                                                     Robin
# firstinits                                                         R
# suffix
# reordered_name                                            Burgess, R
# doclists                                                         NaN
# Name: 204, dtype: object
# Burgess, R
# TOO MANY MATCHES: Burgess, R
#
# Ranking                                                           4
# University Name    London School of Economics and Political Science
# Name                                              Francesco Caselli
# Position                                                  Professor
# URL                             http://personal.lse.ac.uk/casellif/
# hosting domain                                   University webpage
# lastname                                                    Caselli
# firstnames                                                Francesco
# firstinits                                                        F
# suffix
# reordered_name                                           Caselli, F
# doclists                                                        NaN
# Name: 205, dtype: object
# Caselli, F
# multiple pages for:  Caselli, F pages =  4
#
# ***Searching for: Caselli, F
#
# ***Searching for: Caselli, F
#
# ***Searching for: Caselli, F
#
# ***Searching for: Caselli, F
# Ranking                                                           4
# University Name    London School of Economics and Political Science
# Name                                                   Frank Cowell
# Position                                                  Professor
# URL                http://darp.lse.ac.uk/frankweb/Frank/default.htm
# hosting domain                                   University webpage
# lastname                                                     Cowell
# firstnames                                                    Frank
# firstinits                                                        F
# suffix
# reordered_name                                            Cowell, F
# doclists                                                        NaN
# Name: 206, dtype: object
# Cowell, F
# multiple pages for:  Cowell, F pages =  4
#
# ***Searching for: Cowell, F
#
# ***Searching for: Cowell, F
#
# ***Searching for: Cowell, F
#
# ***Searching for: Cowell, F
# Ranking                                                           4
# University Name    London School of Economics and Political Science
# Name                                                Wouter Den Haan
# Position                                                  Professor
# URL                                   http://www.wouterdenhaan.com/
# hosting domain                                                iPage
# lastname                                                       Haan
# firstnames                                               Wouter Den
# firstinits                                                       WD
# suffix
# reordered_name                                             Haan, WD
# doclists                                                        NaN
# Name: 207, dtype: object
# Haan, WD
#
# ***Searching for: Haan, WD
# Ranking                                                           4
# University Name    London School of Economics and Political Science
# Name                                                  Swati Dhingra
# Position                                        Associate Professor
# URL                                       https://www.sdhingra.com/
# hosting domain                                          Wix Hosting
# lastname                                                    Dhingra
# firstnames                                                    Swati
# firstinits                                                        S
# suffix
# reordered_name                                           Dhingra, S
# doclists                                                        NaN
# Name: 208, dtype: object
# Dhingra, S
# TOO MANY MATCHES: Dhingra, S
#
# Ranking                                                           4
# University Name    London School of Economics and Political Science
# ...
# Name                                            Benjamin E. Hermalin
# Position                                                   Professor
# URL                http://faculty.haas.berkeley.edu/hermalin/inde...
# hosting domain                                    University webpage
# lastname                                                    Hermalin
# firstnames                                               Benjamin E.
# firstinits                                                        BE
# suffix
# reordered_name                                          Hermalin, BE
# doclists                                                         NaN
# Name: 287, dtype: object
# Hermalin, BE
# multiple pages for:  Hermalin, BE pages =  2
#
# ***Searching for: Hermalin, BE
#
# ***Searching for: Hermalin, BE
# Ranking                                                            5
# University Name                    University of California, Berkely
# Name                                                   Hilary Hoynes
# Position                                                   Professor
# URL                https://gspp.berkeley.edu/directories/faculty/...
# hosting domain                                    University webpage
# lastname                                                      Hoynes
# firstnames                                                    Hilary
# firstinits                                                         H
# suffix
# reordered_name                                             Hoynes, H
# doclists                                                         NaN
# Name: 288, dtype: object
# Hoynes, H
# multiple pages for:  Hoynes, H pages =  2
#
# ***Searching for: Hoynes, H
#
# ***Searching for: Hoynes, H
# Ranking                                                         5
# University Name                 University of California, Berkely
# Name                                              Michael Jansson
# Position                                                Professor
# URL                https://eml.berkeley.edu//~mjansson/index.html
# hosting domain                                 University webpage
# lastname                                                  Jansson
# firstnames                                                Michael
# firstinits                                                      M
# suffix
# reordered_name                                         Jansson, M
# doclists                                                      NaN
# Name: 289, dtype: object
# Jansson, M
# TOO MANY MATCHES: Jansson, M
#
# Ranking                                            5
# University Name    University of California, Berkely
# Name                                   Shachar Kariv
# Position                                   Professor
# URL                https://eml.berkeley.edu//~kariv/
# hosting domain                    University webpage
# lastname                                       Kariv
# firstnames                                   Shachar
# firstinits                                         S
# suffix
# reordered_name                              Kariv, S
# doclists                                         NaN
# Name: 290, dtype: object
# Kariv, S
#
# ***Searching for: Kariv, S
# Ranking                                                            5
# University Name                    University of California, Berkely
# Name                                                    Michael Katz
# Position                                                   Professor
# URL                http://facultybio.haas.berkeley.edu/faculty-li...
# hosting domain                                    University webpage
# lastname                                                        Katz
# firstnames                                                   Michael
# firstinits                                                         M
# suffix
# reordered_name                                               Katz, M
# doclists                                                         NaN
# Name: 291, dtype: object
# Katz, M
# TOO MANY MATCHES: Katz, M
#
# Ranking                                            5
# University Name    University of California, Berkely
# Name                                    Supreet Kaur
# Position                         Assistant Professor
# URL                      http://www.supreetkaur.com/
# hosting domain                    University webpage
# lastname                                        Kaur
# firstnames                                   Supreet
# firstinits                                         S
# suffix
# reordered_name                               Kaur, S
# doclists                                         NaN
# Name: 292, dtype: object
# Kaur, S
# TOO MANY MATCHES: Kaur, S
#
# Ranking                                            5
# University Name    University of California, Berkely
# Name                                       Kei Kawai
# Position                         Assistant Professor
# URL                         http://www.keikawai.com/
# hosting domain                               Athenix
# lastname                                       Kawai
# firstnames                                       Kei
# firstinits                                         K
# suffix
# reordered_name                              Kawai, K
# doclists                                         NaN
# Name: 293, dtype: object
# Kawai, K
# TOO MANY MATCHES: Kawai, K
#
# Ranking                                                       5
# University Name               University of California, Berkely
# Name                                            Theodore Keeler
# Position                                              Professor
# URL                https://eml.berkeley.edu/~keeler/index.shtml
# hosting domain                               University webpage
# lastname                                                 Keeler
# firstnames                                             Theodore
# firstinits                                                    T
# suffix
# reordered_name                                        Keeler, T
# doclists                                                    NaN
# Name: 294, dtype: object
# Keeler, T
# multiple pages for:  Keeler, T pages =  2
#
# ***Searching for: Keeler, T
#
# ***Searching for: Keeler, T
# Ranking                                                      5
# University Name              University of California, Berkely
# Name                                             Patrick Kline
# Position                                   Associate Professor
# URL                https://eml.berkeley.edu//~pkline/index.htm
# hosting domain                              University webpage
# lastname                                                 Kline
# firstnames                                             Patrick
# firstinits                                                   P
# suffix
# reordered_name                                        Kline, P
# doclists                                                   NaN
# Name: 295, dtype: object
# Kline, P
# TOO MANY MATCHES: Kline, P
#
# Ranking                                                      5
# University Name              University of California, Berkely
# Name                                             Ronald D. Lee
# Position                                             Professor
# URL                http://www.demog.berkeley.edu/~rlee/papers/
# hosting domain                              University webpage
# lastname                                                   Lee
# firstnames                                           Ronald D.
# firstinits                                                  RD
# suffix
# reordered_name                                         Lee, RD
# doclists                                                   NaN
# Name: 296, dtype: object
# Lee, RD
# multiple pages for:  Lee, RD pages =  8
#
# ***Searching for: Lee, RD
#
# ***Searching for: Lee, RD
#
# ***Searching for: Lee, RD
#
# ***Searching for: Lee, RD
#
# ***Searching for: Lee, RD
#
# ***Searching for: Lee, RD
#
# ***Searching for: Lee, RD
#
# ***Searching for: Lee, RD
# Ranking                                            5
# University Name    University of California, Berkely
# Name                                 John M. Letiche
# Position                                   Professor
# URL
# hosting domain
# lastname                                     Letiche
# firstnames                                   John M.
# firstinits                                        JM
# suffix
# reordered_name                           Letiche, JM
# doclists                                         NaN
# Name: 297, dtype: object
# Letiche, JM
#
# ***Searching for: Letiche, JM
# Ranking                                                       5
# University Name               University of California, Berkely
# Name                                          Ulrike Malmendier
# Position                                              Professor
# URL                https://eml.berkeley.edu//~ulrike/index.html
# hosting domain                               University webpage
# lastname                                             Malmendier
# firstnames                                               Ulrike
# firstinits                                                    U
# suffix
# reordered_name                                    Malmendier, U
# doclists                                                    NaN
# Name: 298, dtype: object
# Malmendier, U
#
# ***Searching for: Malmendier, U
# Ranking                                                          5
# University Name                  University of California, Berkely
# Name                                            Daniel L. McFadden
# Position                                                 Professor
# URL                https://eml.berkeley.edu//~mcfadden/index.shtml
# hosting domain                                  University webpage
# lastname                                                  McFadden
# firstnames                                               Daniel L.
# firstinits                                                      DL
# suffix
# reordered_name                                        McFadden, DL
# doclists                                                       NaN
# Name: 299, dtype: object
# McFadden, DL
# multiple pages for:  McFadden, DL pages =  2
#
# ***Searching for: McFadden, DL
#
# ***Searching for: McFadden, DL
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 7
#       4 #startidx = 0
#       5 #endidx = 3
#       6 subdf = authordf.iloc[startidx:endidx].copy()
# ----> 7 subdf.loc[:, "doclists"] = subdf.apply(lambda x: get_author_metadata(x, "reordered_name"), axis=1)
#       8 #authordf.loc[startidx: endidx, "doclists"] = authordf.iloc[startidx:endidx].apply(lambda x: get_author_metadata(x, "reordered_name"), axis=1)
#       9 docdf = subdf.explode("doclists")
#
# File c:\Users\F0040RP\Documents\DartLib_RDS\projects\bibliometrics\.venv\Lib\site-packages\pandas\core\frame.py:10347, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10333 from pandas.core.apply import frame_apply
#   10335 op = frame_apply(
#   10336     self,
#   10337     func=func,
#    (...)
#   10345     kwargs=kwargs,
#   10346 )
# > 10347 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\F0040RP\Documents\DartLib_RDS\projects\bibliometrics\.venv\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File c:\Users\F0040RP\Documents\DartLib_RDS\projects\bibliometrics\.venv\Lib\site-packages\pandas\core\apply.py:1068, in FrameApply.apply_standard(self)
#    1065     results, res_index = self.apply_series_numba()
#    1067 # wrap results
# -> 1068 return self.wrap_results(results, res_index)
#
# File c:\Users\F0040RP\Documents\DartLib_RDS\projects\bibliometrics\.venv\Lib\site-packages\pandas\core\apply.py:1107, in FrameApply.wrap_results(self, results, res_index)
#    1105 # see if we can infer the results
#    1106 if len(results) > 0 and 0 in results and is_sequence(results[0]):
# -> 1107     return self.wrap_results_for_axis(results, res_index)
#    1109 # dict of scalars
#    1110
#    1111 # the default dtype of an empty Series is `object`, but this
#    1112 # code can be hit by df.mean() where the result should have dtype
#    1113 # float64 even if it's an empty Series.
#    1114 constructor_sliced = self.obj._constructor_sliced
#
# File c:\Users\F0040RP\Documents\DartLib_RDS\projects\bibliometrics\.venv\Lib\site-packages\pandas\core\apply.py:1354, in FrameColumnApply.wrap_results_for_axis(self, results, res_index)
#    1350     result.index = res_index
#    1352 # we may want to infer results
#    1353 else:
# -> 1354     result = self.infer_to_same_shape(results, res_index)
#    1356 return result
#
# File c:\Users\F0040RP\Documents\DartLib_RDS\projects\bibliometrics\.venv\Lib\site-packages\pandas\core\apply.py:1360, in FrameColumnApply.infer_to_same_shape(self, results, res_index)
#    1358 def infer_to_same_shape(self, results: ResType, res_index: Index) -> DataFrame:
#    1359     """infer the results to the same shape as the input object"""
# -> 1360     result = self.obj._constructor(data=results)
#    1361     result = result.T
#    1363     # set the index
#
# File c:\Users\F0040RP\Documents\DartLib_RDS\projects\bibliometrics\.venv\Lib\site-packages\pandas\core\frame.py:767, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     761     mgr = self._init_mgr(
#     762         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     763     )
#     765 elif isinstance(data, dict):
#     766     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 767     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     768 elif isinstance(data, ma.MaskedArray):
#     769     from numpy.ma import mrecords
#
# File c:\Users\F0040RP\Documents\DartLib_RDS\projects\bibliometrics\.venv\Lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File c:\Users\F0040RP\Documents\DartLib_RDS\projects\bibliometrics\.venv\Lib\site-packages\pandas\core\internals\construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File c:\Users\F0040RP\Documents\DartLib_RDS\projects\bibliometrics\.venv\Lib\site-packages\pandas\core\internals\construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length

# %%
explodedf = authordf.explode("doclists")
print(explodedf.shape)
explodedf.head(10)
# Out:
# (3359, 12)
#    Ranking  University Name             Name   Position  \
# 0        1  Harvard College  Alberto Alesina  Professor
# 0        1  Harvard College  Alberto Alesina  Professor
# 0        1  Harvard College  Alberto Alesina  Professor
# 0        1  Harvard College  Alberto Alesina  Professor
# 0        1  Harvard College  Alberto Alesina  Professor
# 0        1  Harvard College  Alberto Alesina  Professor
# 0        1  Harvard College  Alberto Alesina  Professor
# 0        1  Harvard College  Alberto Alesina  Professor
# 0        1  Harvard College  Alberto Alesina  Professor
# 0        1  Harvard College  Alberto Alesina  Professor
#
#                                                 URL      hosting domain  \
# 0  https://scholar.harvard.edu/alesina/publications  University webpage
# 0  https://scholar.harvard.edu/alesina/publications  University webpage
# 0  https://scholar.harvard.edu/alesina/publications  University webpage
# 0  https://scholar.harvard.edu/alesina/publications  University webpage
# 0  https://scholar.harvard.edu/alesina/publications  University webpage
# 0  https://scholar.harvard.edu/alesina/publications  University webpage
# 0  https://scholar.harvard.edu/alesina/publications  University webpage
# 0  https://scholar.harvard.edu/alesina/publications  University webpage
# 0  https://scholar.harvard.edu/alesina/publications  University webpage
# 0  https://scholar.harvard.edu/alesina/publications  University webpage
#
#   lastname firstnames firstinits suffix reordered_name  \
# 0  Alesina    Alberto          A            Alesina, A
# 0  Alesina    Alberto          A            Alesina, A
# 0  Alesina    Alberto          A            Alesina, A
# 0  Alesina    Alberto          A            Alesina, A
# 0  Alesina    Alberto          A            Alesina, A
# 0  Alesina    Alberto          A            Alesina, A
# 0  Alesina    Alberto          A            Alesina, A
# 0  Alesina    Alberto          A            Alesina, A
# 0  Alesina    Alberto          A            Alesina, A
# 0  Alesina    Alberto          A            Alesina, A
#
#                                             doclists
# 0  [ALESINA, A, CBE-0396-2022, WOS:A1979GV9620002...
# 0  [ALESINA, A, CBE-0396-2022, WOS:A1981LH4860000...
# 0  [ALESINA, A, CBE-0396-2022, WOS:A1982QW1520000...
# 0  [ALESINA, A, CBE-0396-2022, WOS:A1983RJ7480000...
# 0  [ALESINA, A, CBE-0396-2022, WOS:A1985A10860001...
# 0  [ALESINA, A, EMJ-5429-2022, WOS:A1987J36310001...
# 0  [ALESINA, A, CBE-0396-2022, WOS:A1987L12860000...
# 0  [ALESINA, A, EMJ-5429-2022, WOS:A1988M17760001...
# 0  [ALESINA, A, CBE-0396-2022, WOS:A1988AH4800000...
# 0  [ALESINA, A, EMJ-5429-2022, WOS:A1988M17930000...

# %% [markdown]
# https://stackoverflow.com/questions/35491274/split-a-pandas-column-of-lists-into-multiple-columns
#
# [tgt_shortname, tgt_id,
#                         doc_uid, doi, issn, eissn,
#                         so_title, keywords, pubyear,
#                         citedby_count]

# %%
explodedf['doclists'] = explodedf['doclists'].fillna("[]")

# %%
explodedf[["match_name", "resID", "doc_uid", "doc_doi", "doc_issn",
           "doc_eissn", "so_title", "au_keywords", "pubyear", "citedby_count"]] =\
           pd.DataFrame(explodedf.doclists.tolist(), index=explodedf.index)

# %%
explodedf.columns
# Out:
# Index(['Ranking', 'University Name', 'Name', 'Position', 'URL',
#        'hosting domain', 'lastname', 'firstnames', 'firstinits', 'suffix',
#        'reordered_name', 'doclists', 'match_name', 'resID', 'doc_uid',
#        'doc_doi', 'doc_issn', 'doc_eissn', 'so_title', 'au_keywords',
#        'pubyear', 'citedby_count'],
#       dtype='object')

# %%
# Out:
#    Ranking  University Name             Name   Position  \
# 0        1  Harvard College  Alberto Alesina  Professor
# 0        1  Harvard College  Alberto Alesina  Professor
# 0        1  Harvard College  Alberto Alesina  Professor
# 0        1  Harvard College  Alberto Alesina  Professor
# 0        1  Harvard College  Alberto Alesina  Professor
#
#                                                 URL      hosting domain  \
# 0  https://scholar.harvard.edu/alesina/publications  University webpage
# 0  https://scholar.harvard.edu/alesina/publications  University webpage
# 0  https://scholar.harvard.edu/alesina/publications  University webpage
# 0  https://scholar.harvard.edu/alesina/publications  University webpage
# 0  https://scholar.harvard.edu/alesina/publications  University webpage
#
#   lastname firstnames firstinits suffix  ...  match_name          resID  \
# 0  Alesina    Alberto          A         ...  ALESINA, A  CBE-0396-2022
# 0  Alesina    Alberto          A         ...  ALESINA, A  CBE-0396-2022
# 0  Alesina    Alberto          A         ...  ALESINA, A  CBE-0396-2022
# 0  Alesina    Alberto          A         ...  ALESINA, A  CBE-0396-2022
# 0  Alesina    Alberto          A         ...  ALESINA, A  CBE-0396-2022
#
#                doc_uid                   doc_doi   doc_issn doc_eissn  \
# 0  WOS:A1979GV96200029                            0002-9939
# 0  WOS:A1981LH48600008  10.1109/TCS.1981.1084993  0098-4094
# 0  WOS:A1982QW15200001  10.2140/pjm.1982.103.251  0030-8730
# 0  WOS:A1983RJ74800005                            0017-0097
# 0  WOS:A1985A108600011                            0017-0097
#
#                                            so_title au_keywords pubyear  \
# 0  PROCEEDINGS OF THE AMERICAN MATHEMATICAL SOCIETY          []  [1979]
# 0         IEEE TRANSACTIONS ON CIRCUITS AND SYSTEMS          []  [1981]
# 0                    PACIFIC JOURNAL OF MATHEMATICS          []  [1982]
# 0    GIORNALE DEGLI ECONOMISTI E ANNALI DI ECONOMIA          []  [1983]
# 0    GIORNALE DEGLI ECONOMISTI E ANNALI DI ECONOMIA          []  [1985]
#
#   citedby_count
# 0           0.0
# 0         273.0
# 0           5.0
# 0           0.0
# 0           0.0
#
# [5 rows x 22 columns]
